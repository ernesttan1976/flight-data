# %%
# !python -m venv venv
# # !venv/scripts/activate
# %pip install pandas numpy matplotlib seaborn plotly geopandas scipy scikit-learn statsmodels requests aiohttp shapely ipython h3 ipywidgets dtale

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

import numpy as np

# Data Visualization
import matplotlib.pyplot as plt

import requests
import os

import datetime as dt
import time

from pandas import read_csv
import concurrent.futures
import psutil

from datetime import datetime

import h3
import geopandas as gpd
import shapely
import plotly.express as px

# %%
# Verify that the hexagon grid is suitable
# create_choropleth_map_only_hexagon_df(geojson_df=hexagon_df)

# def create_choropleth_map_only_hexagon_df(geojson_df, alpha=0.1, map_style="carto-positron", color_scale="Viridis"):
#     """
#     Create an interactive choropleth map using Plotly Express.
#     Parameters:
#     - geojson_df (GeoDataFrame): GeoJSON data containing polygon geometries.
#     - alpha (float): Opacity level for the map polygons (0.0 to 1.0).
#     - map_style (str): Map style for the Plotly map (e.g., "carto-positron").
#     - color_scale (str): Color scale for the choropleth map.
#     Returns:
#     None
#     """
#     # Create a choropleth map using px.choropleth_mapbox
#     fig = px.choropleth_mapbox(
#         geojson_df,
#         geojson=geojson_df.geometry,
#         locations=geojson_df.index,  # Use index as locations to avoid duplicate rows
#         # color="Count",
#         color_continuous_scale=color_scale,
#         title="GPS Jam Map",
#         mapbox_style=map_style,
#         center={"lat": home_lat, "lon": home_lng},  # Adjust the center as needed
#         zoom=2,
#     )

#     # Customize the opacity of the hexagons
#     fig.update_traces(marker=dict(opacity=alpha))

#     # Set margins to 25 on all sides
#     fig.update_layout(margin=dict(l=35, r=35, t=45, b=35))
    
#     # Adjust the width of the visualization
#     fig.update_layout(width=1000) 

#     fig.show()

# %%
# hexagon map
def get_hexagon_grid(latitude, longitude, resolution, ring_size):
    """
    Generate a hexagonal grid GeoDataFrame centered around a specified location.
    Parameters:
    - latitude (float): Latitude of the center point.
    - longitude (float): Longitude of the center point.
    - resolution (int): H3 resolution for hexagons.
    - ring_size (int): Number of rings to create around the center hexagon.
    Returns:
    - hexagon_df (geopandas.GeoDataFrame): GeoDataFrame containing hexagons and their geometries.
    """

    # Get the H3 hexagons covering the specified location
    center_h3 = h3.geo_to_h3(latitude, longitude, resolution)
    hexagons = list(h3.k_ring(center_h3, ring_size))  # Convert the set to a list

    # Create a GeoDataFrame with hexagons and their corresponding geometries
    hexagon_geometries = [shapely.geometry.Polygon(h3.h3_to_geo_boundary(hexagon, geo_json=True)) for hexagon in hexagons]
    hexagon_df = gpd.GeoDataFrame({'Hexagon_ID': hexagons, 'geometry': hexagon_geometries})

    return hexagon_df


# Latitude and longitude coordinates
home_lat = 1.3472764
home_lng = 103.9104234

# Generate H3 hexagons at a specified resolution (e.g., 9)
resolution = 5

# Indicate the number of rings around the central hexagon
ring_size = 463

# Hexagon grid around HOME
hexagon_df = get_hexagon_grid(home_lat, home_lng, resolution, ring_size)

def calculate_hexagon_ids(df):
    """
    Calculate Hexagon IDs for each row(ping) in a DataFrame based on their geographic coordinates.
    Args:
        df (pd.DataFrame): DataFrame containing ADSB data with "lat" and "lon" columns.
        hexagon_df (gpd.GeoDataFrame): GeoDataFrame with hexagon geometries and associated Hexagon IDs.
    Returns:
        pd.DataFrame: The input DataFrame with an additional "Hexagon_ID" column indicating the Hexagon ID for each ping.
    """

    # Create a column Hexagon_ID with the ID of the hexagon
    df['Hexagon_ID'] = None

    # Iterate through the hotels in the df DataFrame and calculate hotel counts within each hexagon
    for i, ping in df.iterrows():
        if not isinstance(ping['lat'], float):
            continue  
        resolution=5   
        result = h3.geo_to_h3(ping["lat"], ping["lon"], resolution)
        # print(f'{ping["lat"]},{ping["lon"]}=>{result}')
        if result != 0:
             df.loc[i, 'Hexagon_ID'] = result
    
    return df

def time_elapsed(start_time):
    end_time = time.time()
    return end_time - start_time

time_data={
    "pickle": 0,
    "url": 0,
    "concat": 0,
}

def get_adsb_data(data):
    response = requests.get(data["url"])
    print(f"downloaded {data['url']}")
    json_data = response.json()
    
    df = pd.json_normalize(json_data['aircraft'])
    df = df.fillna("Nan values")
    df = df[df["type"] == 'adsb_icao']
    df['time'] = datetime.fromtimestamp(json_data['now']).strftime("%Y%m%d%H%M%S")
    df['good_bad'] = df['nic'].apply(lambda x: 'bad' if x=="Nan values" or int(x)<=6 else 'good')
    df['alt_baro'] = df['alt_baro'].apply(lambda x: 0 if (x == "ground" or x == "Nan values" ) else float(x))
    df["nic"] = df['nic'].apply(lambda x: int(float(x)) if x !="Nan values" else 0)


    df['Hexagon_ID'] = None
    df = df[['time','Hexagon_ID', 'r', 'time', 'alt_baro', 'nic', 'good_bad', 'hex','lat','lon','type','flight','t','category','version','nac_p','nac_v']]
    df = df.map(lambda x: ', '.join(x) if isinstance(x, list) else x)
    df = df[df["r"]!="Nan values"]

    df = calculate_hexagon_ids(df)

    #save to pickle
    if not os.path.exists(os.path.dirname(data["csv"])):
        os.makedirs(os.path.dirname(data["csv"]))
    df.to_csv(data["csv"])
    return df

def download_data(index, data, length_data_array, start_time_overall):
    start_time = time.time()

    try:
        # if pickle exists, do nothing
        if (os.path.isfile(data["csv"])):
            print(f"csv exists {data['csv']}")
            return
        else:
            get_adsb_data(data)

            time_data["url"] += time_elapsed(start_time)

            remaining_time = (time.time() - start_time_overall)/(index+1) * (length_data_array - index)
            print(f"Remaining execution time: {remaining_time//60:.0f}m {remaining_time%60:.0f}s")

            return

    except Exception as e:
        # Handle other exceptions
        print("An error occurred:", e)

def join_large_csv(folder_path,start,end,file_path):
    if os.path.exists(file_path):
        os.remove(file_path)
    isHeader = True
    with open(file_path, 'w') as outfile:
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            file_datetime = datetime.strptime(file_path, 'csv\\%Y%m%d\\%H%M%SZ.csv')
            print(file_datetime)
            # csv_path = os.path.join('csv',start.strftime("%Y%m%d"), f'{start.strftime("%H%M%S")}Z.csv')
            if filename.endswith('.csv') and start <= file_datetime and file_datetime <= end:
                with open(file_path, 'r') as infile:
                    # skip row header
                    if isHeader:
                        outfile.write(infile.read())
                        isHeader = False
                    else:
                        outfile.write(''.join(infile.readlines()[1:]))
                print(f'Joined {file_path}')

def sampling(datestring, file_path):
    df1 = read_csv(file_path)
    df1_bad = df1[df1['good_bad']=='bad']
    df1_bad.to_csv(os.path.join('csv','joined', f'{datestring}bad.csv'))

    df1_good = df1[df1['good_bad']=='good']
    df1_good.to_csv(os.path.join('csv','joined', f'{datestring}good.csv'))

    sampled_file_path = os.path.join('csv','joined', f'{datestring}sampled.csv')
    bad_path = os.path.join('csv','joined', f'{datestring}bad.csv')
    good_path = os.path.join('csv','joined', f'{datestring}good.csv')
    with open(sampled_file_path, 'w') as outfile:
        with open(bad_path, 'r') as infile:
            outfile.write(infile.read())
        with open(good_path, 'r') as infile:
            lines = infile.readlines()
            filtered_lines = [line for i, line in enumerate(lines[1:]) if (i + 1) % 10 != 0]
            outfile.write(''.join(filtered_lines))
        print(f'Joined {file_path}')
    df1 = read_csv(sampled_file_path)

    df1 = df1.sort_values(by=["Hexagon_ID","r","time"], ascending=[True,True,True])
    df1.to_csv(sampled_file_path)

def load_data(start_date_time,end_date_time, reload=False):
    delta = dt.timedelta(seconds=5)
    start = start_date_time
    df1 = None
    df2 = None
    csv_path = os.path.join('csv', 'joined', f'{start_date_time.strftime("%Y%m%d")}joined.csv')
    hexbin_path = os.path.join('csv', 'hexbin', f'{start_date_time.strftime("%Y%m%d")}hexbin.csv')

    if not reload[0]:

        data_array = []
        while start < end_date_time:
            data_array.append({
                "url": f'https://samples.adsbexchange.com/readsb-hist/{start.strftime("%Y/%m/%d")}/{start.strftime("%H%M%S")}Z.json.gz',
                "pickle": os.path.join('pickle',start.strftime("%Y%m%d"), f'{start.strftime("%H%M%S")}Z.pkl'),
                "csv": os.path.join('csv',start.strftime("%Y%m%d"), f'{start.strftime("%H%M%S")}Z.csv')
                })
            start += delta

        report1=""
        report2=""

        start_time_overall = time.time()

        with concurrent.futures.ThreadPoolExecutor() as executor:
            l = [len(data_array)] * len(data_array)
            list(executor.map(lambda i: download_data(i, data_array[i], l[i], start_time_overall), range(len(data_array))))
            report1 = get_memory_usage()

        join_large_csv(os.path.join('csv',start_date_time.strftime("%Y%m%d")),start_date_time,end_date_time,csv_path)
        sampling(start_date_time.strftime("%Y%m%d"), csv_path)

        start_time_overall = time.time()
        print(f"Download memory usage\n{report1}\n\n")
        print(f"CSV memory usage\n{report2}")
        # only when all the threads are complete, then concat happens
        print(f'Total directory size: {get_directory_size("csv"):.1f} MB')
        print(f"Download time: {(time_data['url']/3600):.1f} min")
        print(f"CSV time: {(time_data['pickle']/3600):.1f} min")
    
    df1 = read_csv(csv_path)

    if not reload[1]:

        df2 = df1.groupby(['Hexagon_ID', 'r'], as_index=False).agg(
                            good_count=('good_bad', lambda x: (x == 'good').sum()),
                            bad_count=('good_bad', lambda x: (x == 'bad').sum()),
                            alt_baro_range=('alt_baro', lambda x: (x.max() - x.min())),
                            time_range=('time', lambda x: x.max() - x.min()))

        df2["total_count"]=df2["good_count"]+df2["bad_count"]
        df2["percentage_bad"]=df2["bad_count"]/df2["total_count"]
        def get_lat(row):
            return h3.h3_to_geo(row['Hexagon_ID'])[0]

        def get_lng(row):
            return h3.h3_to_geo(row['Hexagon_ID'])[1]

        # Apply the function to create new 'lat' and 'lng' columns
        df2['lat'] = df2.apply(get_lat, axis=1)
        df2['lng'] = df2.apply(get_lng, axis=1)

        unique = df1.groupby('Hexagon_ID', as_index=False)['r'].nunique().sort_values('r',ascending=False)
        unique = unique.rename(columns={"r": "r_count"})

        df2 = df2.merge(unique, on='Hexagon_ID', how='left').sort_values(["r_count", "Hexagon_ID"], ascending=[False,True])
        df2 = df2[['Hexagon_ID', 'r_count',	'r', 'good_count','bad_count','alt_baro_range','time_range','total_count','percentage_bad']]
        df2 = df2.groupby('Hexagon_ID')[['r_count','r', 'good_count','bad_count','alt_baro_range','time_range','total_count','percentage_bad']]
        df2.to_csv(hexbin_path)
    
    else:
        df2 = read_csv(hexbin_path)

    return [df1, df2]


def get_directory_size(directory):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(directory):
        for filename in filenames:
            filepath = os.path.join(dirpath, filename)
            total_size += os.path.getsize(filepath)
            total_size_mb = total_size / (1024 * 1024)
    return total_size_mb

def get_memory_usage():

    # Get the memory usage
    memory_usage = psutil.virtual_memory()

    # Print the memory usage
    report = f"""
        Total Memory: {memory_usage.total / (1024 ** 3):.2f} GB
        Available Memory: {memory_usage.available / (1024 ** 3):.2f} GB
        Used Memory: {memory_usage.used / (1024 ** 3):.2f} GB
        Memory Usage Percentage: {memory_usage.percent:.2f}%
    """
    return report

# note that for the free sample, only the first day of each month is available on the adsbexchange
# 4 hours + to download 1 day of files
# 18 mins to reload

[df1,df2] = load_data(dt.datetime(2024,6,1,0,0,0),dt.datetime(2024,6,2,0,0,0), reload=[False, False])
# Out:
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000050Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000035Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000010Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000025Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000000Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000045Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000115Z.json.gz
# Remaining execution time: 568m 9s
# Remaining execution time: 1042m 30s
# Remaining execution time: 457m 31s
# Remaining execution time: 564m 17s
# Remaining execution time: 991m 12s
# Remaining execution time: 2724m 3s
# Remaining execution time: 743m 12s
# Remaining execution time: 629m 15s
# Remaining execution time: 456m 48s
# Remaining execution time: 8252m 27s
# Remaining execution time: 434m 9s
# Remaining execution time: 688m 31s
# Remaining execution time: 1378m 45s
# Remaining execution time: 2069m 12s
# Remaining execution time: 1182m 49s
# Remaining execution time: 413m 52s
# Remaining execution time: 552m 9s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000145Z.json.gz
# Remaining execution time: 4157m 44s
# Remaining execution time: 522m 4s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000140Z.json.gz
# Remaining execution time: 836m 26s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000305Z.json.gz
# Remaining execution time: 531m 10s
# Remaining execution time: 583m 42s
# Remaining execution time: 575m 9s
# Remaining execution time: 654m 14s
# Remaining execution time: 537m 35s
# Remaining execution time: 637m 11s
# Remaining execution time: 437m 17s
# Remaining execution time: 416m 28s
# Remaining execution time: 595m 25s
# Remaining execution time: 431m 32s
# Remaining execution time: 538m 48s
# Remaining execution time: 507m 18s
# Remaining execution time: 525m 52s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000320Z.json.gz
# Remaining execution time: 606m 0s
# Remaining execution time: 497m 34s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000330Z.json.gz
# Remaining execution time: 424m 7s
# Remaining execution time: 436m 6s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000355Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000335Z.json.gz
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000350Z.json.gz
# Remaining execution time: 507m 24s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000420Z.json.gz
# Remaining execution time: 541m 22s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000405Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000415Z.json.gz
# Remaining execution time: 467m 14s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000435Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000450Z.json.gz
# Remaining execution time: 465m 48s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000455Z.json.gz
# Remaining execution time: 513m 15s
# Remaining execution time: 528m 48s
# Remaining execution time: 508m 21s
# Remaining execution time: 533m 8sRemaining execution time: 488m 38s
#
# Remaining execution time: 442m 60s
# Remaining execution time: 499m 59s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000500Z.json.gz
# Remaining execution time: 461m 37s
# Remaining execution time: 452m 55s
# Remaining execution time: 482m 4s
# Remaining execution time: 526m 3s
# Remaining execution time: 475m 36s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000505Z.json.gz
# Remaining execution time: 443m 23s
# Remaining execution time: 459m 56s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000510Z.json.gz
# Remaining execution time: 452m 56s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000525Z.json.gz
# Remaining execution time: 446m 22s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000600Z.json.gz
# Remaining execution time: 436m 19s
# Remaining execution time: 446m 60s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000550Z.json.gz
# Remaining execution time: 440m 39s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000620Z.json.gz
# Remaining execution time: 453m 59s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000625Z.json.gz
# Remaining execution time: 466m 8s
# Remaining execution time: 473m 32s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000635Z.json.gz
# Remaining execution time: 489m 31s
# Remaining execution time: 484m 42s
# Remaining execution time: 480m 3s
# Remaining execution time: 466m 50s
# Remaining execution time: 432m 20s
# Remaining execution time: 478m 5s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000640Z.json.gz
# Remaining execution time: 466m 13s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000645Z.json.gz
# Remaining execution time: 462m 44s
# Remaining execution time: 445m 7s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000650Z.json.gz
# Remaining execution time: 452m 51s
# Remaining execution time: 459m 22s
# Remaining execution time: 435m 3s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000700Z.json.gz
# Remaining execution time: 428m 48s
# Remaining execution time: 438m 44s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000720Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000730Z.json.gz
# Remaining execution time: 438m 59s
# Remaining execution time: 445m 50s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000755Z.json.gz
# Remaining execution time: 444m 1s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000800Z.json.gz
# Remaining execution time: 445m 58s
# Remaining execution time: 456m 27s
# Remaining execution time: 454m 27s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000815Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000805Z.json.gz
#
# Remaining execution time: 452m 42s
# Remaining execution time: 442m 38s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000810Z.json.gz
# Remaining execution time: 442m 59s
# Remaining execution time: 453m 40s
# Remaining execution time: 439m 43s
# Remaining execution time: 466m 21s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000820Z.json.gz
# Remaining execution time: 448m 6s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000825Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000835Z.json.gz
# Remaining execution time: 444m 55s
# Remaining execution time: 449m 53s
# Remaining execution time: 427m 19s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000845Z.json.gzRemaining execution time: 423m 42s
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000855Z.json.gz
# Remaining execution time: 435m 2s
# Remaining execution time: 439m 51s
# Remaining execution time: 446m 36s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000925Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000920Z.json.gz
# Remaining execution time: 434m 58s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000910Z.json.gz
# Remaining execution time: 451m 22s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000930Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000935Z.json.gzRemaining execution time: 441m 26s
#
# Remaining execution time: 451m 60s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000915Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000940Z.json.gz
# Remaining execution time: 444m 6s
# Remaining execution time: 447m 21s
# Remaining execution time: 439m 37s
# Remaining execution time: 444m 30s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000945Z.json.gz
# Remaining execution time: 436m 15s
# Remaining execution time: 432m 14s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000950Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/000955Z.json.gz
# Remaining execution time: 441m 3s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001000Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001005Z.json.gz
# Remaining execution time: 440m 39s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001010Z.json.gz
# Remaining execution time: 436m 55s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001015Z.json.gz
# Remaining execution time: 431m 25s
# Remaining execution time: 436m 40s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001025Z.json.gz
# Remaining execution time: 444m 48s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001035Z.json.gz
# Remaining execution time: 433m 45s
# Remaining execution time: 438m 15s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001040Z.json.gz
# Remaining execution time: 436m 45s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001045Z.json.gz
# Remaining execution time: 459m 29s
# Remaining execution time: 440m 49s
# Remaining execution time: 434m 12s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001050Z.json.gz
# Remaining execution time: 444m 35s
# Remaining execution time: 437m 56s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001115Z.json.gz
# Remaining execution time: 443m 35s
# Remaining execution time: 433m 52s
# Remaining execution time: 437m 25s
# Remaining execution time: 441m 3s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001120Z.json.gz
# Remaining execution time: 431m 4s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001135Z.json.gz
# Remaining execution time: 437m 55s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001140Z.json.gz
# Remaining execution time: 431m 28s
# Remaining execution time: 434m 49s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001145Z.json.gz
# Remaining execution time: 434m 16s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001205Z.json.gz
# Remaining execution time: 435m 44sRemaining execution time: 439m 5s
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001210Z.json.gz
# Remaining execution time: 443m 17s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001225Z.json.gz
# Remaining execution time: 439m 2s
# Remaining execution time: 442m 28s
# Remaining execution time: 436m 20s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001220Z.json.gz
# Remaining execution time: 430m 42s
# Remaining execution time: 434m 55s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001230Z.json.gz
# Remaining execution time: 443m 47s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001240Z.json.gz
# Remaining execution time: 438m 36s
# Remaining execution time: 437m 1s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001255Z.json.gz
# Remaining execution time: 438m 1s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001245Z.json.gz
# Remaining execution time: 433m 48s
# Remaining execution time: 440m 36s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001305Z.json.gz
# Remaining execution time: 440m 26s
# Remaining execution time: 435m 52s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001310Z.json.gz
# Remaining execution time: 434m 39s
# Remaining execution time: 432m 42s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001315Z.json.gz
# Remaining execution time: 429m 27s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001320Z.json.gz
# Remaining execution time: 435m 54s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001345Z.json.gz
# Remaining execution time: 434m 37s
# Remaining execution time: 435m 52s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001355Z.json.gz
# Remaining execution time: 437m 37s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001405Z.json.gz
# Remaining execution time: 433m 54s
# Remaining execution time: 436m 58s
# Remaining execution time: 440m 2s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001410Z.json.gzRemaining execution time: 432m 29s
#
# Remaining execution time: 431m 27s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001420Z.json.gz
# Remaining execution time: 441m 37s
# Remaining execution time: 440m 28s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001435Z.json.gz
# Remaining execution time: 438m 53s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001425Z.json.gz
# Remaining execution time: 437m 45s
# Remaining execution time: 443m 52s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001430Z.json.gz
# Remaining execution time: 437m 50s
# Remaining execution time: 433m 39s
# Remaining execution time: 429m 41s
# Remaining execution time: 437m 42s
# Remaining execution time: 434m 25s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001450Z.json.gz
# Remaining execution time: 431m 25s
# Remaining execution time: 428m 60s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001505Z.json.gz
# Remaining execution time: 429m 4s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001515Z.json.gz
# Remaining execution time: 429m 39s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001535Z.json.gz
# Remaining execution time: 434m 44s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001545Z.json.gzRemaining execution time: 430m 16s
#
# Remaining execution time: 428m 37s
# Remaining execution time: 426m 35s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001550Z.json.gz
# Remaining execution time: 438m 40s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001555Z.json.gz
# Remaining execution time: 441m 56s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001600Z.json.gz
# Remaining execution time: 437m 14s
# Remaining execution time: 442m 15s
# Remaining execution time: 434m 55s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001610Z.json.gz
# Remaining execution time: 442m 49s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001620Z.json.gz
# Remaining execution time: 432m 7s
# Remaining execution time: 430m 14s
# Remaining execution time: 437m 52sRemaining execution time: 435m 29s
#
# Remaining execution time: 426m 41s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001625Z.json.gz
# Remaining execution time: 429m 13s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001630Z.json.gz
# Remaining execution time: 428m 20s
# Remaining execution time: 426m 41s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001640Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001645Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001650Z.json.gz
# Remaining execution time: 428m 41s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001700Z.json.gz
# Remaining execution time: 430m 54s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001720Z.json.gz
# Remaining execution time: 433m 2s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001725Z.json.gz
# Remaining execution time: 430m 34s
# Remaining execution time: 433m 5s
# Remaining execution time: 429m 53s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001730Z.json.gz
# Remaining execution time: 431m 7s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001735Z.json.gz
# Remaining execution time: 432m 30s
# Remaining execution time: 434m 36s
# Remaining execution time: 431m 51s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001755Z.json.gz
# Remaining execution time: 440m 30s
# Remaining execution time: 437m 24s
# Remaining execution time: 435m 32s
# Remaining execution time: 427m 3s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001800Z.json.gz
# Remaining execution time: 425m 19s
# Remaining execution time: 432m 2s
# Remaining execution time: 434m 13s
# Remaining execution time: 424m 28s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001815Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001810Z.json.gz
# Remaining execution time: 431m 31s
# Remaining execution time: 424m 8s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001820Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001825Z.json.gz
# Remaining execution time: 427m 2s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001845Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001855Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001805Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001850Z.json.gz
# Remaining execution time: 431m 11s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001900Z.json.gz
# Remaining execution time: 430m 53s
# Remaining execution time: 427m 16s
# Remaining execution time: 429m 49s
# Remaining execution time: 431m 54s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001910Z.json.gz
# Remaining execution time: 429m 13s
# Remaining execution time: 424m 41s
# Remaining execution time: 428m 23s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001920Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001915Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001925Z.json.gz
# Remaining execution time: 429m 0s
# Remaining execution time: 436m 16s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001935Z.json.gz
# Remaining execution time: 429m 5s
# Remaining execution time: 435m 0s
# Remaining execution time: 427m 13s
# Remaining execution time: 433m 8s
# Remaining execution time: 424m 3s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001940Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001945Z.json.gz
# Remaining execution time: 427m 6s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001950Z.json.gz
# Remaining execution time: 422m 32s
# Remaining execution time: 446m 10s
# Remaining execution time: 424m 38s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001955Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002000Z.json.gzRemaining execution time: 423m 15s
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002025Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002010Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002040Z.json.gz
# Remaining execution time: 426m 26s
# Remaining execution time: 429m 18s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002035Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002045Z.json.gz
# Remaining execution time: 427m 51s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002050Z.json.gz
# Remaining execution time: 426m 26s
# Remaining execution time: 425m 41s
# Remaining execution time: 424m 11s
# Remaining execution time: 430m 10s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002105Z.json.gz
# Remaining execution time: 429m 22s
# Remaining execution time: 425m 59s
# Remaining execution time: 420m 56s
# Remaining execution time: 422m 43s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/001930Z.json.gz
# Remaining execution time: 430m 57s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002115Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002120Z.json.gz
#
# Remaining execution time: 424m 51s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002125Z.json.gz
# Remaining execution time: 430m 32s
# Remaining execution time: 425m 22s
# Remaining execution time: 421m 57s
# Remaining execution time: 420m 15s
# Remaining execution time: 423m 43s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002140Z.json.gz
# Remaining execution time: 423m 13s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002155Z.json.gz
# Remaining execution time: 425m 39s
# Remaining execution time: 424m 21s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002200Z.json.gz
# Remaining execution time: 424m 44s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002205Z.json.gz
# Remaining execution time: 462m 50s
# Remaining execution time: 427m 21s
# Remaining execution time: 425m 56s
# Remaining execution time: 425m 12s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002225Z.json.gz
# Remaining execution time: 426m 28sdownloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002230Z.json.gz
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002240Z.json.gz
# Remaining execution time: 427m 42s
# Remaining execution time: 426m 14s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002235Z.json.gz
# Remaining execution time: 425m 15s
# Remaining execution time: 427m 13s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002300Z.json.gz
# Remaining execution time: 426m 39s
# Remaining execution time: 428m 35s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002305Z.json.gz
# Remaining execution time: 425m 54s
# Remaining execution time: 421m 21s
# Remaining execution time: 424m 36s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002315Z.json.gz
# Remaining execution time: 420m 24s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002310Z.json.gz
# Remaining execution time: 425m 22s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002320Z.json.gz
# Remaining execution time: 425m 60s
# Remaining execution time: 425m 11s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002340Z.json.gz
# Remaining execution time: 425m 4s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002400Z.json.gz
# Remaining execution time: 428m 32s
# Remaining execution time: 425m 6s
# Remaining execution time: 423m 37s
# Remaining execution time: 426m 57s
# Remaining execution time: 424m 42s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002405Z.json.gz
# Remaining execution time: 424m 46s
# Remaining execution time: 422m 34s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002415Z.json.gz
# Remaining execution time: 424m 55s
# Remaining execution time: 421m 21s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002420Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002435Z.json.gzRemaining execution time: 428m 11s
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002440Z.json.gz
# Remaining execution time: 421m 31s
# Remaining execution time: 420m 2s
# Remaining execution time: 426m 6s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002450Z.json.gz
# Remaining execution time: 427m 58s
# Remaining execution time: 424m 58s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002445Z.json.gz
# Remaining execution time: 424m 48s
# Remaining execution time: 420m 36s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002505Z.json.gz
# Remaining execution time: 422m 31s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002520Z.json.gz
# Remaining execution time: 427m 36s
# Remaining execution time: 426m 13s
# Remaining execution time: 424m 45s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002540Z.json.gzRemaining execution time: 424m 2s
#
# Remaining execution time: 421m 56s
# Remaining execution time: 424m 41s
# Remaining execution time: 422m 36s
# Remaining execution time: 421m 26s
# Remaining execution time: 423m 19sdownloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002545Z.json.gz
#
# Remaining execution time: 421m 52s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002610Z.json.gz
# Remaining execution time: 424m 56s
# Remaining execution time: 423m 55s
# Remaining execution time: 422m 59s
# Remaining execution time: 427m 31s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002625Z.json.gz
# Remaining execution time: 421m 38s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002620Z.json.gz
# Remaining execution time: 423m 19s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002630Z.json.gz
# Remaining execution time: 421m 44s
# Remaining execution time: 421m 37s
# Remaining execution time: 421m 50s
# Remaining execution time: 424m 30s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002640Z.json.gz
# Remaining execution time: 423m 23s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002650Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002700Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002645Z.json.gz
# Remaining execution time: 420m 35s
# Remaining execution time: 423m 54s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002705Z.json.gz
# Remaining execution time: 418m 38s
# Remaining execution time: 424m 7s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002715Z.json.gz
# Remaining execution time: 422m 46s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002720Z.json.gz
# Remaining execution time: 420m 4s
# Remaining execution time: 421m 31s
# Remaining execution time: 418m 15s
# Remaining execution time: 420m 35s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002730Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002755Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002750Z.json.gz
# Remaining execution time: 422m 49s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002805Z.json.gz
# Remaining execution time: 422m 46s
# Remaining execution time: 424m 9s
# Remaining execution time: 421m 40s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002800Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002810Z.json.gz
# Remaining execution time: 421m 60s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002815Z.json.gz
# Remaining execution time: 421m 34s
# Remaining execution time: 419m 52s
# Remaining execution time: 421m 42s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002830Z.json.gzRemaining execution time: 422m 24s
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002820Z.json.gz
# Remaining execution time: 419m 10s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002825Z.json.gz
# Remaining execution time: 423m 1s
# Remaining execution time: 424m 22s
# Remaining execution time: 425m 56s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002840Z.json.gz
# Remaining execution time: 422m 48s
# Remaining execution time: 416m 42s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002845Z.json.gz
# Remaining execution time: 419m 51s
# Remaining execution time: 421m 8s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002855Z.json.gz
# Remaining execution time: 419m 34s
# Remaining execution time: 417m 56s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002910Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002920Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002925Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002915Z.json.gz
# Remaining execution time: 421m 2s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002930Z.json.gz
# Remaining execution time: 418m 11s
# Remaining execution time: 421m 1s
# Remaining execution time: 417m 51s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002935Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002940Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002945Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002950Z.json.gz
# Remaining execution time: 422m 47s
# Remaining execution time: 419m 58s
# Remaining execution time: 420m 8s
# Remaining execution time: 422m 4s
# Remaining execution time: 421m 16s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003010Z.json.gz
# Remaining execution time: 420m 27s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003000Z.json.gz
# Remaining execution time: 419m 57s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/002955Z.json.gz
# Remaining execution time: 417m 55s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003020Z.json.gz
# Remaining execution time: 420m 55s
# Remaining execution time: 418m 53s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003025Z.json.gz
# Remaining execution time: 426m 5s
# Remaining execution time: 419m 24s
# Remaining execution time: 418m 14s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003035Z.json.gz
# Remaining execution time: 417m 36s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003045Z.json.gz
# Remaining execution time: 416m 30s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003050Z.json.gz
# Remaining execution time: 416m 7s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003100Z.json.gz
# Remaining execution time: 419m 18sRemaining execution time: 418m 7s
#
# Remaining execution time: 417m 0s
# Remaining execution time: 422m 14s
# Remaining execution time: 421m 4s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003115Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003130Z.json.gz
# Remaining execution time: 418m 26s
# Remaining execution time: 419m 41s
# Remaining execution time: 417m 40s
# Remaining execution time: 416m 10s
# Remaining execution time: 419m 44s
# Remaining execution time: 417m 26s
# Remaining execution time: 415m 15s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003200Z.json.gz
# Remaining execution time: 421m 49s
# Remaining execution time: 414m 54s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003220Z.json.gz
# Remaining execution time: 417m 28s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003225Z.json.gz
# Remaining execution time: 414m 45s
# Remaining execution time: 417m 6s
# Remaining execution time: 416m 9s
# Remaining execution time: 420m 43s
# Remaining execution time: 419m 36s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003310Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003245Z.json.gz
#
# Remaining execution time: 413m 55s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003305Z.json.gz
# Remaining execution time: 418m 49s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003300Z.json.gz
# Remaining execution time: 419m 20s
# Remaining execution time: 421m 14s
# Remaining execution time: 424m 41s
# Remaining execution time: 417m 58s
# Remaining execution time: 413m 39s
# Remaining execution time: 416m 57s
# Remaining execution time: 416m 1s
# Remaining execution time: 418m 16s
# Remaining execution time: 415m 2s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003320Z.json.gz
# Remaining execution time: 413m 13s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003335Z.json.gz
# Remaining execution time: 417m 12s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003405Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003350Z.json.gz
# Remaining execution time: 413m 14s
# Remaining execution time: 417m 32s
# Remaining execution time: 418m 39s
# Remaining execution time: 416m 32s
# Remaining execution time: 433m 26s
# Remaining execution time: 415m 57s
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/06/01/003410Z.json.gz
# ...
# Joined csv\20240601\233420Z.csv
# 2024-06-01 23:34:25
# Joined csv\20240601\233425Z.csv
# 2024-06-01 23:34:30
# Joined csv\20240601\233430Z.csv
# 2024-06-01 23:34:35
# Joined csv\20240601\233435Z.csv
# 2024-06-01 23:34:40
# Joined csv\20240601\233440Z.csv
# 2024-06-01 23:34:45
# Joined csv\20240601\233445Z.csv
# 2024-06-01 23:34:50
# Joined csv\20240601\233450Z.csv
# 2024-06-01 23:34:55
# Joined csv\20240601\233455Z.csv
# 2024-06-01 23:35:00
# Joined csv\20240601\233500Z.csv
# 2024-06-01 23:35:05
# Joined csv\20240601\233505Z.csv
# 2024-06-01 23:35:10
# Joined csv\20240601\233510Z.csv
# 2024-06-01 23:35:15
# Joined csv\20240601\233515Z.csv
# 2024-06-01 23:35:20
# Joined csv\20240601\233520Z.csv
# 2024-06-01 23:35:25
# Joined csv\20240601\233525Z.csv
# 2024-06-01 23:35:30
# Joined csv\20240601\233530Z.csv
# 2024-06-01 23:35:35
# Joined csv\20240601\233535Z.csv
# 2024-06-01 23:35:40
# Joined csv\20240601\233540Z.csv
# 2024-06-01 23:35:45
# Joined csv\20240601\233545Z.csv
# 2024-06-01 23:35:50
# Joined csv\20240601\233550Z.csv
# 2024-06-01 23:35:55
# Joined csv\20240601\233555Z.csv
# 2024-06-01 23:36:00
# Joined csv\20240601\233600Z.csv
# 2024-06-01 23:36:05
# Joined csv\20240601\233605Z.csv
# 2024-06-01 23:36:10
# Joined csv\20240601\233610Z.csv
# 2024-06-01 23:36:15
# Joined csv\20240601\233615Z.csv
# 2024-06-01 23:36:20
# Joined csv\20240601\233620Z.csv
# 2024-06-01 23:36:25
# Joined csv\20240601\233625Z.csv
# 2024-06-01 23:36:30
# Joined csv\20240601\233630Z.csv
# 2024-06-01 23:36:35
# Joined csv\20240601\233635Z.csv
# 2024-06-01 23:36:40
# Joined csv\20240601\233640Z.csv
# 2024-06-01 23:36:45
# Joined csv\20240601\233645Z.csv
# 2024-06-01 23:36:50
# Joined csv\20240601\233650Z.csv
# 2024-06-01 23:36:55
# Joined csv\20240601\233655Z.csv
# 2024-06-01 23:37:00
# Joined csv\20240601\233700Z.csv
# 2024-06-01 23:37:05
# Joined csv\20240601\233705Z.csv
# 2024-06-01 23:37:10
# Joined csv\20240601\233710Z.csv
# 2024-06-01 23:37:15
# Joined csv\20240601\233715Z.csv
# 2024-06-01 23:37:20
# Joined csv\20240601\233720Z.csv
# 2024-06-01 23:37:25
# Joined csv\20240601\233725Z.csv
# 2024-06-01 23:37:30
# Joined csv\20240601\233730Z.csv
# 2024-06-01 23:37:35
# Joined csv\20240601\233735Z.csv
# 2024-06-01 23:37:40
# Joined csv\20240601\233740Z.csv
# 2024-06-01 23:37:45
# Joined csv\20240601\233745Z.csv
# 2024-06-01 23:37:50
# Joined csv\20240601\233750Z.csv
# 2024-06-01 23:37:55
# Joined csv\20240601\233755Z.csv
# 2024-06-01 23:38:00
# Joined csv\20240601\233800Z.csv
# 2024-06-01 23:38:05
# Joined csv\20240601\233805Z.csv
# 2024-06-01 23:38:10
# Joined csv\20240601\233810Z.csv
# 2024-06-01 23:38:15
# Joined csv\20240601\233815Z.csv
# 2024-06-01 23:38:20
# Joined csv\20240601\233820Z.csv
# 2024-06-01 23:38:25
# Joined csv\20240601\233825Z.csv
# 2024-06-01 23:38:30
# Joined csv\20240601\233830Z.csv
# 2024-06-01 23:38:35
# Joined csv\20240601\233835Z.csv
# 2024-06-01 23:38:40
# Joined csv\20240601\233840Z.csv
# 2024-06-01 23:38:45
# Joined csv\20240601\233845Z.csv
# 2024-06-01 23:38:50
# Joined csv\20240601\233850Z.csv
# 2024-06-01 23:38:55
# Joined csv\20240601\233855Z.csv
# 2024-06-01 23:39:00
# Joined csv\20240601\233900Z.csv
# 2024-06-01 23:39:05
# Joined csv\20240601\233905Z.csv
# 2024-06-01 23:39:10
# Joined csv\20240601\233910Z.csv
# 2024-06-01 23:39:15
# Joined csv\20240601\233915Z.csv
# 2024-06-01 23:39:20
# Joined csv\20240601\233920Z.csv
# 2024-06-01 23:39:25
# Joined csv\20240601\233925Z.csv
# 2024-06-01 23:39:30
# Joined csv\20240601\233930Z.csv
# 2024-06-01 23:39:35
# Joined csv\20240601\233935Z.csv
# 2024-06-01 23:39:40
# Joined csv\20240601\233940Z.csv
# 2024-06-01 23:39:45
# Joined csv\20240601\233945Z.csv
# 2024-06-01 23:39:50
# Joined csv\20240601\233950Z.csv
# 2024-06-01 23:39:55
# Joined csv\20240601\233955Z.csv
# 2024-06-01 23:40:00
# Joined csv\20240601\234000Z.csv
# 2024-06-01 23:40:05
# Joined csv\20240601\234005Z.csv
# 2024-06-01 23:40:10
# Joined csv\20240601\234010Z.csv
# 2024-06-01 23:40:15
# Joined csv\20240601\234015Z.csv
# 2024-06-01 23:40:20
# Joined csv\20240601\234020Z.csv
# 2024-06-01 23:40:25
# Joined csv\20240601\234025Z.csv
# 2024-06-01 23:40:30
# Joined csv\20240601\234030Z.csv
# 2024-06-01 23:40:35
# Joined csv\20240601\234035Z.csv
# 2024-06-01 23:40:40
# Joined csv\20240601\234040Z.csv
# 2024-06-01 23:40:45
# Joined csv\20240601\234045Z.csv
# 2024-06-01 23:40:50
# Joined csv\20240601\234050Z.csv
# 2024-06-01 23:40:55
# Joined csv\20240601\234055Z.csv
# 2024-06-01 23:41:00
# Joined csv\20240601\234100Z.csv
# 2024-06-01 23:41:05
# Joined csv\20240601\234105Z.csv
# 2024-06-01 23:41:10
# Joined csv\20240601\234110Z.csv
# 2024-06-01 23:41:15
# Joined csv\20240601\234115Z.csv
# 2024-06-01 23:41:20
# Joined csv\20240601\234120Z.csv
# 2024-06-01 23:41:25
# Joined csv\20240601\234125Z.csv
# 2024-06-01 23:41:30
# Joined csv\20240601\234130Z.csv
# 2024-06-01 23:41:35
# Joined csv\20240601\234135Z.csv
# 2024-06-01 23:41:40
# Joined csv\20240601\234140Z.csv
# 2024-06-01 23:41:45
# Joined csv\20240601\234145Z.csv
# 2024-06-01 23:41:50
# Joined csv\20240601\234150Z.csv
# 2024-06-01 23:41:55
# Joined csv\20240601\234155Z.csv
# 2024-06-01 23:42:00
# Joined csv\20240601\234200Z.csv
# 2024-06-01 23:42:05
# Joined csv\20240601\234205Z.csv
# 2024-06-01 23:42:10
# Joined csv\20240601\234210Z.csv
# 2024-06-01 23:42:15
# Joined csv\20240601\234215Z.csv
# 2024-06-01 23:42:20
# Joined csv\20240601\234220Z.csv
# 2024-06-01 23:42:25
# Joined csv\20240601\234225Z.csv
# 2024-06-01 23:42:30
# Joined csv\20240601\234230Z.csv
# 2024-06-01 23:42:35
# Joined csv\20240601\234235Z.csv
# 2024-06-01 23:42:40
# Joined csv\20240601\234240Z.csv
# 2024-06-01 23:42:45
# Joined csv\20240601\234245Z.csv
# 2024-06-01 23:42:50
# Joined csv\20240601\234250Z.csv
# 2024-06-01 23:42:55
# Joined csv\20240601\234255Z.csv
# 2024-06-01 23:43:00
# Joined csv\20240601\234300Z.csv
# 2024-06-01 23:43:05
# Joined csv\20240601\234305Z.csv
# 2024-06-01 23:43:10
# Joined csv\20240601\234310Z.csv
# 2024-06-01 23:43:15
# Joined csv\20240601\234315Z.csv
# 2024-06-01 23:43:20
# Joined csv\20240601\234320Z.csv
# 2024-06-01 23:43:25
# Joined csv\20240601\234325Z.csv
# 2024-06-01 23:43:30
# Joined csv\20240601\234330Z.csv
# 2024-06-01 23:43:35
# Joined csv\20240601\234335Z.csv
# 2024-06-01 23:43:40
# Joined csv\20240601\234340Z.csv
# 2024-06-01 23:43:45
# Joined csv\20240601\234345Z.csv
# 2024-06-01 23:43:50
# Joined csv\20240601\234350Z.csv
# 2024-06-01 23:43:55
# Joined csv\20240601\234355Z.csv
# 2024-06-01 23:44:00
# Joined csv\20240601\234400Z.csv
# 2024-06-01 23:44:05
# Joined csv\20240601\234405Z.csv
# 2024-06-01 23:44:10
# Joined csv\20240601\234410Z.csv
# 2024-06-01 23:44:15
# Joined csv\20240601\234415Z.csv
# 2024-06-01 23:44:20
# Joined csv\20240601\234420Z.csv
# 2024-06-01 23:44:25
# Joined csv\20240601\234425Z.csv
# 2024-06-01 23:44:30
# Joined csv\20240601\234430Z.csv
# 2024-06-01 23:44:35
# Joined csv\20240601\234435Z.csv
# 2024-06-01 23:44:40
# Joined csv\20240601\234440Z.csv
# 2024-06-01 23:44:45
# Joined csv\20240601\234445Z.csv
# 2024-06-01 23:44:50
# Joined csv\20240601\234450Z.csv
# 2024-06-01 23:44:55
# Joined csv\20240601\234455Z.csv
# 2024-06-01 23:45:00
# Joined csv\20240601\234500Z.csv
# 2024-06-01 23:45:05
# Joined csv\20240601\234505Z.csv
# 2024-06-01 23:45:10
# Joined csv\20240601\234510Z.csv
# 2024-06-01 23:45:15
# Joined csv\20240601\234515Z.csv
# 2024-06-01 23:45:20
# Joined csv\20240601\234520Z.csv
# 2024-06-01 23:45:25
# Joined csv\20240601\234525Z.csv
# 2024-06-01 23:45:30
# Joined csv\20240601\234530Z.csv
# 2024-06-01 23:45:35
# Joined csv\20240601\234535Z.csv
# 2024-06-01 23:45:40
# Joined csv\20240601\234540Z.csv
# 2024-06-01 23:45:45
# Joined csv\20240601\234545Z.csv
# 2024-06-01 23:45:50
# Joined csv\20240601\234550Z.csv
# 2024-06-01 23:45:55
# Joined csv\20240601\234555Z.csv
# 2024-06-01 23:46:00
# Joined csv\20240601\234600Z.csv
# 2024-06-01 23:46:05
# Joined csv\20240601\234605Z.csv
# 2024-06-01 23:46:10
# Joined csv\20240601\234610Z.csv
# 2024-06-01 23:46:15
# Joined csv\20240601\234615Z.csv
# 2024-06-01 23:46:20
# Joined csv\20240601\234620Z.csv
# 2024-06-01 23:46:25
# Joined csv\20240601\234625Z.csv
# 2024-06-01 23:46:30
# Joined csv\20240601\234630Z.csv
# 2024-06-01 23:46:35
# Joined csv\20240601\234635Z.csv
# 2024-06-01 23:46:40
# Joined csv\20240601\234640Z.csv
# 2024-06-01 23:46:45
# Joined csv\20240601\234645Z.csv
# 2024-06-01 23:46:50
# Joined csv\20240601\234650Z.csv
# 2024-06-01 23:46:55
# Joined csv\20240601\234655Z.csv
# 2024-06-01 23:47:00
# Joined csv\20240601\234700Z.csv
# 2024-06-01 23:47:05
# Joined csv\20240601\234705Z.csv
# 2024-06-01 23:47:10
# Joined csv\20240601\234710Z.csv
# 2024-06-01 23:47:15
# Joined csv\20240601\234715Z.csv
# 2024-06-01 23:47:20
# Joined csv\20240601\234720Z.csv
# 2024-06-01 23:47:25
# Joined csv\20240601\234725Z.csv
# 2024-06-01 23:47:30
# Joined csv\20240601\234730Z.csv
# 2024-06-01 23:47:35
# Joined csv\20240601\234735Z.csv
# 2024-06-01 23:47:40
# Joined csv\20240601\234740Z.csv
# 2024-06-01 23:47:45
# Joined csv\20240601\234745Z.csv
# 2024-06-01 23:47:50
# Joined csv\20240601\234750Z.csv
# 2024-06-01 23:47:55
# Joined csv\20240601\234755Z.csv
# 2024-06-01 23:48:00
# Joined csv\20240601\234800Z.csv
# 2024-06-01 23:48:05
# Joined csv\20240601\234805Z.csv
# 2024-06-01 23:48:10
# Joined csv\20240601\234810Z.csv
# 2024-06-01 23:48:15
# Joined csv\20240601\234815Z.csv
# 2024-06-01 23:48:20
# Joined csv\20240601\234820Z.csv
# 2024-06-01 23:48:25
# Joined csv\20240601\234825Z.csv
# 2024-06-01 23:48:30
# Joined csv\20240601\234830Z.csv
# 2024-06-01 23:48:35
# Joined csv\20240601\234835Z.csv
# 2024-06-01 23:48:40
# Joined csv\20240601\234840Z.csv
# 2024-06-01 23:48:45
# Joined csv\20240601\234845Z.csv
# 2024-06-01 23:48:50
# Joined csv\20240601\234850Z.csv
# 2024-06-01 23:48:55
# Joined csv\20240601\234855Z.csv
# 2024-06-01 23:49:00
# Joined csv\20240601\234900Z.csv
# 2024-06-01 23:49:05
# Joined csv\20240601\234905Z.csv
# 2024-06-01 23:49:10
# Joined csv\20240601\234910Z.csv
# 2024-06-01 23:49:15
# Joined csv\20240601\234915Z.csv
# 2024-06-01 23:49:20
# Joined csv\20240601\234920Z.csv
# 2024-06-01 23:49:25
# Joined csv\20240601\234925Z.csv
# 2024-06-01 23:49:30
# Joined csv\20240601\234930Z.csv
# 2024-06-01 23:49:35
# Joined csv\20240601\234935Z.csv
# 2024-06-01 23:49:40
# Joined csv\20240601\234940Z.csv
# 2024-06-01 23:49:45
# Joined csv\20240601\234945Z.csv
# 2024-06-01 23:49:50
# Joined csv\20240601\234950Z.csv
# 2024-06-01 23:49:55
# Joined csv\20240601\234955Z.csv
# 2024-06-01 23:50:00
# Joined csv\20240601\235000Z.csv
# 2024-06-01 23:50:05
# Joined csv\20240601\235005Z.csv
# 2024-06-01 23:50:10
# Joined csv\20240601\235010Z.csv
# 2024-06-01 23:50:15
# Joined csv\20240601\235015Z.csv
# 2024-06-01 23:50:20
# Joined csv\20240601\235020Z.csv
# 2024-06-01 23:50:25
# Joined csv\20240601\235025Z.csv
# 2024-06-01 23:50:30
# Joined csv\20240601\235030Z.csv
# 2024-06-01 23:50:35
# Joined csv\20240601\235035Z.csv
# 2024-06-01 23:50:40
# Joined csv\20240601\235040Z.csv
# 2024-06-01 23:50:45
# Joined csv\20240601\235045Z.csv
# 2024-06-01 23:50:50
# Joined csv\20240601\235050Z.csv
# 2024-06-01 23:50:55
# Joined csv\20240601\235055Z.csv
# 2024-06-01 23:51:00
# Joined csv\20240601\235100Z.csv
# 2024-06-01 23:51:05
# Joined csv\20240601\235105Z.csv
# 2024-06-01 23:51:10
# Joined csv\20240601\235110Z.csv
# 2024-06-01 23:51:15
# Joined csv\20240601\235115Z.csv
# 2024-06-01 23:51:20
# Joined csv\20240601\235120Z.csv
# 2024-06-01 23:51:25
# Joined csv\20240601\235125Z.csv
# 2024-06-01 23:51:30
# Joined csv\20240601\235130Z.csv
# 2024-06-01 23:51:35
# Joined csv\20240601\235135Z.csv
# 2024-06-01 23:51:40
# Joined csv\20240601\235140Z.csv
# 2024-06-01 23:51:45
# Joined csv\20240601\235145Z.csv
# 2024-06-01 23:51:50
# Joined csv\20240601\235150Z.csv
# 2024-06-01 23:51:55
# Joined csv\20240601\235155Z.csv
# 2024-06-01 23:52:00
# Joined csv\20240601\235200Z.csv
# 2024-06-01 23:52:05
# Joined csv\20240601\235205Z.csv
# 2024-06-01 23:52:10
# Joined csv\20240601\235210Z.csv
# 2024-06-01 23:52:15
# Joined csv\20240601\235215Z.csv
# 2024-06-01 23:52:20
# Joined csv\20240601\235220Z.csv
# 2024-06-01 23:52:25
# Joined csv\20240601\235225Z.csv
# 2024-06-01 23:52:30
# Joined csv\20240601\235230Z.csv
# 2024-06-01 23:52:35
# Joined csv\20240601\235235Z.csv
# 2024-06-01 23:52:40
# Joined csv\20240601\235240Z.csv
# 2024-06-01 23:52:45
# Joined csv\20240601\235245Z.csv
# 2024-06-01 23:52:50
# Joined csv\20240601\235250Z.csv
# 2024-06-01 23:52:55
# Joined csv\20240601\235255Z.csv
# 2024-06-01 23:53:00
# Joined csv\20240601\235300Z.csv
# 2024-06-01 23:53:05
# Joined csv\20240601\235305Z.csv
# 2024-06-01 23:53:10
# Joined csv\20240601\235310Z.csv
# 2024-06-01 23:53:15
# Joined csv\20240601\235315Z.csv
# 2024-06-01 23:53:20
# Joined csv\20240601\235320Z.csv
# 2024-06-01 23:53:25
# Joined csv\20240601\235325Z.csv
# 2024-06-01 23:53:30
# Joined csv\20240601\235330Z.csv
# 2024-06-01 23:53:35
# Joined csv\20240601\235335Z.csv
# 2024-06-01 23:53:40
# Joined csv\20240601\235340Z.csv
# 2024-06-01 23:53:45
# Joined csv\20240601\235345Z.csv
# 2024-06-01 23:53:50
# Joined csv\20240601\235350Z.csv
# 2024-06-01 23:53:55
# Joined csv\20240601\235355Z.csv
# 2024-06-01 23:54:00
# Joined csv\20240601\235400Z.csv
# 2024-06-01 23:54:05
# Joined csv\20240601\235405Z.csv
# 2024-06-01 23:54:10
# Joined csv\20240601\235410Z.csv
# 2024-06-01 23:54:15
# Joined csv\20240601\235415Z.csv
# 2024-06-01 23:54:20
# Joined csv\20240601\235420Z.csv
# 2024-06-01 23:54:25
# Joined csv\20240601\235425Z.csv
# 2024-06-01 23:54:30
# Joined csv\20240601\235430Z.csv
# 2024-06-01 23:54:35
# Joined csv\20240601\235435Z.csv
# 2024-06-01 23:54:40
# Joined csv\20240601\235440Z.csv
# 2024-06-01 23:54:45
# Joined csv\20240601\235445Z.csv
# 2024-06-01 23:54:50
# Joined csv\20240601\235450Z.csv
# 2024-06-01 23:54:55
# Joined csv\20240601\235455Z.csv
# 2024-06-01 23:55:00
# Joined csv\20240601\235500Z.csv
# 2024-06-01 23:55:05
# Joined csv\20240601\235505Z.csv
# 2024-06-01 23:55:10
# Joined csv\20240601\235510Z.csv
# 2024-06-01 23:55:15
# Joined csv\20240601\235515Z.csv
# 2024-06-01 23:55:20
# Joined csv\20240601\235520Z.csv
# 2024-06-01 23:55:25
# Joined csv\20240601\235525Z.csv
# 2024-06-01 23:55:30
# Joined csv\20240601\235530Z.csv
# 2024-06-01 23:55:35
# Joined csv\20240601\235535Z.csv
# 2024-06-01 23:55:40
# Joined csv\20240601\235540Z.csv
# 2024-06-01 23:55:45
# Joined csv\20240601\235545Z.csv
# 2024-06-01 23:55:50
# Joined csv\20240601\235550Z.csv
# 2024-06-01 23:55:55
# Joined csv\20240601\235555Z.csv
# 2024-06-01 23:56:00
# Joined csv\20240601\235600Z.csv
# 2024-06-01 23:56:05
# Joined csv\20240601\235605Z.csv
# 2024-06-01 23:56:10
# Joined csv\20240601\235610Z.csv
# 2024-06-01 23:56:15
# Joined csv\20240601\235615Z.csv
# 2024-06-01 23:56:20
# Joined csv\20240601\235620Z.csv
# 2024-06-01 23:56:25
# Joined csv\20240601\235625Z.csv
# 2024-06-01 23:56:30
# Joined csv\20240601\235630Z.csv
# 2024-06-01 23:56:35
# Joined csv\20240601\235635Z.csv
# 2024-06-01 23:56:40
# Joined csv\20240601\235640Z.csv
# 2024-06-01 23:56:45
# Joined csv\20240601\235645Z.csv
# 2024-06-01 23:56:50
# Joined csv\20240601\235650Z.csv
# 2024-06-01 23:56:55
# Joined csv\20240601\235655Z.csv
# 2024-06-01 23:57:00
# Joined csv\20240601\235700Z.csv
# 2024-06-01 23:57:05
# Joined csv\20240601\235705Z.csv
# 2024-06-01 23:57:10
# Joined csv\20240601\235710Z.csv
# 2024-06-01 23:57:15
# Joined csv\20240601\235715Z.csv
# 2024-06-01 23:57:20
# Joined csv\20240601\235720Z.csv
# 2024-06-01 23:57:25
# Joined csv\20240601\235725Z.csv
# 2024-06-01 23:57:30
# Joined csv\20240601\235730Z.csv
# 2024-06-01 23:57:35
# Joined csv\20240601\235735Z.csv
# 2024-06-01 23:57:40
# Joined csv\20240601\235740Z.csv
# 2024-06-01 23:57:45
# Joined csv\20240601\235745Z.csv
# 2024-06-01 23:57:50
# Joined csv\20240601\235750Z.csv
# 2024-06-01 23:57:55
# Joined csv\20240601\235755Z.csv
# 2024-06-01 23:58:00
# Joined csv\20240601\235800Z.csv
# 2024-06-01 23:58:05
# Joined csv\20240601\235805Z.csv
# 2024-06-01 23:58:10
# Joined csv\20240601\235810Z.csv
# 2024-06-01 23:58:15
# Joined csv\20240601\235815Z.csv
# 2024-06-01 23:58:20
# Joined csv\20240601\235820Z.csv
# 2024-06-01 23:58:25
# Joined csv\20240601\235825Z.csv
# 2024-06-01 23:58:30
# Joined csv\20240601\235830Z.csv
# 2024-06-01 23:58:35
# Joined csv\20240601\235835Z.csv
# 2024-06-01 23:58:40
# Joined csv\20240601\235840Z.csv
# 2024-06-01 23:58:45
# Joined csv\20240601\235845Z.csv
# 2024-06-01 23:58:50
# Joined csv\20240601\235850Z.csv
# 2024-06-01 23:58:55
# Joined csv\20240601\235855Z.csv
# 2024-06-01 23:59:00
# Joined csv\20240601\235900Z.csv
# 2024-06-01 23:59:05
# Joined csv\20240601\235905Z.csv
# 2024-06-01 23:59:10
# Joined csv\20240601\235910Z.csv
# 2024-06-01 23:59:15
# Joined csv\20240601\235915Z.csv
# 2024-06-01 23:59:20
# Joined csv\20240601\235920Z.csv
# 2024-06-01 23:59:25
# Joined csv\20240601\235925Z.csv
# 2024-06-01 23:59:30
# Joined csv\20240601\235930Z.csv
# 2024-06-01 23:59:35
# Joined csv\20240601\235935Z.csv
# 2024-06-01 23:59:40
# Joined csv\20240601\235940Z.csv
# 2024-06-01 23:59:45
# Joined csv\20240601\235945Z.csv
# 2024-06-01 23:59:50
# Joined csv\20240601\235950Z.csv
# 2024-06-01 23:59:55
# Joined csv\20240601\235955Z.csv

# %%
# split the original csv into good and bad. For the bad load all lines. For the good load only samples

# datestring = "20240601"
# df1 = read_csv(os.path.join('csv','joined', f'{datestring}joined.csv'))
# df1["nic"] = df1['nic'].apply(lambda x: int(float(x)) if x !="Nan values" else 0)
# df1['good_bad'] = df1['nic'].apply(lambda x: 'bad' if x=="Nan values" or int(x)<=6 else 'good')
# df1['alt_baro'] = df1['alt_baro'].apply(lambda x: 0 if (x == "ground" or x == "Nan values" ) else int(x))

# df1=df1[['Hexagon_ID', 'r', 'time', 'alt_baro', 'nic', 'good_bad', 'hex','lat','lon','type','flight','t','category','version','nac_p','nac_v']]
# df1 = df1.sort_values(by=["Hexagon_ID","r","time"], ascending=[True,True,True])

# df1_bad = df1[df1['good_bad']=='bad']
# df1_bad.to_csv(os.path.join('csv','joined', f'{datestring}bad.csv'))

# df1_good = df1[df1['good_bad']=='good']
# df1_good.to_csv(os.path.join('csv','joined', f'{datestring}good.csv'))

# print(df1_bad.head(10))
# print(df1_good.head(10))

# # %%
# file_path = os.path.join('csv','joined', f'{datestring}joined-2.csv')
# bad_path = os.path.join('csv','joined', f'{datestring}bad.csv')
# good_path = os.path.join('csv','joined', f'{datestring}good.csv')
# with open(file_path, 'w') as outfile:
#     with open(bad_path, 'r') as infile:
#         outfile.write(infile.read())
#         isHeader = False
#     with open(good_path, 'r') as infile:
#         lines = infile.readlines()
#         filtered_lines = [line for i, line in enumerate(lines[1:]) if (i + 1) % 10 != 0]
#         outfile.write(''.join(filtered_lines))
#     print(f'Joined {file_path}')
# df1 = read_csv(os.path.join('csv','joined', f'{datestring}joined-2.csv'))
# df1 = df1[df1["r"]!="Nan values"]

# df1 = df1.sort_values(by=["Hexagon_ID","r","time"], ascending=[True,True,True])
# df1.to_csv(os.path.join('csv','joined', f'{datestring}joined-2.csv'))

# %%
# df2 = df1.groupby(['Hexagon_ID', 'r'], as_index=False).agg(
#     good_count=('good_bad', lambda x: (x == 'good').sum()),
#     bad_count=('good_bad', lambda x: (x == 'bad').sum()),
#     alt_baro_range=('alt_baro', lambda x: (x.max() - x.min())),
#     time_range=('time', lambda x: x.max() - x.min()))
# df2["total_count"]=df2["good_count"]+df2["bad_count"]
# df2["percentage_bad"]=df2["bad_count"]/df2["total_count"]
# unique = df1.groupby('Hexagon_ID', as_index=False)['r'].nunique().sort_values('r',ascending=False)
# unique = unique.rename(columns={"r": "r_count"})

# print(unique.head(10))

# df2 = df2.merge(unique, on='Hexagon_ID', how='left').sort_values(["r_count", "Hexagon_ID"], ascending=[False,True])
# df2 = df2[['Hexagon_ID', 'r_count',	'r', 'good_count','bad_count','alt_baro_range','time_range','total_count','percentage_bad']]
# df2.to_csv(os.path.join('csv','hexbin', f'{datestring}hexbin.csv'))

# df3 = df2.groupby('Hexagon_ID')[['r_count','r', 'good_count','bad_count','alt_baro_range','time_range','total_count','percentage_bad']]

# df3.head(10)

# %%
# select these rows because it has the highest confidence
# df2_select = df2.query('bad_count>0 and total_count>20 and percentage_bad<1')
# print(f"{df2_select.shape[0]} of {df2.shape[0]}")
# df2_select = df2_select.sort_values(["bad_count"], ascending=[False])

# df2_select.head(10)

# %%
# https://towardsdatascience.com/3-python-packages-for-interactive-data-analysis-3063a201a589
# https://towardsdatascience.com/4-libraries-that-can-perform-eda-in-one-line-of-python-code-b13938a06ae

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))
ax1.plot(df1['time'], df1['alt_baro'], 'b-', label='alt_baro')
ax1.set_xlabel('Time')
ax1.set_ylabel('Altitude (ft)', color='b')
ax1.tick_params('y', colors='b')
ax1.set_yticks(np.arange(0, 50000, 5000))
start_time = datetime.timestamp(dt.datetime(2024,6,1,0,0,0))
end_time = datetime.timestamp(dt.datetime(2024,6,2,0,0,0))
xticks = np.arange(start_time, end_time, 3600)
xticksminor=np.arange(start_time, end_time, 900)
xticksminor=xticksminor[xticksminor//3600!=0]
# for i in np.arange(start_time, end_time, 900)]
xlabels = [f"{datetime.strftime(datetime.fromtimestamp(x), '%Y-%m-%d %H:%M:%S')}" for x in xticks]
xlabelsminor = [f"{datetime.strftime(datetime.fromtimestamp(x), '%H:%M:%S')}" for x in xticksminor]

ax1.set_xticks(xticks, labels=xlabels, rotation=90, fontsize=10)
ax1.set_xticks(xticksminor, labels=xlabelsminor, rotation=90, fontsize=10, minor=True)
ax1.tick_params('x', labelbottom='True')
plt.xlim((start_time, end_time))


ax2 = ax1.twinx()
ax2.plot(df1['time'], df1['nic'], 'rx', label='nic')
ax2.set_ylabel('NIC', color='g')
ax2.tick_params('y', colors='g')
ax2.set_yticks(np.arange(0, 14, 1))


plt.title('Altitude and NIC vs Time')
fig.legend(loc="upper right")
plt.show()

# %%
def create_choropleth_map(geojson_df, data_df, alpha=0.3, map_style="carto-positron", data="percentage_bad", limits=[0,0.1,0.5,1]):
    """
    Create an interactive choropleth map using Plotly Express.
    Parameters:
    - geojson_df (GeoDataFrame): GeoJSON data containing polygon geometries.
    - data_df (DataFrame): DataFrame containing data to be visualized on the map.
    - alpha (float): Opacity level for the map polygons (0.0 to 1.0).
    - map_style (str): Map style for the Plotly map (e.g., "carto-positron").
    - color_scale (str): Color scale for the choropleth map.
    Returns:
    None
    """
    # Merge the GeoJSON data with your DataFrame
    merged_df = geojson_df.merge(data_df, on="Hexagon_ID", how="left")

    # Create a choropleth map using px.choropleth_mapbox
    fig = px.choropleth_mapbox(
        merged_df,
        geojson=merged_df.geometry,
        locations=merged_df.index,  # Use index as locations to avoid duplicate rows
        color=data,
        color_continuous_scale=[[limits[0], f'rgba(0,255,0,{alpha})'],
                                [limits[1], f'rgba(255,255,0,{alpha})'],
                                [limits[2], f'rgba(255,0,0,{alpha})'],
                                [limits[3], f'rgba(255,0,0,{alpha})']],        
        title="GPS Jam Map",
        mapbox_style=map_style,
        center={"lat": home_lat, "lon": home_lng},  # Adjust the center as needed
        zoom=2,
    )

    # Customize the opacity of the hexagons
    fig.update_traces(marker=dict(opacity=alpha))

    # Add hover data for hotel names
    fig.update_traces(customdata=merged_df[["Hexagon_ID","bad_count", "total_count", "percentage_bad", "lat", "lng"]])

    # Define the hover template 
    hover_template = "<b>Hexagon ID:</b> %{customdata[0]}<br><b>Location:</b> %{customdata[4]:.4f},%{customdata[5]:.4f}<br><b>Percentage bad:</b> %{customdata[3]:.3f}<br><b>Total Count:</b> %{customdata[2]}<extra></extra>"
    fig.update_traces(hovertemplate=hover_template)

    # Set margins to 25 on all sides
    fig.update_layout(margin=dict(l=35, r=35, t=45, b=35))
    
    # Adjust the width of the visualization
    fig.update_layout(width=1000) 

    fig.show()

# %%
create_choropleth_map(geojson_df=hexagon_df, data_df=df2, data="percentage_bad", limits = [0,0.1,0.5,1])

# %%
create_choropleth_map(geojson_df=hexagon_df, data_df=df2, data="bad_count", limits = [0,20,50,100])

# %%
# Change in NIC/NAC/SIL indicates an anomaly, which may be due to any reason

# nic: Navigation Integrity Category (2.2.3.2.7.2.6)
# Table 1: NIC value and corresponding size of containment radius
# NIC Containment Radius
# 0 Unknown
# 1 Rc < 37.04km (20nm)
# 2 Rc < 14.816km (8nm)
# 3 Rc < 7.408km (4nm)
# 4 Rc < 3.704km (2nm)
# 5 Rc < 1852m (1nm)
# 6 Rc < 1111.2m (0.6nm)
# Rc < 926m (0.5nm)
# Rc < 555.6m (0.3nm)
# 7 Rc < 370.4m (0.2nm)
# 8 Rc < 185.2m (0.1nm)
# 9 Rc < 75m
# 10 Rc < 25m
# 11 Rc < 7.5m

# Assuming you have already calculated the counts
# counts = df1['nic'].value_counts(dropna=False)
# print(f"List all nic values with counts {counts}")
# # Create bins for the histogram
# bins = np.arange(len(counts) + 1)

# # Plot the histogram with NA on the left
# plt.hist(df1['nic'], bins=bins, align='left',rwidth=0.5)
# plt.yscale('log')
# plt.title('nic')
# plt.show()

print(f"bad {df1[df1['good_bad']=='bad'].shape[0]}")
print(f"total {df1.shape[0]}")
print(f"% bad / total {df1[df1['good_bad']=='bad'].shape[0]/df1.shape[0]*100:.2f}%")
df1[df1['good_bad']=='bad'].head(100)

# %%
# %%
print(f"List all type with counts {df1['type'].value_counts()}")
# List all type with counts type
# adsb_icao         9145 - messages from a Mode S or ADS-B transponder, using a 24-bit ICAO address
# other              725 - IGNORE miscellaneous data received via Basestation / SBS format, quality / source is unknown.
# adsb_icao_nt       524 - IGNORE - messages from an ADS-B equipped “non-transponder” emitter e.g. a ground vehicle, using a 24-bit ICAO address
# mode_s             515 - ModeS data from the planes transponder (no position transmitted)
# adsr_icao          280 - rebroadcast of ADS-B messages originally sent via another data link e.g. UAT, using a 24-bit ICAO address
# tisb_other         256 - traffic information about a non-ADS-B target using a non-ICAO address
# tisb_trackfile     214 - traffic information about a non-ADS-B target using a track/file identifier, typically from primary or Mode A/C radar
# mlat               116 - MLAT, position calculated arrival time differences using multiple receivers, outliers and varying accuracy is expected.
# unknown             49
# tisb_icao           31 - traffic information about a non-ADS-B target identified by a 24-bit ICAO address, e.g. a Mode S target tracked by secondary radar
# adsb_other          17 - messages from an ADS-B transponder using a non-ICAO address, e.g. anonymized address
plt.hist(df1['type'], align='left')
plt.title('type')
plt.xticks(rotation='vertical')
plt.show()

# %%
# %%

df1_filtered = df1[df1[['nac_p','nac_v']].notnull().all(1)]
nacp_high = df1_filtered[df1_filtered['nac_p']<8]
nacp_high
# rr_lat not null
# rr_lon not null
# lastPosition.lat / lastPosition.lon not null

# %%
print(f"List all ADSB versions with counts {df1['version'].value_counts()}")
# version: ADS-B Version Number 0, 1, 2 (3-7 are reserved) (2.2.3.2.7.5)
# List all ADSB versions with counts version
# 2.0    8881
# 0.0    1119
# 1.0     141
plt.hist(df1['version'])
plt.title('version')
plt.show()

# %%
# nac_p: Navigation Accuracy for Position (2.2.5.1.35)
counts = df1['nac_p'].value_counts()
print(f"List all nac_p values with counts {counts}")
plt.hist(df1['nac_p'])
plt.title('nac_p')
plt.show()

# %%
# nac_v: Navigation Accuracy for Velocity (2.2.5.1.19)
counts = df1['nac_v'].value_counts()
print(f"List all nac_v values with counts {counts}")
plt.hist(df1['nac_v'])
plt.title('nac_v')
plt.show()

# %%
# roll: Roll, degrees, negative is left roll
counts = df1['roll'].value_counts()
print(f"List all roll with counts {counts}")
plt.hist(df1['roll'], align='left')
plt.title('roll')
plt.show()

# %%
# %%
# category: emitter category to identify particular aircraft or vehicle classes (values A0 – D7) (2.2.3.2.5.2)
counts = df1['category'].dropna()
# print(f"List all category with counts {counts}")
plt.hist(counts)
plt.title('category')
plt.show()
# A0 : No ADS-B emitter category information. Do not use this emitter category. If no emitter category fits your installation, seek guidance from the FAA as appropriate. A1 : Light (< 15500 lbs) – Any airplane with a maximum takeoff weight less than 15,500 pounds. This includes very light aircraft (light sport aircraft) that do not meet the requirements of 14 CFR § 103.1.
# A2 : Small (15500 to 75000 lbs) – Any airplane with a maximum takeoff weight greater than or equal to15,500 pounds but less than 75,000 pounds.
# A3 : Large (75000 to 300000 lbs) – Any airplane with a maximum takeoff weight greater than or equal to 75,000 pounds but less than 300,000 pounds that does not qualify for the high vortex category.
# A4 :  High vortex large (aircraft such as B-757) – Any airplane with a maximum takeoff weight greater than or equal to 75,000 pounds but less than 300,000 pounds that has been determined to generate a high wake vortex. Currently, the Boeing 757 is the only example.
# A5 : Heavy (> 300000 lbs) – Any airplane with a maximum takeoff weight equal to or above 300,000 pounds.
# A6 : High performance (> 5g acceleration and 400 kts) – Any airplane, regardless of weight, which can maneuver in excess of 5 G’s and maintain true airspeed above 400 knots.
# A7 : Rotorcraft – Any rotorcraft regardless of weight.
# B0 : No ADS-B emitter category information
# B1 : Glider / sailplane – Any glider or sailplane regardless of weight.
# B2 : Lighter-than-air – Any lighter than air (airship or balloon) regardless of weight.
# B3 : Parachutist / skydiver
# B4 : Ultralight / hang-glider / paraglider – A vehicle that meets the requirements of 14 CFR § 103.1. Light sport aircraft should not use the ultralight emitter category unless they meet 14 CFR § 103.1.
# B5 : Reserved
# B6 : Unmanned aerial vehicle – Any unmanned aerial vehicle or unmanned aircraft system regardless of weight.
# B7 : Space / trans-atmospheric vehicle
# C0 : No ADS-B emitter category information
# C1 : Surface vehicle – emergency vehicle
# C2 : Surface vehicle – service vehicle
# C3 : Point obstacle (includes tethered balloons)
# C4 : Cluster obstacle
# C5 : Line obstacle
# C6 : Reserved
# C7 : Reserved

# %%
# %%
counts = df1['sil'].value_counts(dropna=False)

print(f"List all sil values with counts {counts}")
# Create bins for the histogram
bins = np.arange(len(counts) + 1)

# Plot the histogram with NA on the left
plt.hist(df1['sil'], bins=bins, align='left',rwidth=0.5)
plt.yscale('log')
plt.title('sil')
plt.show()

# %%
url2 = 'https://samples.adsbexchange.com/readsb-hist/2024/02/01/000005Z.json.gz'
response2 = requests.get(url2)
json_data2 = response2.json()
df2 = pd.json_normalize(json_data2['aircraft'])
url3 = 'https://samples.adsbexchange.com/readsb-hist/2024/02/01/000010Z.json.gz'
response3 = requests.get(url3)
json_data3 = response2.json()
df3 = pd.json_normalize(json_data3['aircraft'])
url4 = 'https://samples.adsbexchange.com/readsb-hist/2024/02/01/000015Z.json.gz'
response4 = requests.get(url4)
json_data4 = response2.json()
df4 = pd.json_normalize(json_data4['aircraft'])
