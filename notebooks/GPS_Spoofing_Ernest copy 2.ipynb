# %%
# !python -m venv venv
# # !venv/scripts/activate
# %pip install pandas numpy matplotlib seaborn plotly geopandas scipy scikit-learn statsmodels requests aiohttp shapely ipython h3 ipywidgets dtale tqdm pickle

# %pip install --upgrade nbformat

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt

import requests
import os

import datetime as dt

from pandas import read_csv
import concurrent.futures
import psutil

from datetime import datetime

import h3
import geopandas as gpd
import shapely
import plotly.express as px

from tqdm import tqdm
tqdm.pandas()

from pandas import read_pickle
import matplotlib.dates as mdates

import seaborn as sn
import sys

# %%
# Latitude and longitude coordinates
home_lat = 1.3472764
home_lng = 103.9104234

# Generate H3 hexagons at a specified resolution (e.g., 9)
resolution = 5

# Indicate the number of rings around the central hexagon
ring_size = 463

# global dataframes to avoid keep loading files
df1=None
df2=None
flights_data=None
hexagon_df=None
flights_df=None
hex_list_df = None

# %%
# Verify that the hexagon grid is suitable
# create_choropleth_map_only_hexagon_df(geojson_df=hexagon_df)

# def create_choropleth_map_only_hexagon_df(geojson_df, alpha=0.1, map_style="carto-positron", color_scale="Viridis"):
#     """
#     Create an interactive choropleth map using Plotly Express.
#     Parameters:
#     - geojson_df (GeoDataFrame): GeoJSON data containing polygon geometries.
#     - alpha (float): Opacity level for the map polygons (0.0 to 1.0).
#     - map_style (str): Map style for the Plotly map (e.g., "carto-positron").
#     - color_scale (str): Color scale for the choropleth map.
#     Returns:
#     None
#     """
#     # Create a choropleth map using px.choropleth_mapbox
#     fig = px.choropleth_mapbox(
#         geojson_df,
#         geojson=geojson_df.geometry,
#         locations=geojson_df.index,  # Use index as locations to avoid duplicate rows
#         # color="Count",
#         color_continuous_scale=color_scale,
#         title="GPS Jam Map",
#         mapbox_style=map_style,
#         center={"lat": home_lat, "lon": home_lng},  # Adjust the center as needed
#         zoom=2,
#     )

#     # Customize the opacity of the hexagons
#     fig.update_traces(marker=dict(opacity=alpha))

#     # Set margins to 25 on all sides
#     fig.update_layout(margin=dict(l=35, r=35, t=45, b=35))
    
#     # Adjust the width of the visualization
#     fig.update_layout(width=1000) 

#     fig.show()

# %% [markdown]
# ### Brief
# The dashboard or app has to be useful for a flight planner to decide how to plan a mission or for a pilot to decide how he might want to fly a flight profile. Given this, how should we investigate the data to determine a representation that yould help him/her. With this in mind, what does the data tell us? GPS Jamming is like encountering turbulence on route. It's undesirable for flight, but it's usually not a safety hazard unless it's large and unexpected.
# It is terrible for munitions that rely on this for guidance. But these profiles can be adjusted. You have access to pilots and planners who would fly these things. So we'll help to provide some context to how the data may be investigated. But do look at the raw data and see what it can tell you.
# Maybe you want to try unsupervised learning to see if there are distinct categories. And then investigate what are the common factors in these clusters? Do the EDA and see what hidden insights there are. Then you can decide on the best representation of the data.
#
# ### Exploratory Questions
#  1. How is GPS signal affected by altitude? Speed? Is there any strong correlation?

# %%
def calculate_hexagon_ids(df):
    """
    Calculate Hexagon IDs for each row(ping) in a DataFrame based on their geographic coordinates.
    Args:
        df (pd.DataFrame): DataFrame containing ADSB data with "lat" and "lon" columns.
        hexagon_df (gpd.GeoDataFrame): GeoDataFrame with hexagon geometries and associated Hexagon IDs.
    Returns:
        pd.DataFrame: The input DataFrame with an additional "Hexagon_ID" column indicating the Hexagon ID for each ping.
    """

    # Create a column Hexagon_ID with the ID of the hexagon
    df['Hexagon_ID'] = None

    df = df.sort_values(['flight','time'])

    # Iterate through the rows in the df DataFrame and calculate counts within each hexagon
    for i, ping in df.iterrows():
        if not isinstance(ping['lat'], float):
            # use location of last ping
            found = False
            j=1
            while not found:
                if isinstance(df.loc[i-j,'lat'],float):
                    df.loc[i,'lat']=df.loc[i-j,'lat']
                    df.loc[i,'lon']=df.loc[i-j,'lon']
                    found=True
                elif isinstance(df.loc[i+j,'lat'],float):
                    df.loc[i,'lat']=df.loc[i+j,'lat']
                    df.loc[i,'lon']=df.loc[i+j,'lon']
                    found=True
                else:
                    j+=1
            continue
        resolution=5   
        result = h3.geo_to_h3(ping["lat"], ping["lon"], resolution)
        # print(f'{ping["lat"]},{ping["lon"]}=>{result}')
        if result != 0:
             df.loc[i, 'Hexagon_ID'] = result
    
    return df

def get_adsb_data(data):
    """
    Fetches data from ADSB web api. Filter adsb_icao. Clean up non-numeric values. 
    Assign Hexagon_IDs to each ping. Convert types per the mapping. Filter where flight is null. 
    Assign "good_bad" is True when NIC >= 7, False when NIC <= 6
    Saves data to csv.
    Args:
        data: Dictionary of url and csv paths
    Returns:
        None

    """

    if (os.path.isfile(data["csv"])):
        print(f"csv exists {data['csv']}")
        return
    else:
        try:
            response = requests.get(data["url"])
            print(f"downloaded {data['url']}")
            json_data = response.json()
            
            df = pd.json_normalize(json_data['aircraft'])

            df = df[df["type"] == 'adsb_icao']
            df['time'] = pd.to_datetime(datetime.fromtimestamp(json_data['now']).strftime("%Y%m%d%H%M%S"))
            df['Hexagon_ID'] = pd.NA
            df['good_bad'] = np.NaN
            df = df[['flight','r','time', 'hex', 'Hexagon_ID', 'alt_baro', 'nic', 'good_bad','lat','lon','type','t','category','version','nac_p','nac_v','track','baro_rate','seen_pos','seen','gs','alt_geom']]	
            df = df[df["type"] == 'adsb_icao']
            df['alt_baro'] = df['alt_baro'].apply(lambda x: 0 if (x == "ground" or x == np.nan ) else float(x))
            df["nic"] = df["nic"].replace(np.NaN,0)

            mapping = {
                "flight": str,
                "r": str,
                "time": "datetime64[ns]",
                "hex": str,
                "Hexagon_ID": str,
                "alt_baro": float,
                "nic": float,
                "good_bad": bool,
                "lat": float,
                "lon": float,
                "type": str,
                "t": str,
                "category": str,
                "version": float,
                "nac_p": float,
                "nac_v": float,
                "track": float,
                "baro_rate": float,
                "seen_pos": float,
                "seen": float,
                "gs": float,
                "alt_geom": float
            }
            df=df.astype(mapping, copy=True)
            df['good_bad'] = df['nic'].apply(lambda x: False if x==np.NaN or x<7 else True)
            df = df[~df["flight"].isnull()]

            df = calculate_hexagon_ids(df)

            if not os.path.exists(os.path.dirname(data["csv"])):
                os.makedirs(os.path.dirname(data["csv"]))
            df.to_csv(data["csv"])

        except Exception as e:
            # Handle other exceptions
            print("Get ADSB Data: An error occurred:", e)


def join_large_file(folder_path,start,end,file_path):
    if os.path.exists(file_path):
        os.remove(file_path)
    isHeader = True
    with open(file_path, 'w') as outfile:
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            file_datetime = datetime.strptime(file_path, 'csv\\%Y%m%d\\%H%M%SZ.csv')
            print(file_datetime)
            if filename.endswith('.csv') and start <= file_datetime and file_datetime <= end:
                with open(file_path, 'r') as infile:
                    # skip row header
                    if isHeader:
                        outfile.write(infile.read())
                        isHeader = False
                    else:
                        outfile.write(''.join(infile.readlines()[1:]))
                print(f'Joined {file_path}')
        print(f"Saved {file_path}")

def get_flight_data(start_date_time):
    """
    Creates a table of flights and calculates stats for each flight based on aggregates over the rows
    Args:
        start_date_time: start time e.g. dt.datetime(YYYY,MM,DD,HH,MM,SS)
    Global:
        df1: dataframe of raw flight pings from ADSB
        global flights_data
    Returns:
        flights_data: one row for each flight with aggregated fields 'flight', 'bad_count', 'total_count', 'percentage_bad','result'
    """
    global df1
    global flights_data
    flights = df1["flight"].unique()
    flights = flights[1:]
    display(f"Found {flights.shape[0]} flights. Preparing data by flights")
    flights_data = pd.DataFrame(flights, columns=['flight']).progress_apply(lambda x: process_flights_data(x['flight']), axis=1)
    display(flights_data.head(10))
    save_df(flights_data, start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)
    return flights_data

def process_flights_data(flight):
    """
    Extract "rows" for this flight from the large df1 table. Calculate counts so that the flight cas be classified as "normal", "equipment failure", "analyse" or "unknown"
    This function is called inside a pandas.apply on flights_data.
    Args:
        flight: string of Flight Identifier
    Globals:
        df1: dataframe of raw flight pings from ADSB
    Returns:
        pd.Series: one row of flights_data dataframe with aggregated fields 'flight', 'bad_count', 'total_count', 'percentage_bad','result'
    """
    global df1
    rows = df1[df1['flight']==flight]
    # print(f"{flight} - {len(rows)} pings")
    bad_count = rows[rows['good_bad'] == False].shape[0]
    total_count = rows.shape[0]
    percentage_bad = bad_count/total_count if total_count!=0 else 0
    result = analyse_data(percentage_bad)
    return pd.Series({'flight': flight, 'bad_count': bad_count, 'total_count': total_count, 'percentage_bad': percentage_bad, 'result': result})

    
def process_data(start_date_time,end_date_time, reload=[False,False,False]):
    """
    Args:
        start_date_time: start time e.g. dt.datetime(YYYY,MM,DD,HH,MM,SS)
        end_date_time: end time e.g. dt.datetime(YYYY,MM,DD,HH,MM,SS)
        reload=[False,False,False]:
            Reload flags are for skipping steps and saving processing time
            reload[0]=True loads data from [date]joined.csv (df1)
            reload[1]=True loads data from [date]flights_data.csv (>45 min) (flights_data)
            reload[2]=True loads data from [date]hexbin.csv (df2)
    Returns:
        [df1, df2, flights_data]
        df1: dataframe of 'flight','r','time', 'hex', 'Hexagon_ID', 'alt_baro', 'nic', 'good_bad',
            'lat','lon','type','t','category','version','nac_p','nac_v','track','baro_rate','seen_pos',
            'seen','gs','alt_geom'
        flights_data: dataframe of  'flight','bad_count', 'total_count', 'percentage_bad', 'result'
        df2: dataframe of 'Hexagon_ID', 'total_count, 'bad_count', 'alt_baro_range', 'time_range', 
            'percentage_bad'

    """
    delta = dt.timedelta(seconds=5)
    start = start_date_time
    global df1
    global df2
    global flights_data
    file_path = os.path.join('csv', 'joined', f'{start_date_time.strftime("%Y%m%d")}joined.csv')

    if not reload[0]:

        data_array = []
        while start < end_date_time:
            data_array.append({
                "url": f'https://samples.adsbexchange.com/readsb-hist/{start.strftime("%Y/%m/%d")}/{start.strftime("%H%M%S")}Z.json.gz',
                "csv": os.path.join('csv',start.strftime("%Y%m%d"), f'{start.strftime("%H%M%S")}Z.csv')
                })
            start += delta

        try:
            with concurrent.futures.ThreadPoolExecutor() as executor:
                list(executor.map(lambda i: get_adsb_data(data_array[i]), range(len(data_array))))
        except Exception as e:
            print("Thread Pool: An error occurred:", e)
            
        join_large_file(os.path.join('csv',start_date_time.strftime("%Y%m%d")),start_date_time,end_date_time,file_path)
        csv_to_parquet(start_date_time, filetype = FileType.JOINED)

    df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True)
    
    flights_data = get_flight_data(start_date_time) if not reload[1] else load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)

    df2 = get_hexagon_df(start_date_time) if not reload[2] else load_df(start_date_time, filetype=FileType.HEXBIN, parquet=True)

    return [df1, flights_data, df2]


def get_hexagon_df(start_date_time):
    global df1
    global df2
    df2 = df1.groupby(['Hexagon_ID', 'flight'], as_index=False)[['good_bad','alt_baro','time']].agg(
                            total_count=('good_bad', lambda x: (x == x).sum()),
                            bad_count=('good_bad', lambda x: (x == False).sum()),
                            percentage_bad=('good_bad', lambda x: (x == False).sum()/(x==x).sum()),
                            alt_baro_min=('alt_baro', lambda x: x.min()),
                            alt_baro_max=('alt_baro', lambda x: x.max()),
                            time_min=('time', lambda x: x.min()),
                            time_max=('time', lambda x: x.max())
                            )
    df2 = pd.DataFrame(df2)
    df2["Hexagon_ID"]=df2["Hexagon_ID"].replace("0","NA")
    display(df2.head(10))

    # Apply the function to create new 'lat' and 'lng' columns
    coord = df2['Hexagon_ID'].apply(lambda x: h3.h3_to_geo(x) if x!="NA" else (np.nan, np.nan))
    df2[['lat', 'lon']] = pd.DataFrame(coord.tolist(), index=df2.index)

    # coord = df2['Hexagon_ID'].apply(lambda x: h3.h3_to_geo(x) if x!="NA" else pd.Series([np.nan, np.nan]))
    # df2['lat']=coord[0]
    # df2['lon']=coord[1]
    
    save_df(df2, start_date_time, filetype=FileType.HEXBIN, parquet=True)
    return df2


class FileType:
    JOINED = "joined"
    SAMPLED = "sampled"
    HEXBIN = "hexbin"
    FLIGHTS_DATA = "flights_data"

def save_df(df, start_date_time, filetype=FileType.JOINED, parquet=False):
    directory = 'joined'
    if parquet:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.parquet')
        display(f'Saving parquet {file_path}')
        df.to_parquet(file_path) 
    else:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.csv')
        display(f'Saving csv {file_path}')
        if isinstance(df, np.ndarray):
            df = pd.DataFrame(df)
            df.to_csv(file_path) 
        else:
            df.to_csv(file_path) 

def load_df(start_date_time, filetype=FileType.JOINED, parquet=False):
    directory = 'joined'
    if parquet:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.parquet')
        display(f'Reading parquet {file_path}')
        return pd.read_parquet(file_path)
    else:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.csv')
        return pd.concat([chunk for chunk in tqdm(pd.read_csv(file_path, chunksize=1000000), desc=f'Loading csv {file_path}')])

def csv_to_parquet(start_date_time, filetype=FileType.JOINED):
    chunk_size = 1000000
    parquet_writer = pd.DataFrame()
    directory = 'joined'
    if filetype == FileType.HEXBIN:
        directory = 'hexbin'
    csv_path=os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.csv')
    parquet_path=os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.parquet')
    print("Converting csv to parquet")
    for i,chunk in enumerate(pd.read_csv(csv_path, chunksize=chunk_size)):
        sys.stdout.write("Conversion progress: %d   \r" % (i) )
        sys.stdout.flush()
        parquet_writer = pd.concat([parquet_writer,chunk])
    parquet_writer.to_parquet(parquet_path)
    display(f"{parquet_path}")

def parquet_to_csv(start_date_time, filetype=FileType.JOINED):
    print("Converting parquet to csv")
    df1=load_df(start_date_time, filetype=filetype, parquet=True)
    save_df(df1, start_date_time, filetype=filetype, parquet=False)


class ResultGroup:
    EQUIPMENT_FAILURE = "equipment_failure"
    NORMAL = "normal"
    ANALYSE = "analyse"
    UNKNOWN = "unknown"

# plot Alt/NIC vs Time
def generate_plots(sample_size, group = ResultGroup.ANALYSE):
    global df1
    global flights_data

    if isinstance(df1, type(None)) or isinstance(flights_data, type(None)):
        print("Generate plots: error no data")
        return

    flights = [str(flight) for flight in flights_data[flights_data['result']==group].sample(sample_size)['flight']]
    for flight in flights:
        flight_df = df1[df1['flight']==flight]
        flight_df.set_index("time")

        fig, ax1 = plt.subplots(figsize=(8, 4))
        ax1.plot(flight_df['time'].astype("datetime64[ns]"), flight_df['alt_baro'], 'bx-', label='alt_baro')
        ax1.tick_params('y', colors='b')
        ax1.set_yticks(np.arange(0, 50000, 5000))
        ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y %H:%M:%S'))

        ax1.set_xlabel('Date-Time', fontsize=10)
        ax1.set_ylabel('Altitude (ft)', color='b', fontsize=10)

        plt.gcf().autofmt_xdate()

        ax2 = ax1.twinx()
        ax2.plot(flight_df['time'].astype("datetime64[ns]"), flight_df['nic'], 'rx-', label='nic')
        ax2.set_ylabel('NIC', color='g', fontsize=10)
        ax2.tick_params('y', colors='g')
        ax2.set_yticks(np.arange(0, 14, 1))

        plt.title(f'Flight:{flight} Altitude and NIC vs Time  (categorised as {group})', fontsize=10)
        fig.legend(loc="lower right")
        plt.show()
        url = f"https://doc8643.com/aircraft/{flight_df.iloc[0]['t']}"
        print(url)
# categorise flights based on NIC
def analyse_data(percentage_bad):
    upper_limit=0.9
    lower_limit=0.1
    if percentage_bad>upper_limit:
        return "equipment_failure"
    elif percentage_bad<lower_limit:
        return "normal"
    elif percentage_bad>=lower_limit and percentage_bad<=upper_limit:
        return "analyse"
    else: 
        return "unknown"

# correlations plot
def generate_correlations(sample_size, group = ResultGroup.ANALYSE):
    global df1
    global flights_data

    if isinstance(df1, type(None)) or isinstance(flights_data, type(None)):
        print("Generate plots: error no data")
        return

    flights = [str(flight) for flight in flights_data[flights_data['result']==group].sample(sample_size)['flight']]
    flights_df=None
    for flight in flights:
        flight_df = df1[df1['flight']==flight]
        flights_df = pd.concat([flights_df,flight_df])    
    
    flights_df.set_index("time")
    selected_columns = ["alt_baro", "nic", "nac_p","nac_v","track","baro_rate","seen_pos","seen","gs","alt_geom"]
    print(flights_df.shape[0])
    display(flights_df.head(10))

    corr_matrix = flights_df[selected_columns].corr(method='pearson')
    ax = plt.axes()
    ax.set_title(f'Pearson cofficient for sample size {sample_size}, \ngroup: {group} \nflights: {flights} ',fontsize=10)
    sn.heatmap(corr_matrix, annot=True)
    plt.show()

# generate hexagons
def get_hexagon_grid(latitude, longitude, resolution, ring_size):
    """
    Generate a hexagonal grid GeoDataFrame centered around a specified location.
    Parameters:
    - latitude (float): Latitude of the center point.
    - longitude (float): Longitude of the center point.
    - resolution (int): H3 resolution for hexagons.
    - ring_size (int): Number of rings to create around the center hexagon.
    Returns:
    - hexagon_df (geopandas.GeoDataFrame): GeoDataFrame containing hexagons and their geometries.
    """

    global hexagon_df

    # Get the H3 hexagons covering the specified location
    center_h3 = h3.geo_to_h3(latitude, longitude, resolution)
    hexagons = list(h3.k_ring(center_h3, ring_size))  # Convert the set to a list

    # Create a GeoDataFrame with hexagons and their corresponding geometries
    hexagon_geometries = [shapely.geometry.Polygon(h3.h3_to_geo_boundary(hexagon, geo_json=True)) for hexagon in hexagons]
    hexagon_df = gpd.GeoDataFrame({'Hexagon_ID': hexagons, 'geometry': hexagon_geometries})
    return hexagon_df

# plot hexagon map    
def create_choropleth_map(alpha=0.5, map_style="carto-positron", data="percentage_bad", limits=[0,0.1,0.5,1], lat=home_lat, lon=home_lng, hex_list=[]):
    """
    Create an interactive choropleth map using Plotly Express.
    Parameters:
    - geojson_df (GeoDataFrame): GeoJSON data containing polygon geometries.
    - data_df (DataFrame): DataFrame containing data to be visualized on the map.
    - alpha (float): Opacity level for the map polygons (0.0 to 1.0).
    - map_style (str): Map style for the Plotly map (e.g., "carto-positron").
    - color_scale (str): Color scale for the choropleth map.
    Returns:
    None
    """
    global df2
    global hexagon_df
    global flights_df
    global hex_list_df
    

    # Hexagon grid around HOME
    if isinstance(hexagon_df, type(None)):
        hexagon_df = get_hexagon_grid(home_lat, home_lng, resolution, ring_size)
    print("hexagons calculated")

    if isinstance(hex_list_df, type(None)):
        hex_list_df = df2[(df2["Hexagon_ID"].isin(hex_list))]
    print("hex_list_df calculated")
    display(hex_list_df.head(10))

    # Merge the GeoJSON data with your DataFrame
    merged_df = hexagon_df.merge(df2 if (len(hex_list)==0) else hex_list_df, on="Hexagon_ID", how="left")
    print(f'merged hexagon_df with {"df2" if (len(hex_list)==0) else "hex_list_df"}')

    merged_df['lat'].astype(float)
    merged_df['lon'].astype(float)
    # merged_df = merged_df.dropna(subset=['lat', 'lon']) if merged_df["lat"].isnull().values.any() else merged_df
    
    display(merged_df.head(10))
    print(f"merged_df: {merged_df.shape[0]}")

    # Create a choropleth map using px.choropleth_mapbox
    fig = px.choropleth_mapbox(
        merged_df,
        geojson=merged_df.geometry,
        locations=merged_df.index,  # Use index as locations to avoid duplicate rows
        color=data,
        color_continuous_scale=[[limits[0], f'rgba(0,255,0,{alpha})'],
                                [limits[1], f'rgba(255,255,0,{alpha})'],
                                [limits[2], f'rgba(255,0,0,{alpha})'],
                                [limits[3], f'rgba(255,0,0,{alpha})']],        
        title="GPS Jam Map",
        mapbox_style=map_style,
        center={"lat": lat, "lon": lon},  # Adjust the center as needed
        zoom=2,
    )

    # Customize the opacity of the hexagons
    fig.update_traces(marker=dict(opacity=alpha))

    # Add hover data for hotel names
    fig.update_traces(customdata=merged_df[["Hexagon_ID","bad_count", "total_count", "percentage_bad", "lat", "lon"]])

    # Define the hover template 
    hover_template = "<b>Hexagon ID:</b> %{customdata[0]}<br><b>Location:</b> %{customdata[4]:.4f},%{customdata[5]:.4f}<br><b>Percentage bad:</b> %{customdata[3]:.3f}<br><b>Total Count:</b> %{customdata[2]}<extra></extra>"
    fig.update_traces(hovertemplate=hover_template)

    # Set margins to 25 on all sides
    fig.update_layout(margin=dict(l=35, r=35, t=45, b=35))
    
    # Adjust the width of the visualization
    fig.update_layout(width=1000) 


    # Create a scatter mapbox plot for the flight data
    flight_fig = px.scatter_mapbox(
        flights_df,
        lat="lat",
        lon="lon",
        hover_name="flight", 
        hover_data=["flight","time","alt_baro", "nic", "nac_p","nac_v","track","baro_rate","seen_pos","seen","gs","alt_geom"], 
        color_discrete_sequence=["blue"],  # Set the color of the flight points
        zoom=2,
    )

    # Overlay the flight data onto the choropleth map
    fig.add_trace(flight_fig.data[0])

    fig.show()

# plot flights on hexagon map, only those flights passing through hexagons in the hex_list
def get_flights_with_hex_list(hex_list):
        
        global flights_df
        global df1

        flights_df=None


        for hexagon_ID in hex_list:
                
                # get the flights in that hexagon
                flights_in_hex = df1[df1['Hexagon_ID']==hexagon_ID]['flight'].unique()

                # extract all the rows for those flights
                for flight in flights_in_hex:
                        flight_df = df1[(df1['flight']==flight) & (df1['Hexagon_ID']==hexagon_ID)]
                        time_start = flight_df["time"].min()
                        time_end = flight_df["time"].max()
                        # flight_df2 contains all pings of the flight between the start and end time that the flight is inside the hex. i.e. it includes pings that have null lat/lon values
                        flight_df2 = df1[(df1['flight']==flight) & (df1['time'].between(time_start, time_end))]
                        flights_df = pd.concat([flights_df,flight_df2])

        display(flights_df.head(5))

        return flights_df
        # plot choropleth map with flights overlaid on top of the hexagons
        create_choropleth_map(data="percentage_bad", limits = [0,0.1,0.5,1], lat=hex_list[0][0], lon=hex_list[0][1], hex_list=hex_list)


# note that for the free sample, only the first day of each month is available on the adsbexchange
# 4 hours + to download 1 day of files
# 18 mins to reload

[df1, flights_data, df2] = process_data(dt.datetime(2024,3,1,0,0,0),dt.datetime(2024,3,2,0,0,0), reload=[False, False, False])
# Out:
# csv exists csv\20240301\000000Z.csv
# csv exists csv\20240301\000005Z.csv
# csv exists csv\20240301\000010Z.csv
# csv exists csv\20240301\000015Z.csv
# csv exists csv\20240301\000020Z.csv
# csv exists csv\20240301\000025Z.csv
# csv exists csv\20240301\000030Z.csv
# csv exists csv\20240301\000035Z.csv
# csv exists csv\20240301\000040Z.csv
# csv exists csv\20240301\000045Z.csv
# csv exists csv\20240301\000050Z.csv
# csv exists csv\20240301\000055Z.csv
# csv exists csv\20240301\000105Z.csv
# csv exists csv\20240301\000110Z.csv
# csv exists csv\20240301\000100Z.csv
# csv exists csv\20240301\000120Z.csv
# csv exists csv\20240301\000115Z.csv
# csv exists csv\20240301\000130Z.csv
# csv exists csv\20240301\000125Z.csv
# csv exists csv\20240301\000135Z.csv
# csv exists csv\20240301\000150Z.csv
# csv exists csv\20240301\000145Z.csv
# csv exists csv\20240301\000140Z.csv
# csv exists csv\20240301\000155Z.csv
# csv exists csv\20240301\000200Z.csv
# csv exists csv\20240301\000210Z.csv
# csv exists csv\20240301\000205Z.csv
# csv exists csv\20240301\000220Z.csv
# csv exists csv\20240301\000215Z.csv
# csv exists csv\20240301\000230Z.csv
# csv exists csv\20240301\000225Z.csv
# csv exists csv\20240301\000235Z.csv
# csv exists csv\20240301\000240Z.csv
# csv exists csv\20240301\000250Z.csv
# csv exists csv\20240301\000245Z.csv
# csv exists csv\20240301\000255Z.csv
# csv exists csv\20240301\000300Z.csv
# csv exists csv\20240301\000305Z.csv
# csv exists csv\20240301\000310Z.csv
# csv exists csv\20240301\000315Z.csv
# csv exists csv\20240301\000320Z.csv
# csv exists csv\20240301\000330Z.csv
# csv exists csv\20240301\000325Z.csv
# csv exists csv\20240301\000335Z.csv
# csv exists csv\20240301\000340Z.csv
# csv exists csv\20240301\000350Z.csv
# csv exists csv\20240301\000405Z.csv
# csv exists csv\20240301\000345Z.csv
# csv exists csv\20240301\000425Z.csv
# csv exists csv\20240301\000410Z.csv
# csv exists csv\20240301\000355Z.csv
# csv exists csv\20240301\000415Z.csv
# csv exists csv\20240301\000400Z.csv
# csv exists csv\20240301\000430Z.csv
# csv exists csv\20240301\000435Z.csv
# csv exists csv\20240301\000420Z.csv
# csv exists csv\20240301\000440Z.csv
# csv exists csv\20240301\000445Z.csv
# csv exists csv\20240301\000510Z.csv
# csv exists csv\20240301\000515Z.csv
# csv exists csv\20240301\000450Z.csv
# csv exists csv\20240301\000500Z.csv
# csv exists csv\20240301\000455Z.csv
# csv exists csv\20240301\000505Z.csv
# csv exists csv\20240301\000545Z.csv
# csv exists csv\20240301\000530Z.csv
# csv exists csv\20240301\000535Z.csv
# csv exists csv\20240301\000525Z.csv
# csv exists csv\20240301\000540Z.csv
# csv exists csv\20240301\000520Z.csv
# csv exists csv\20240301\000550Z.csv
# csv exists csv\20240301\000600Z.csv
# csv exists csv\20240301\000555Z.csv
# csv exists csv\20240301\000620Z.csv
# csv exists csv\20240301\000625Z.csv
# csv exists csv\20240301\000610Z.csv
# csv exists csv\20240301\000605Z.csv
# csv exists csv\20240301\000650Z.csv
# csv exists csv\20240301\000655Z.csv
# csv exists csv\20240301\000635Z.csv
# csv exists csv\20240301\000640Z.csv
# csv exists csv\20240301\000615Z.csv
# csv exists csv\20240301\000645Z.csv
# csv exists csv\20240301\000630Z.csv
# csv exists csv\20240301\000700Z.csv
# csv exists csv\20240301\000710Z.csv
# csv exists csv\20240301\000705Z.csv
# csv exists csv\20240301\000715Z.csv
# csv exists csv\20240301\000720Z.csv
# csv exists csv\20240301\000725Z.csv
# csv exists csv\20240301\000755Z.csv
# csv exists csv\20240301\000735Z.csv
# csv exists csv\20240301\000745Z.csv
# csv exists csv\20240301\000730Z.csv
# csv exists csv\20240301\000740Z.csv
# csv exists csv\20240301\000750Z.csv
# csv exists csv\20240301\000805Z.csv
# csv exists csv\20240301\000810Z.csv
# csv exists csv\20240301\000815Z.csv
# csv exists csv\20240301\000800Z.csv
# csv exists csv\20240301\000830Z.csv
# csv exists csv\20240301\000820Z.csv
# csv exists csv\20240301\000825Z.csv
# csv exists csv\20240301\000835Z.csv
# csv exists csv\20240301\000840Z.csv
# csv exists csv\20240301\000845Z.csv
# csv exists csv\20240301\000850Z.csv
# csv exists csv\20240301\000855Z.csv
# csv exists csv\20240301\000900Z.csv
# csv exists csv\20240301\000905Z.csv
# csv exists csv\20240301\000910Z.csv
# csv exists csv\20240301\000915Z.csv
# csv exists csv\20240301\000925Z.csv
# csv exists csv\20240301\000930Z.csv
# csv exists csv\20240301\000940Z.csv
# csv exists csv\20240301\000945Z.csv
# csv exists csv\20240301\000935Z.csv
# csv exists csv\20240301\000920Z.csv
# csv exists csv\20240301\000955Z.csv
# csv exists csv\20240301\000950Z.csv
# csv exists csv\20240301\001000Z.csv
# csv exists csv\20240301\001005Z.csv
# csv exists csv\20240301\001015Z.csv
# csv exists csv\20240301\001010Z.csv
# csv exists csv\20240301\001045Z.csv
# csv exists csv\20240301\001035Z.csv
# csv exists csv\20240301\001025Z.csv
# csv exists csv\20240301\001050Z.csv
# csv exists csv\20240301\001100Z.csv
# csv exists csv\20240301\001030Z.csv
# csv exists csv\20240301\001040Z.csv
# csv exists csv\20240301\001055Z.csv
# csv exists csv\20240301\001020Z.csv
# csv exists csv\20240301\001105Z.csv
# csv exists csv\20240301\001110Z.csv
# csv exists csv\20240301\001115Z.csv
# csv exists csv\20240301\001120Z.csv
# csv exists csv\20240301\001125Z.csv
# csv exists csv\20240301\001130Z.csv
# csv exists csv\20240301\001135Z.csv
# csv exists csv\20240301\001140Z.csv
# csv exists csv\20240301\001150Z.csv
# csv exists csv\20240301\001220Z.csv
# csv exists csv\20240301\001155Z.csv
# csv exists csv\20240301\001205Z.csv
# csv exists csv\20240301\001200Z.csv
# csv exists csv\20240301\001210Z.csv
# csv exists csv\20240301\001215Z.csv
# csv exists csv\20240301\001145Z.csv
# csv exists csv\20240301\001225Z.csv
# csv exists csv\20240301\001230Z.csv
# csv exists csv\20240301\001235Z.csv
# csv exists csv\20240301\001240Z.csv
# csv exists csv\20240301\001245Z.csv
# csv exists csv\20240301\001250Z.csv
# csv exists csv\20240301\001300Z.csv
# csv exists csv\20240301\001305Z.csv
# csv exists csv\20240301\001255Z.csv
# csv exists csv\20240301\001310Z.csv
# csv exists csv\20240301\001315Z.csv
# csv exists csv\20240301\001325Z.csv
# csv exists csv\20240301\001340Z.csv
# csv exists csv\20240301\001345Z.csv
# csv exists csv\20240301\001320Z.csv
# csv exists csv\20240301\001335Z.csv
# csv exists csv\20240301\001400Z.csv
# csv exists csv\20240301\001330Z.csv
# csv exists csv\20240301\001415Z.csv
# csv exists csv\20240301\001410Z.csv
# csv exists csv\20240301\001430Z.csv
# csv exists csv\20240301\001405Z.csv
# csv exists csv\20240301\001425Z.csv
# csv exists csv\20240301\001445Z.csv
# csv exists csv\20240301\001435Z.csv
# csv exists csv\20240301\001455Z.csv
# csv exists csv\20240301\001420Z.csv
# csv exists csv\20240301\001500Z.csv
# csv exists csv\20240301\001450Z.csv
# csv exists csv\20240301\001440Z.csv
# csv exists csv\20240301\001510Z.csv
# csv exists csv\20240301\001505Z.csv
# csv exists csv\20240301\001520Z.csv
# csv exists csv\20240301\001355Z.csv
# csv exists csv\20240301\001545Z.csv
# csv exists csv\20240301\001350Z.csv
# csv exists csv\20240301\001515Z.csv
# csv exists csv\20240301\001525Z.csv
# csv exists csv\20240301\001605Z.csv
# csv exists csv\20240301\001540Z.csv
# csv exists csv\20240301\001555Z.csv
# csv exists csv\20240301\001620Z.csv
# csv exists csv\20240301\001550Z.csv
# csv exists csv\20240301\001535Z.csv
# csv exists csv\20240301\001600Z.csv
# csv exists csv\20240301\001530Z.csv
# csv exists csv\20240301\001610Z.csv
# csv exists csv\20240301\001615Z.csv
# csv exists csv\20240301\001625Z.csv
# csv exists csv\20240301\001700Z.csv
# csv exists csv\20240301\001630Z.csv
# csv exists csv\20240301\001710Z.csv
# csv exists csv\20240301\001640Z.csv
# csv exists csv\20240301\001645Z.csv
# csv exists csv\20240301\001655Z.csv
# csv exists csv\20240301\001650Z.csv
# csv exists csv\20240301\001705Z.csv
# csv exists csv\20240301\001635Z.csv
# csv exists csv\20240301\001715Z.csv
# csv exists csv\20240301\001720Z.csv
# csv exists csv\20240301\001725Z.csv
# csv exists csv\20240301\001805Z.csv
# csv exists csv\20240301\001810Z.csv
# csv exists csv\20240301\001815Z.csv
# csv exists csv\20240301\001825Z.csv
# csv exists csv\20240301\001830Z.csv
# csv exists csv\20240301\001745Z.csv
# csv exists csv\20240301\001750Z.csv
# csv exists csv\20240301\001755Z.csv
# csv exists csv\20240301\001800Z.csv
# csv exists csv\20240301\001735Z.csv
# csv exists csv\20240301\001730Z.csv
# csv exists csv\20240301\001820Z.csv
# csv exists csv\20240301\001840Z.csv
# csv exists csv\20240301\001850Z.csv
# csv exists csv\20240301\001855Z.csv
# csv exists csv\20240301\001900Z.csv
# csv exists csv\20240301\001905Z.csv
# csv exists csv\20240301\001910Z.csv
# csv exists csv\20240301\001940Z.csv
# csv exists csv\20240301\001945Z.csv
# csv exists csv\20240301\001835Z.csv
# csv exists csv\20240301\001915Z.csv
# csv exists csv\20240301\001845Z.csv
# csv exists csv\20240301\001920Z.csv
# csv exists csv\20240301\001925Z.csv
# csv exists csv\20240301\001930Z.csv
# csv exists csv\20240301\001935Z.csv
# csv exists csv\20240301\002020Z.csv
# csv exists csv\20240301\002030Z.csv
# csv exists csv\20240301\002035Z.csv
# csv exists csv\20240301\002040Z.csv
# csv exists csv\20240301\001740Z.csv
# csv exists csv\20240301\002005Z.csv
# csv exists csv\20240301\002010Z.csv
# csv exists csv\20240301\002105Z.csv
# csv exists csv\20240301\002025Z.csv
# csv exists csv\20240301\002110Z.csv
# csv exists csv\20240301\001955Z.csv
# csv exists csv\20240301\001950Z.csv
# csv exists csv\20240301\002045Z.csv
# csv exists csv\20240301\002130Z.csv
# csv exists csv\20240301\002050Z.csv
# csv exists csv\20240301\002100Z.csv
# csv exists csv\20240301\002055Z.csv
# csv exists csv\20240301\002150Z.csv
# csv exists csv\20240301\002015Z.csv
# csv exists csv\20240301\002120Z.csv
# csv exists csv\20240301\002115Z.csv
# csv exists csv\20240301\002000Z.csv
# csv exists csv\20240301\002135Z.csv
# csv exists csv\20240301\002125Z.csv
# csv exists csv\20240301\002230Z.csv
# csv exists csv\20240301\002155Z.csv
# csv exists csv\20240301\002200Z.csv
# csv exists csv\20240301\002145Z.csv
# csv exists csv\20240301\002205Z.csv
# csv exists csv\20240301\002210Z.csv
# csv exists csv\20240301\002305Z.csv
# csv exists csv\20240301\002315Z.csv
# csv exists csv\20240301\002225Z.csv
# csv exists csv\20240301\002320Z.csv
# csv exists csv\20240301\002235Z.csv
# csv exists csv\20240301\002330Z.csv
# csv exists csv\20240301\002245Z.csv
# csv exists csv\20240301\002250Z.csv
# csv exists csv\20240301\002255Z.csv
# csv exists csv\20240301\002350Z.csv
# csv exists csv\20240301\002215Z.csv
# csv exists csv\20240301\002310Z.csv
# csv exists csv\20240301\002220Z.csv
# csv exists csv\20240301\002410Z.csv
# csv exists csv\20240301\002325Z.csv
# csv exists csv\20240301\002240Z.csv
# csv exists csv\20240301\002335Z.csv
# csv exists csv\20240301\002340Z.csv
# csv exists csv\20240301\002440Z.csv
# csv exists csv\20240301\002445Z.csv
# csv exists csv\20240301\002300Z.csv
# csv exists csv\20240301\002400Z.csv
# csv exists csv\20240301\002405Z.csv
# csv exists csv\20240301\002140Z.csv
# csv exists csv\20240301\002415Z.csv
# csv exists csv\20240301\002420Z.csv
# csv exists csv\20240301\002425Z.csv
# csv exists csv\20240301\002430Z.csv
# csv exists csv\20240301\002435Z.csv
# csv exists csv\20240301\002535Z.csv
# csv exists csv\20240301\002355Z.csv
# csv exists csv\20240301\002450Z.csv
# csv exists csv\20240301\002455Z.csv
# csv exists csv\20240301\002500Z.csv
# csv exists csv\20240301\002505Z.csv
# csv exists csv\20240301\002510Z.csv
# csv exists csv\20240301\002515Z.csv
# csv exists csv\20240301\002520Z.csv
# csv exists csv\20240301\002525Z.csv
# csv exists csv\20240301\002530Z.csv
# csv exists csv\20240301\002540Z.csv
# csv exists csv\20240301\002640Z.csv
# csv exists csv\20240301\002345Z.csv
# csv exists csv\20240301\002545Z.csv
# csv exists csv\20240301\002700Z.csv
# csv exists csv\20240301\002555Z.csv
# csv exists csv\20240301\002600Z.csv
# csv exists csv\20240301\002605Z.csv
# csv exists csv\20240301\002610Z.csv
# csv exists csv\20240301\002615Z.csv
# csv exists csv\20240301\002725Z.csv
# csv exists csv\20240301\002730Z.csv
# csv exists csv\20240301\002735Z.csv
# csv exists csv\20240301\002635Z.csv
# csv exists csv\20240301\002650Z.csv
# csv exists csv\20240301\002800Z.csv
# csv exists csv\20240301\002655Z.csv
# csv exists csv\20240301\002550Z.csv
# csv exists csv\20240301\002705Z.csv
# csv exists csv\20240301\002710Z.csv
# csv exists csv\20240301\002715Z.csv
# csv exists csv\20240301\002720Z.csv
# csv exists csv\20240301\002620Z.csv
# csv exists csv\20240301\002845Z.csv
# csv exists csv\20240301\002630Z.csv
# csv exists csv\20240301\002740Z.csv
# csv exists csv\20240301\002855Z.csv
# csv exists csv\20240301\002750Z.csv
# csv exists csv\20240301\002645Z.csv
# csv exists csv\20240301\002915Z.csv
# csv exists csv\20240301\002920Z.csv
# csv exists csv\20240301\002810Z.csv
# csv exists csv\20240301\002815Z.csv
# csv exists csv\20240301\002820Z.csv
# csv exists csv\20240301\002825Z.csv
# csv exists csv\20240301\002830Z.csv
# csv exists csv\20240301\002835Z.csv
# csv exists csv\20240301\002840Z.csv
# csv exists csv\20240301\002625Z.csv
# csv exists csv\20240301\002850Z.csv
# csv exists csv\20240301\002745Z.csv
# csv exists csv\20240301\002900Z.csv
# csv exists csv\20240301\002905Z.csv
# csv exists csv\20240301\002910Z.csv
# csv exists csv\20240301\003035Z.csv
# csv exists csv\20240301\002805Z.csv
# csv exists csv\20240301\002925Z.csv
# csv exists csv\20240301\002930Z.csv
# csv exists csv\20240301\003100Z.csv
# csv exists csv\20240301\002940Z.csv
# csv exists csv\20240301\002945Z.csv
# csv exists csv\20240301\003105Z.csv
# csv exists csv\20240301\002955Z.csv
# csv exists csv\20240301\003000Z.csv
# csv exists csv\20240301\003005Z.csv
# csv exists csv\20240301\003140Z.csv
# csv exists csv\20240301\003015Z.csv
# csv exists csv\20240301\003145Z.csv
# csv exists csv\20240301\003025Z.csv
# csv exists csv\20240301\003030Z.csv
# csv exists csv\20240301\002755Z.csv
# csv exists csv\20240301\003040Z.csv
# csv exists csv\20240301\003045Z.csv
# csv exists csv\20240301\003050Z.csv
# csv exists csv\20240301\003055Z.csv
# csv exists csv\20240301\002935Z.csv
# csv exists csv\20240301\003110Z.csv
# csv exists csv\20240301\002950Z.csv
# csv exists csv\20240301\003115Z.csv
# csv exists csv\20240301\003245Z.csv
# csv exists csv\20240301\003125Z.csv
# csv exists csv\20240301\003130Z.csv
# csv exists csv\20240301\003135Z.csv
# csv exists csv\20240301\003010Z.csv
# csv exists csv\20240301\003020Z.csv
# csv exists csv\20240301\003150Z.csv
# csv exists csv\20240301\003155Z.csv
# csv exists csv\20240301\003200Z.csv
# csv exists csv\20240301\003205Z.csv
# csv exists csv\20240301\003210Z.csv
# csv exists csv\20240301\003215Z.csv
# csv exists csv\20240301\003345Z.csv
# csv exists csv\20240301\003350Z.csv
# csv exists csv\20240301\003230Z.csv
# csv exists csv\20240301\003235Z.csv
# csv exists csv\20240301\003240Z.csv
# csv exists csv\20240301\003250Z.csv
# csv exists csv\20240301\003255Z.csv
# csv exists csv\20240301\003120Z.csv
# csv exists csv\20240301\003300Z.csv
# csv exists csv\20240301\003305Z.csv
# csv exists csv\20240301\003310Z.csv
# csv exists csv\20240301\003315Z.csv
# csv exists csv\20240301\003320Z.csv
# csv exists csv\20240301\003325Z.csv
# csv exists csv\20240301\003455Z.csv
# csv exists csv\20240301\003335Z.csv
# csv exists csv\20240301\003340Z.csv
# csv exists csv\20240301\003220Z.csv
# csv exists csv\20240301\003225Z.csv
# csv exists csv\20240301\003355Z.csv
# csv exists csv\20240301\003400Z.csv
# csv exists csv\20240301\003405Z.csv
# csv exists csv\20240301\003535Z.csv
# csv exists csv\20240301\003415Z.csv
# csv exists csv\20240301\003420Z.csv
# csv exists csv\20240301\003550Z.csv
# csv exists csv\20240301\003430Z.csv
# csv exists csv\20240301\003435Z.csv
# csv exists csv\20240301\003440Z.csv
# csv exists csv\20240301\003445Z.csv
# csv exists csv\20240301\003450Z.csv
# csv exists csv\20240301\003330Z.csv
# csv exists csv\20240301\003500Z.csv
# csv exists csv\20240301\003505Z.csv
# csv exists csv\20240301\003510Z.csv
# csv exists csv\20240301\003515Z.csv
# csv exists csv\20240301\003520Z.csv
# csv exists csv\20240301\003525Z.csv
# csv exists csv\20240301\003530Z.csv
# csv exists csv\20240301\003410Z.csv
# csv exists csv\20240301\003540Z.csv
# csv exists csv\20240301\003545Z.csv
# csv exists csv\20240301\003555Z.csv
# csv exists csv\20240301\003425Z.csv
# csv exists csv\20240301\003605Z.csv
# csv exists csv\20240301\003600Z.csv
# csv exists csv\20240301\003610Z.csv
# csv exists csv\20240301\003615Z.csv
# csv exists csv\20240301\003620Z.csv
# csv exists csv\20240301\003625Z.csv
# csv exists csv\20240301\003630Z.csv
# csv exists csv\20240301\003640Z.csv
# csv exists csv\20240301\003635Z.csv
# csv exists csv\20240301\003645Z.csv
# csv exists csv\20240301\003650Z.csv
# csv exists csv\20240301\003820Z.csv
# csv exists csv\20240301\003700Z.csv
# csv exists csv\20240301\003705Z.csv
# csv exists csv\20240301\003710Z.csv
# csv exists csv\20240301\003715Z.csv
# csv exists csv\20240301\003850Z.csv
# csv exists csv\20240301\003725Z.csv
# csv exists csv\20240301\003730Z.csv
# csv exists csv\20240301\003735Z.csv
# csv exists csv\20240301\003740Z.csv
# csv exists csv\20240301\003745Z.csv
# csv exists csv\20240301\003750Z.csv
# csv exists csv\20240301\003920Z.csv
# csv exists csv\20240301\003800Z.csv
# csv exists csv\20240301\003805Z.csv
# csv exists csv\20240301\003810Z.csv
# csv exists csv\20240301\003815Z.csv
# csv exists csv\20240301\003825Z.csv
# csv exists csv\20240301\003655Z.csv
# csv exists csv\20240301\004000Z.csv
# csv exists csv\20240301\003835Z.csv
# csv exists csv\20240301\004005Z.csv
# csv exists csv\20240301\003845Z.csv
# csv exists csv\20240301\003720Z.csv
# csv exists csv\20240301\003900Z.csv
# csv exists csv\20240301\003855Z.csv
# csv exists csv\20240301\003905Z.csv
# csv exists csv\20240301\003910Z.csv
# csv exists csv\20240301\003915Z.csv
# csv exists csv\20240301\003755Z.csv
# csv exists csv\20240301\003925Z.csv
# csv exists csv\20240301\003930Z.csv
# csv exists csv\20240301\003935Z.csv
# csv exists csv\20240301\003940Z.csv
# csv exists csv\20240301\003945Z.csv
# csv exists csv\20240301\004115Z.csv
# csv exists csv\20240301\004120Z.csv
# csv exists csv\20240301\004125Z.csv
# csv exists csv\20240301\004130Z.csv
# csv exists csv\20240301\004135Z.csv
# csv exists csv\20240301\003830Z.csv
# csv exists csv\20240301\004015Z.csv
# csv exists csv\20240301\004020Z.csv
# csv exists csv\20240301\004025Z.csv
# csv exists csv\20240301\004030Z.csv
# csv exists csv\20240301\004035Z.csv
# csv exists csv\20240301\004040Z.csv
# csv exists csv\20240301\004045Z.csv
# csv exists csv\20240301\004050Z.csv
# csv exists csv\20240301\004055Z.csv
# csv exists csv\20240301\004100Z.csv
# csv exists csv\20240301\004110Z.csv
# csv exists csv\20240301\003950Z.csv
# csv exists csv\20240301\003955Z.csv
# csv exists csv\20240301\004255Z.csv
# csv exists csv\20240301\004010Z.csv
# csv exists csv\20240301\003840Z.csv
# csv exists csv\20240301\004140Z.csv
# csv exists csv\20240301\004105Z.csv
# csv exists csv\20240301\004150Z.csv
# csv exists csv\20240301\004310Z.csv
# csv exists csv\20240301\004145Z.csv
# csv exists csv\20240301\004200Z.csv
# csv exists csv\20240301\004335Z.csv
# csv exists csv\20240301\004345Z.csv
# csv exists csv\20240301\004355Z.csv
# csv exists csv\20240301\004225Z.csv
# csv exists csv\20240301\004220Z.csv
# csv exists csv\20240301\004230Z.csv
# csv exists csv\20240301\004240Z.csv
# csv exists csv\20240301\004235Z.csv
# csv exists csv\20240301\004250Z.csv
# csv exists csv\20240301\004245Z.csv
# csv exists csv\20240301\004430Z.csv
# csv exists csv\20240301\004305Z.csv
# csv exists csv\20240301\004315Z.csv
# csv exists csv\20240301\004320Z.csv
# csv exists csv\20240301\004155Z.csv
# csv exists csv\20240301\004325Z.csv
# csv exists csv\20240301\004330Z.csv
# csv exists csv\20240301\004340Z.csv
# csv exists csv\20240301\004210Z.csv
# csv exists csv\20240301\004215Z.csv
# csv exists csv\20240301\004350Z.csv
# csv exists csv\20240301\004205Z.csv
# csv exists csv\20240301\004400Z.csv
# csv exists csv\20240301\004530Z.csv
# csv exists csv\20240301\004410Z.csv
# csv exists csv\20240301\004415Z.csv
# csv exists csv\20240301\004420Z.csv
# csv exists csv\20240301\004550Z.csv
# csv exists csv\20240301\004555Z.csv
# csv exists csv\20240301\004600Z.csv
# csv exists csv\20240301\004605Z.csv
# csv exists csv\20240301\004610Z.csv
# csv exists csv\20240301\004615Z.csv
# csv exists csv\20240301\004435Z.csv
# csv exists csv\20240301\004455Z.csv
# csv exists csv\20240301\004500Z.csv
# csv exists csv\20240301\004505Z.csv
# csv exists csv\20240301\004640Z.csv
# csv exists csv\20240301\004515Z.csv
# csv exists csv\20240301\004520Z.csv
# csv exists csv\20240301\004525Z.csv
# csv exists csv\20240301\004535Z.csv
# csv exists csv\20240301\004405Z.csv
# csv exists csv\20240301\004540Z.csv
# csv exists csv\20240301\004545Z.csv
# csv exists csv\20240301\004425Z.csv
# csv exists csv\20240301\004730Z.csv
# csv exists csv\20240301\004300Z.csv
# csv exists csv\20240301\004445Z.csv
# csv exists csv\20240301\004450Z.csv
# csv exists csv\20240301\004625Z.csv
# csv exists csv\20240301\004630Z.csv
# csv exists csv\20240301\004620Z.csv
# csv exists csv\20240301\004645Z.csv
# csv exists csv\20240301\004510Z.csv
# csv exists csv\20240301\004635Z.csv
# csv exists csv\20240301\004650Z.csv
# csv exists csv\20240301\004655Z.csv
# csv exists csv\20240301\004705Z.csv
# csv exists csv\20240301\004700Z.csv
# csv exists csv\20240301\004835Z.csv
# csv exists csv\20240301\004715Z.csv
# csv exists csv\20240301\004720Z.csv
# csv exists csv\20240301\004725Z.csv
# csv exists csv\20240301\004440Z.csv
# csv exists csv\20240301\004735Z.csv
# csv exists csv\20240301\004900Z.csv
# csv exists csv\20240301\004740Z.csv
# csv exists csv\20240301\004920Z.csv
# csv exists csv\20240301\004755Z.csv
# csv exists csv\20240301\004800Z.csv
# csv exists csv\20240301\004805Z.csv
# csv exists csv\20240301\004810Z.csv
# csv exists csv\20240301\004815Z.csv
# csv exists csv\20240301\004945Z.csv
# csv exists csv\20240301\004825Z.csv
# csv exists csv\20240301\004830Z.csv
# csv exists csv\20240301\004710Z.csv
# csv exists csv\20240301\004840Z.csv
# csv exists csv\20240301\004850Z.csv
# csv exists csv\20240301\004855Z.csv
# csv exists csv\20240301\004845Z.csv
# csv exists csv\20240301\004745Z.csv
# csv exists csv\20240301\004915Z.csv
# csv exists csv\20240301\004905Z.csv
# csv exists csv\20240301\004750Z.csv
# csv exists csv\20240301\004910Z.csv
# csv exists csv\20240301\004930Z.csv
# csv exists csv\20240301\004925Z.csv
# csv exists csv\20240301\004935Z.csv
# csv exists csv\20240301\004940Z.csv
# csv exists csv\20240301\004820Z.csv
# csv exists csv\20240301\004950Z.csv
# csv exists csv\20240301\004955Z.csv
# csv exists csv\20240301\005000Z.csv
# csv exists csv\20240301\005005Z.csv
# csv exists csv\20240301\005010Z.csv
# csv exists csv\20240301\005015Z.csv
# csv exists csv\20240301\005020Z.csv
# csv exists csv\20240301\005025Z.csv
# csv exists csv\20240301\005155Z.csv
# csv exists csv\20240301\005035Z.csv
# csv exists csv\20240301\005040Z.csv
# csv exists csv\20240301\005045Z.csv
# csv exists csv\20240301\005050Z.csv
# csv exists csv\20240301\005055Z.csv
# csv exists csv\20240301\005100Z.csv
# csv exists csv\20240301\005105Z.csv
# csv exists csv\20240301\005110Z.csv
# csv exists csv\20240301\005115Z.csv
# csv exists csv\20240301\005120Z.csv
# csv exists csv\20240301\005250Z.csv
# csv exists csv\20240301\005255Z.csv
# csv exists csv\20240301\005300Z.csv
# csv exists csv\20240301\005140Z.csv
# csv exists csv\20240301\005145Z.csv
# csv exists csv\20240301\005150Z.csv
# csv exists csv\20240301\005200Z.csv
# csv exists csv\20240301\005330Z.csv
# csv exists csv\20240301\005205Z.csv
# csv exists csv\20240301\005210Z.csv
# csv exists csv\20240301\005215Z.csv
# csv exists csv\20240301\005345Z.csv
# csv exists csv\20240301\005350Z.csv
# csv exists csv\20240301\005355Z.csv
# csv exists csv\20240301\005235Z.csv
# csv exists csv\20240301\005240Z.csv
# csv exists csv\20240301\005245Z.csv
# csv exists csv\20240301\005125Z.csv
# csv exists csv\20240301\005130Z.csv
# csv exists csv\20240301\005135Z.csv
# csv exists csv\20240301\005305Z.csv
# csv exists csv\20240301\005310Z.csv
# csv exists csv\20240301\005440Z.csv
# csv exists csv\20240301\005320Z.csv
# csv exists csv\20240301\005325Z.csv
# csv exists csv\20240301\005030Z.csv
# csv exists csv\20240301\005340Z.csv
# csv exists csv\20240301\005335Z.csv
# csv exists csv\20240301\005225Z.csv
# csv exists csv\20240301\005515Z.csv
# csv exists csv\20240301\005220Z.csv
# csv exists csv\20240301\005400Z.csv
# csv exists csv\20240301\005405Z.csv
# csv exists csv\20240301\005410Z.csv
# csv exists csv\20240301\005415Z.csv
# csv exists csv\20240301\005420Z.csv
# csv exists csv\20240301\005425Z.csv
# csv exists csv\20240301\005430Z.csv
# csv exists csv\20240301\005435Z.csv
# csv exists csv\20240301\005315Z.csv
# csv exists csv\20240301\005445Z.csv
# csv exists csv\20240301\005615Z.csv
# csv exists csv\20240301\005455Z.csv
# csv exists csv\20240301\005500Z.csv
# csv exists csv\20240301\005505Z.csv
# csv exists csv\20240301\005520Z.csv
# csv exists csv\20240301\005525Z.csv
# csv exists csv\20240301\005230Z.csv
# csv exists csv\20240301\005510Z.csv
# csv exists csv\20240301\005530Z.csv
# csv exists csv\20240301\005535Z.csv
# csv exists csv\20240301\005540Z.csv
# csv exists csv\20240301\005545Z.csv
# csv exists csv\20240301\005715Z.csv
# csv exists csv\20240301\005720Z.csv
# csv exists csv\20240301\005725Z.csv
# csv exists csv\20240301\005730Z.csv
# csv exists csv\20240301\005610Z.csv
# csv exists csv\20240301\005450Z.csv
# csv exists csv\20240301\005620Z.csv
# csv exists csv\20240301\005625Z.csv
# csv exists csv\20240301\005750Z.csv
# csv exists csv\20240301\005635Z.csv
# csv exists csv\20240301\005640Z.csv
# csv exists csv\20240301\005645Z.csv
# csv exists csv\20240301\005650Z.csv
# csv exists csv\20240301\005655Z.csv
# csv exists csv\20240301\005700Z.csv
# csv exists csv\20240301\005705Z.csv
# csv exists csv\20240301\005710Z.csv
# csv exists csv\20240301\005845Z.csv
# csv exists csv\20240301\005555Z.csv
# csv exists csv\20240301\005605Z.csv
# csv exists csv\20240301\005735Z.csv
# csv exists csv\20240301\005600Z.csv
# csv exists csv\20240301\005740Z.csv
# csv exists csv\20240301\005745Z.csv
# csv exists csv\20240301\005755Z.csv
# csv exists csv\20240301\005630Z.csv
# csv exists csv\20240301\005800Z.csv
# csv exists csv\20240301\005805Z.csv
# csv exists csv\20240301\005810Z.csv
# csv exists csv\20240301\005815Z.csv
# csv exists csv\20240301\005945Z.csv
# csv exists csv\20240301\005950Z.csv
# csv exists csv\20240301\005955Z.csv
# csv exists csv\20240301\010000Z.csv
# csv exists csv\20240301\010005Z.csv
# csv exists csv\20240301\005550Z.csv
# csv exists csv\20240301\005850Z.csv
# csv exists csv\20240301\005855Z.csv
# csv exists csv\20240301\005900Z.csv
# csv exists csv\20240301\005905Z.csv
# csv exists csv\20240301\010030Z.csv
# csv exists csv\20240301\005915Z.csv
# csv exists csv\20240301\005920Z.csv
# csv exists csv\20240301\010050Z.csv
# csv exists csv\20240301\005930Z.csv
# csv exists csv\20240301\005940Z.csv
# csv exists csv\20240301\005935Z.csv
# csv exists csv\20240301\005825Z.csv
# csv exists csv\20240301\005820Z.csv
# csv exists csv\20240301\005830Z.csv
# csv exists csv\20240301\005835Z.csv
# csv exists csv\20240301\005840Z.csv
# csv exists csv\20240301\010010Z.csv
# csv exists csv\20240301\010015Z.csv
# csv exists csv\20240301\010020Z.csv
# csv exists csv\20240301\010025Z.csv
# csv exists csv\20240301\010200Z.csv
# csv exists csv\20240301\005910Z.csv
# csv exists csv\20240301\010040Z.csv
# csv exists csv\20240301\010045Z.csv
# csv exists csv\20240301\005925Z.csv
# csv exists csv\20240301\010055Z.csv
# csv exists csv\20240301\010100Z.csv
# csv exists csv\20240301\010105Z.csv
# csv exists csv\20240301\010110Z.csv
# csv exists csv\20240301\010115Z.csv
# csv exists csv\20240301\010120Z.csv
# csv exists csv\20240301\010125Z.csv
# csv exists csv\20240301\010130Z.csv
# csv exists csv\20240301\010135Z.csv
# csv exists csv\20240301\010140Z.csv
# csv exists csv\20240301\010145Z.csv
# csv exists csv\20240301\010150Z.csv
# csv exists csv\20240301\010155Z.csv
# csv exists csv\20240301\010035Z.csv
# csv exists csv\20240301\010205Z.csv
# csv exists csv\20240301\010210Z.csv
# csv exists csv\20240301\010215Z.csv
# csv exists csv\20240301\010220Z.csv
# csv exists csv\20240301\010225Z.csv
# csv exists csv\20240301\010230Z.csv
# csv exists csv\20240301\010235Z.csv
# csv exists csv\20240301\010240Z.csv
# csv exists csv\20240301\010245Z.csv
# csv exists csv\20240301\010250Z.csv
# csv exists csv\20240301\010255Z.csv
# csv exists csv\20240301\010300Z.csv
# csv exists csv\20240301\010305Z.csv
# csv exists csv\20240301\010310Z.csv
# csv exists csv\20240301\010315Z.csv
# csv exists csv\20240301\010320Z.csv
# csv exists csv\20240301\010325Z.csv
# csv exists csv\20240301\010330Z.csv
# csv exists csv\20240301\010335Z.csv
# csv exists csv\20240301\010340Z.csv
# csv exists csv\20240301\010505Z.csv
# csv exists csv\20240301\010345Z.csv
# csv exists csv\20240301\010350Z.csv
# csv exists csv\20240301\010525Z.csv
# csv exists csv\20240301\010400Z.csv
# csv exists csv\20240301\010405Z.csv
# csv exists csv\20240301\010410Z.csv
# csv exists csv\20240301\010415Z.csv
# csv exists csv\20240301\010420Z.csv
# csv exists csv\20240301\010425Z.csv
# csv exists csv\20240301\010430Z.csv
# csv exists csv\20240301\010435Z.csv
# csv exists csv\20240301\010440Z.csv
# csv exists csv\20240301\010445Z.csv
# csv exists csv\20240301\010450Z.csv
# csv exists csv\20240301\010455Z.csv
# csv exists csv\20240301\010635Z.csv
# csv exists csv\20240301\010510Z.csv
# csv exists csv\20240301\010645Z.csv
# csv exists csv\20240301\010650Z.csv
# csv exists csv\20240301\010520Z.csv
# csv exists csv\20240301\010700Z.csv
# csv exists csv\20240301\010530Z.csv
# csv exists csv\20240301\010535Z.csv
# csv exists csv\20240301\010540Z.csv
# csv exists csv\20240301\010715Z.csv
# csv exists csv\20240301\010720Z.csv
# csv exists csv\20240301\010555Z.csv
# csv exists csv\20240301\010600Z.csv
# csv exists csv\20240301\010605Z.csv
# csv exists csv\20240301\010610Z.csv
# csv exists csv\20240301\010615Z.csv
# csv exists csv\20240301\010630Z.csv
# csv exists csv\20240301\010800Z.csv
# csv exists csv\20240301\010620Z.csv
# csv exists csv\20240301\010625Z.csv
# csv exists csv\20240301\010810Z.csv
# csv exists csv\20240301\010515Z.csv
# csv exists csv\20240301\010655Z.csv
# csv exists csv\20240301\010710Z.csv
# csv exists csv\20240301\010355Z.csv
# csv exists csv\20240301\010705Z.csv
# csv exists csv\20240301\010845Z.csv
# csv exists csv\20240301\010545Z.csv
# csv exists csv\20240301\010730Z.csv
# csv exists csv\20240301\010735Z.csv
# csv exists csv\20240301\010725Z.csv
# csv exists csv\20240301\010740Z.csv
# csv exists csv\20240301\010745Z.csv
# csv exists csv\20240301\010750Z.csv
# csv exists csv\20240301\010755Z.csv
# csv exists csv\20240301\010805Z.csv
# csv exists csv\20240301\010500Z.csv
# csv exists csv\20240301\010815Z.csv
# csv exists csv\20240301\010640Z.csv
# csv exists csv\20240301\010820Z.csv
# csv exists csv\20240301\010825Z.csv
# csv exists csv\20240301\010830Z.csv
# csv exists csv\20240301\011005Z.csv
# csv exists csv\20240301\011010Z.csv
# csv exists csv\20240301\010550Z.csv
# csv exists csv\20240301\010850Z.csv
# csv exists csv\20240301\010855Z.csv
# csv exists csv\20240301\011025Z.csv
# csv exists csv\20240301\010900Z.csv
# csv exists csv\20240301\011035Z.csv
# csv exists csv\20240301\011045Z.csv
# csv exists csv\20240301\010920Z.csv
# csv exists csv\20240301\011055Z.csv
# csv exists csv\20240301\010930Z.csv
# csv exists csv\20240301\011100Z.csv
# csv exists csv\20240301\010940Z.csv
# csv exists csv\20240301\010945Z.csv
# csv exists csv\20240301\010950Z.csv
# csv exists csv\20240301\010955Z.csv
# csv exists csv\20240301\011000Z.csv
# csv exists csv\20240301\010835Z.csv
# csv exists csv\20240301\011015Z.csv
# csv exists csv\20240301\010840Z.csv
# csv exists csv\20240301\011145Z.csv
# csv exists csv\20240301\011150Z.csv
# csv exists csv\20240301\011155Z.csv
# csv exists csv\20240301\011135Z.csv
# csv exists csv\20240301\010905Z.csv
# csv exists csv\20240301\011050Z.csv
# csv exists csv\20240301\010910Z.csv
# csv exists csv\20240301\010925Z.csv
# csv exists csv\20240301\011235Z.csv
# csv exists csv\20240301\011040Z.csv
# csv exists csv\20240301\011110Z.csv
# csv exists csv\20240301\011240Z.csv
# csv exists csv\20240301\011105Z.csv
# csv exists csv\20240301\011120Z.csv
# csv exists csv\20240301\011130Z.csv
# csv exists csv\20240301\011125Z.csv
# csv exists csv\20240301\011140Z.csv
# csv exists csv\20240301\011310Z.csv
# csv exists csv\20240301\010915Z.csv
# csv exists csv\20240301\011205Z.csv
# csv exists csv\20240301\011020Z.csv
# csv exists csv\20240301\011030Z.csv
# csv exists csv\20240301\011340Z.csv
# csv exists csv\20240301\011350Z.csv
# csv exists csv\20240301\011215Z.csv
# csv exists csv\20240301\011355Z.csv
# csv exists csv\20240301\011225Z.csv
# csv exists csv\20240301\010935Z.csv
# csv exists csv\20240301\011410Z.csv
# csv exists csv\20240301\011415Z.csv
# csv exists csv\20240301\011250Z.csv
# csv exists csv\20240301\011255Z.csv
# csv exists csv\20240301\011430Z.csv
# csv exists csv\20240301\011425Z.csv
# csv exists csv\20240301\011435Z.csv
# csv exists csv\20240301\011445Z.csv
# csv exists csv\20240301\011320Z.csv
# csv exists csv\20240301\011500Z.csv
# csv exists csv\20240301\011330Z.csv
# csv exists csv\20240301\011335Z.csv
# csv exists csv\20240301\011210Z.csv
# csv exists csv\20240301\011515Z.csv
# csv exists csv\20240301\011520Z.csv
# csv exists csv\20240301\011400Z.csv
# csv exists csv\20240301\011525Z.csv
# csv exists csv\20240301\011230Z.csv
# csv exists csv\20240301\011540Z.csv
# csv exists csv\20240301\011545Z.csv
# csv exists csv\20240301\011550Z.csv
# csv exists csv\20240301\011300Z.csv
# csv exists csv\20240301\011440Z.csv
# csv exists csv\20240301\011305Z.csv
# csv exists csv\20240301\011610Z.csv
# csv exists csv\20240301\011200Z.csv
# csv exists csv\20240301\011315Z.csv
# csv exists csv\20240301\011455Z.csv
# csv exists csv\20240301\011325Z.csv
# csv exists csv\20240301\011505Z.csv
# csv exists csv\20240301\011635Z.csv
# csv exists csv\20240301\011640Z.csv
# csv exists csv\20240301\011650Z.csv
# csv exists csv\20240301\011220Z.csv
# csv exists csv\20240301\011405Z.csv
# csv exists csv\20240301\011535Z.csv
# csv exists csv\20240301\011710Z.csv
# csv exists csv\20240301\011705Z.csv
# csv exists csv\20240301\011245Z.csv
# csv exists csv\20240301\011555Z.csv
# csv exists csv\20240301\011600Z.csv
# csv exists csv\20240301\011615Z.csv
# csv exists csv\20240301\011450Z.csv
# csv exists csv\20240301\011605Z.csv
# csv exists csv\20240301\011750Z.csv
# csv exists csv\20240301\011625Z.csv
# csv exists csv\20240301\011755Z.csv
# csv exists csv\20240301\011510Z.csv
# csv exists csv\20240301\011645Z.csv
# csv exists csv\20240301\011345Z.csv
# csv exists csv\20240301\011700Z.csv
# csv exists csv\20240301\011530Z.csv
# csv exists csv\20240301\011655Z.csv
# csv exists csv\20240301\011830Z.csv
# csv exists csv\20240301\011420Z.csv
# csv exists csv\20240301\011715Z.csv
# csv exists csv\20240301\011720Z.csv
# csv exists csv\20240301\011725Z.csv
# csv exists csv\20240301\011730Z.csv
# csv exists csv\20240301\011735Z.csv
# csv exists csv\20240301\011740Z.csv
# csv exists csv\20240301\011905Z.csv
# csv exists csv\20240301\011620Z.csv
# csv exists csv\20240301\011630Z.csv
# csv exists csv\20240301\011925Z.csv
# csv exists csv\20240301\011805Z.csv
# csv exists csv\20240301\011940Z.csv
# csv exists csv\20240301\011820Z.csv
# csv exists csv\20240301\011815Z.csv
# csv exists csv\20240301\011945Z.csv
# csv exists csv\20240301\011835Z.csv
# csv exists csv\20240301\011115Z.csv
# csv exists csv\20240301\011840Z.csv
# csv exists csv\20240301\011845Z.csv
# csv exists csv\20240301\011850Z.csv
# csv exists csv\20240301\011855Z.csv
# csv exists csv\20240301\011900Z.csv
# csv exists csv\20240301\012035Z.csv
# csv exists csv\20240301\011745Z.csv
# csv exists csv\20240301\011915Z.csv
# csv exists csv\20240301\011920Z.csv
# csv exists csv\20240301\011800Z.csv
# csv exists csv\20240301\011930Z.csv
# csv exists csv\20240301\011935Z.csv
# csv exists csv\20240301\011810Z.csv
# csv exists csv\20240301\011950Z.csv
# csv exists csv\20240301\011825Z.csv
# csv exists csv\20240301\011955Z.csv
# csv exists csv\20240301\012000Z.csv
# csv exists csv\20240301\012005Z.csv
# csv exists csv\20240301\012010Z.csv
# csv exists csv\20240301\012015Z.csv
# csv exists csv\20240301\012020Z.csv
# csv exists csv\20240301\012025Z.csv
# csv exists csv\20240301\012155Z.csv
# csv exists csv\20240301\012030Z.csv
# csv exists csv\20240301\012205Z.csv
# csv exists csv\20240301\012040Z.csv
# csv exists csv\20240301\012050Z.csv
# csv exists csv\20240301\012055Z.csv
# csv exists csv\20240301\012100Z.csv
# csv exists csv\20240301\012105Z.csv
# csv exists csv\20240301\012110Z.csv
# csv exists csv\20240301\012115Z.csv
# csv exists csv\20240301\012245Z.csv
# csv exists csv\20240301\012250Z.csv
# csv exists csv\20240301\012255Z.csv
# csv exists csv\20240301\012135Z.csv
# csv exists csv\20240301\012140Z.csv
# csv exists csv\20240301\012145Z.csv
# csv exists csv\20240301\012200Z.csv
# csv exists csv\20240301\012150Z.csv
# csv exists csv\20240301\011910Z.csv
# csv exists csv\20240301\012045Z.csv
# csv exists csv\20240301\012210Z.csv
# csv exists csv\20240301\012340Z.csv
# csv exists csv\20240301\012215Z.csv
# csv exists csv\20240301\012355Z.csv
# csv exists csv\20240301\012230Z.csv
# csv exists csv\20240301\012235Z.csv
# csv exists csv\20240301\012240Z.csv
# csv exists csv\20240301\012400Z.csv
# csv exists csv\20240301\012420Z.csv
# csv exists csv\20240301\012130Z.csv
# csv exists csv\20240301\012300Z.csv
# csv exists csv\20240301\012305Z.csv
# csv exists csv\20240301\012310Z.csv
# csv exists csv\20240301\012440Z.csv
# csv exists csv\20240301\012450Z.csv
# csv exists csv\20240301\012330Z.csv
# csv exists csv\20240301\012455Z.csv
# csv exists csv\20240301\012335Z.csv
# csv exists csv\20240301\012345Z.csv
# csv exists csv\20240301\012220Z.csv
# csv exists csv\20240301\012350Z.csv
# csv exists csv\20240301\012225Z.csv
# csv exists csv\20240301\012405Z.csv
# csv exists csv\20240301\012410Z.csv
# csv exists csv\20240301\012535Z.csv
# csv exists csv\20240301\012545Z.csv
# csv exists csv\20240301\012125Z.csv
# csv exists csv\20240301\012550Z.csv
# csv exists csv\20240301\012425Z.csv
# csv exists csv\20240301\012435Z.csv
# csv exists csv\20240301\012445Z.csv
# csv exists csv\20240301\012315Z.csv
# csv exists csv\20240301\012320Z.csv
# csv exists csv\20240301\012625Z.csv
# csv exists csv\20240301\012325Z.csv
# csv exists csv\20240301\012505Z.csv
# csv exists csv\20240301\012510Z.csv
# csv exists csv\20240301\012515Z.csv
# csv exists csv\20240301\012520Z.csv
# csv exists csv\20240301\012650Z.csv
# csv exists csv\20240301\012530Z.csv
# csv exists csv\20240301\012540Z.csv
# csv exists csv\20240301\012715Z.csv
# csv exists csv\20240301\012415Z.csv
# csv exists csv\20240301\012555Z.csv
# csv exists csv\20240301\012430Z.csv
# csv exists csv\20240301\012600Z.csv
# csv exists csv\20240301\012605Z.csv
# csv exists csv\20240301\012735Z.csv
# csv exists csv\20240301\012615Z.csv
# csv exists csv\20240301\012620Z.csv
# csv exists csv\20240301\012500Z.csv
# csv exists csv\20240301\012635Z.csv
# csv exists csv\20240301\012640Z.csv
# csv exists csv\20240301\012630Z.csv
# csv exists csv\20240301\012645Z.csv
# csv exists csv\20240301\012525Z.csv
# csv exists csv\20240301\012655Z.csv
# csv exists csv\20240301\012700Z.csv
# csv exists csv\20240301\012705Z.csv
# csv exists csv\20240301\012840Z.csv
# csv exists csv\20240301\012710Z.csv
# csv exists csv\20240301\012720Z.csv
# csv exists csv\20240301\012725Z.csv
# csv exists csv\20240301\012730Z.csv
# csv exists csv\20240301\012740Z.csv
# csv exists csv\20240301\012610Z.csv
# csv exists csv\20240301\012745Z.csv
# csv exists csv\20240301\012750Z.csv
# csv exists csv\20240301\012755Z.csv
# csv exists csv\20240301\012800Z.csv
# csv exists csv\20240301\012935Z.csv
# csv exists csv\20240301\012810Z.csv
# csv exists csv\20240301\012815Z.csv
# csv exists csv\20240301\012820Z.csv
# csv exists csv\20240301\012950Z.csv
# csv exists csv\20240301\012830Z.csv
# csv exists csv\20240301\012835Z.csv
# csv exists csv\20240301\012120Z.csv
# csv exists csv\20240301\012845Z.csv
# csv exists csv\20240301\012850Z.csv
# csv exists csv\20240301\012855Z.csv
# csv exists csv\20240301\012900Z.csv
# csv exists csv\20240301\012905Z.csv
# csv exists csv\20240301\012910Z.csv
# csv exists csv\20240301\012915Z.csv
# csv exists csv\20240301\012920Z.csv
# csv exists csv\20240301\012925Z.csv
# csv exists csv\20240301\012805Z.csv
# csv exists csv\20240301\013100Z.csv
# csv exists csv\20240301\013105Z.csv
# csv exists csv\20240301\013110Z.csv
# csv exists csv\20240301\013115Z.csv
# csv exists csv\20240301\012955Z.csv
# csv exists csv\20240301\013000Z.csv
# csv exists csv\20240301\013135Z.csv
# csv exists csv\20240301\013005Z.csv
# csv exists csv\20240301\013015Z.csv
# csv exists csv\20240301\013020Z.csv
# csv exists csv\20240301\013025Z.csv
# csv exists csv\20240301\013030Z.csv
# csv exists csv\20240301\013035Z.csv
# csv exists csv\20240301\013040Z.csv
# csv exists csv\20240301\013045Z.csv
# csv exists csv\20240301\013050Z.csv
# csv exists csv\20240301\013215Z.csv
# csv exists csv\20240301\012930Z.csv
# csv exists csv\20240301\012940Z.csv
# csv exists csv\20240301\013235Z.csv
# csv exists csv\20240301\013125Z.csv
# csv exists csv\20240301\012945Z.csv
# csv exists csv\20240301\012825Z.csv
# csv exists csv\20240301\013300Z.csv
# csv exists csv\20240301\013305Z.csv
# csv exists csv\20240301\013010Z.csv
# csv exists csv\20240301\013145Z.csv
# csv exists csv\20240301\013150Z.csv
# csv exists csv\20240301\013155Z.csv
# csv exists csv\20240301\013200Z.csv
# csv exists csv\20240301\013205Z.csv
# csv exists csv\20240301\013210Z.csv
# csv exists csv\20240301\013220Z.csv
# csv exists csv\20240301\013225Z.csv
# csv exists csv\20240301\013055Z.csv
# csv exists csv\20240301\013350Z.csv
# csv exists csv\20240301\013230Z.csv
# csv exists csv\20240301\013405Z.csv
# csv exists csv\20240301\013245Z.csv
# csv exists csv\20240301\013250Z.csv
# csv exists csv\20240301\013255Z.csv
# csv exists csv\20240301\013425Z.csv
# csv exists csv\20240301\013140Z.csv
# csv exists csv\20240301\013310Z.csv
# csv exists csv\20240301\013315Z.csv
# csv exists csv\20240301\013320Z.csv
# csv exists csv\20240301\013455Z.csv
# csv exists csv\20240301\013330Z.csv
# csv exists csv\20240301\013340Z.csv
# csv exists csv\20240301\013500Z.csv
# csv exists csv\20240301\013335Z.csv
# csv exists csv\20240301\013515Z.csv
# csv exists csv\20240301\013520Z.csv
# csv exists csv\20240301\013525Z.csv
# csv exists csv\20240301\013530Z.csv
# csv exists csv\20240301\013535Z.csv
# csv exists csv\20240301\013410Z.csv
# csv exists csv\20240301\013550Z.csv
# csv exists csv\20240301\013430Z.csv
# csv exists csv\20240301\013600Z.csv
# csv exists csv\20240301\013435Z.csv
# csv exists csv\20240301\013440Z.csv
# csv exists csv\20240301\013445Z.csv
# csv exists csv\20240301\013450Z.csv
# csv exists csv\20240301\013325Z.csv
# csv exists csv\20240301\013505Z.csv
# csv exists csv\20240301\013510Z.csv
# csv exists csv\20240301\013345Z.csv
# csv exists csv\20240301\013645Z.csv
# csv exists csv\20240301\013400Z.csv
# csv exists csv\20240301\013650Z.csv
# csv exists csv\20240301\013700Z.csv
# csv exists csv\20240301\013415Z.csv
# csv exists csv\20240301\013710Z.csv
# csv exists csv\20240301\013705Z.csv
# csv exists csv\20240301\013720Z.csv
# csv exists csv\20240301\013555Z.csv
# csv exists csv\20240301\013730Z.csv
# csv exists csv\20240301\013725Z.csv
# csv exists csv\20240301\013740Z.csv
# csv exists csv\20240301\013745Z.csv
# csv exists csv\20240301\013620Z.csv
# csv exists csv\20240301\013755Z.csv
# csv exists csv\20240301\013630Z.csv
# csv exists csv\20240301\013635Z.csv
# csv exists csv\20240301\013640Z.csv
# csv exists csv\20240301\013355Z.csv
# csv exists csv\20240301\013820Z.csv
# csv exists csv\20240301\013655Z.csv
# csv exists csv\20240301\013825Z.csv
# csv exists csv\20240301\013540Z.csv
# csv exists csv\20240301\013715Z.csv
# csv exists csv\20240301\013840Z.csv
# csv exists csv\20240301\013420Z.csv
# csv exists csv\20240301\013605Z.csv
# csv exists csv\20240301\013130Z.csv
# csv exists csv\20240301\013735Z.csv
# csv exists csv\20240301\013610Z.csv
# csv exists csv\20240301\013910Z.csv
# csv exists csv\20240301\013750Z.csv
# csv exists csv\20240301\013800Z.csv
# csv exists csv\20240301\013625Z.csv
# csv exists csv\20240301\013930Z.csv
# csv exists csv\20240301\013935Z.csv
# csv exists csv\20240301\013815Z.csv
# csv exists csv\20240301\013120Z.csv
# csv exists csv\20240301\014000Z.csv
# csv exists csv\20240301\013835Z.csv
# csv exists csv\20240301\013845Z.csv
# csv exists csv\20240301\013545Z.csv
# csv exists csv\20240301\013850Z.csv
# csv exists csv\20240301\013900Z.csv
# csv exists csv\20240301\013855Z.csv
# csv exists csv\20240301\013905Z.csv
# csv exists csv\20240301\013920Z.csv
# csv exists csv\20240301\013615Z.csv
# csv exists csv\20240301\013925Z.csv
# csv exists csv\20240301\013915Z.csv
# csv exists csv\20240301\013940Z.csv
# csv exists csv\20240301\014055Z.csv
# csv exists csv\20240301\014100Z.csv
# csv exists csv\20240301\013945Z.csv
# csv exists csv\20240301\014105Z.csv
# csv exists csv\20240301\013950Z.csv
# csv exists csv\20240301\014125Z.csv
# csv exists csv\20240301\013240Z.csv
# csv exists csv\20240301\014135Z.csv
# csv exists csv\20240301\014015Z.csv
# csv exists csv\20240301\014010Z.csv
# csv exists csv\20240301\014020Z.csv
# csv exists csv\20240301\014025Z.csv
# csv exists csv\20240301\014155Z.csv
# csv exists csv\20240301\014040Z.csv
# csv exists csv\20240301\014210Z.csv
# csv exists csv\20240301\014205Z.csv
# csv exists csv\20240301\014220Z.csv
# csv exists csv\20240301\013810Z.csv
# csv exists csv\20240301\013805Z.csv
# csv exists csv\20240301\014110Z.csv
# csv exists csv\20240301\014235Z.csv
# csv exists csv\20240301\014115Z.csv
# csv exists csv\20240301\014120Z.csv
# csv exists csv\20240301\014130Z.csv
# csv exists csv\20240301\014300Z.csv
# csv exists csv\20240301\014005Z.csv
# csv exists csv\20240301\014145Z.csv
# csv exists csv\20240301\014315Z.csv
# csv exists csv\20240301\014140Z.csv
# csv exists csv\20240301\014200Z.csv
# csv exists csv\20240301\014030Z.csv
# csv exists csv\20240301\014045Z.csv
# csv exists csv\20240301\014035Z.csv
# csv exists csv\20240301\014050Z.csv
# csv exists csv\20240301\014350Z.csv
# csv exists csv\20240301\014225Z.csv
# csv exists csv\20240301\014230Z.csv
# csv exists csv\20240301\014240Z.csv
# csv exists csv\20240301\013830Z.csv
# csv exists csv\20240301\014415Z.csv
# csv exists csv\20240301\014250Z.csv
# csv exists csv\20240301\014255Z.csv
# csv exists csv\20240301\013955Z.csv
# csv exists csv\20240301\014430Z.csv
# csv exists csv\20240301\014435Z.csv
# csv exists csv\20240301\014440Z.csv
# csv exists csv\20240301\014445Z.csv
# csv exists csv\20240301\014325Z.csv
# csv exists csv\20240301\014340Z.csv
# csv exists csv\20240301\014345Z.csv
# csv exists csv\20240301\014330Z.csv
# csv exists csv\20240301\014335Z.csv
# csv exists csv\20240301\014510Z.csv
# csv exists csv\20240301\014400Z.csv
# csv exists csv\20240301\014405Z.csv
# csv exists csv\20240301\014355Z.csv
# csv exists csv\20240301\014410Z.csv
# csv exists csv\20240301\014245Z.csv
# csv exists csv\20240301\014420Z.csv
# csv exists csv\20240301\014425Z.csv
# csv exists csv\20240301\014305Z.csv
# csv exists csv\20240301\014310Z.csv
# csv exists csv\20240301\014610Z.csv
# csv exists csv\20240301\014320Z.csv
# csv exists csv\20240301\014620Z.csv
# csv exists csv\20240301\014615Z.csv
# csv exists csv\20240301\014500Z.csv
# csv exists csv\20240301\014505Z.csv
# csv exists csv\20240301\014515Z.csv
# csv exists csv\20240301\014215Z.csv
# csv exists csv\20240301\014520Z.csv
# csv exists csv\20240301\014525Z.csv
# csv exists csv\20240301\014655Z.csv
# csv exists csv\20240301\014535Z.csv
# csv exists csv\20240301\014540Z.csv
# csv exists csv\20240301\014545Z.csv
# csv exists csv\20240301\014550Z.csv
# csv exists csv\20240301\014555Z.csv
# csv exists csv\20240301\014725Z.csv
# csv exists csv\20240301\014605Z.csv
# csv exists csv\20240301\014150Z.csv
# csv exists csv\20240301\014450Z.csv
# csv exists csv\20240301\014455Z.csv
# csv exists csv\20240301\014625Z.csv
# csv exists csv\20240301\014630Z.csv
# csv exists csv\20240301\014635Z.csv
# csv exists csv\20240301\014640Z.csv
# csv exists csv\20240301\014645Z.csv
# csv exists csv\20240301\014815Z.csv
# csv exists csv\20240301\014820Z.csv
# csv exists csv\20240301\014700Z.csv
# csv exists csv\20240301\014705Z.csv
# csv exists csv\20240301\014710Z.csv
# csv exists csv\20240301\014715Z.csv
# csv exists csv\20240301\014720Z.csv
# csv exists csv\20240301\014730Z.csv
# csv exists csv\20240301\014900Z.csv
# csv exists csv\20240301\014735Z.csv
# csv exists csv\20240301\014905Z.csv
# csv exists csv\20240301\014910Z.csv
# csv exists csv\20240301\014750Z.csv
# csv exists csv\20240301\014745Z.csv
# csv exists csv\20240301\014755Z.csv
# csv exists csv\20240301\014800Z.csv
# csv exists csv\20240301\014805Z.csv
# csv exists csv\20240301\014810Z.csv
# csv exists csv\20240301\014650Z.csv
# csv exists csv\20240301\014530Z.csv
# csv exists csv\20240301\014825Z.csv
# csv exists csv\20240301\014830Z.csv
# csv exists csv\20240301\014835Z.csv
# csv exists csv\20240301\014840Z.csv
# csv exists csv\20240301\015015Z.csv
# csv exists csv\20240301\014850Z.csv
# csv exists csv\20240301\015025Z.csv
# csv exists csv\20240301\015030Z.csv
# csv exists csv\20240301\014740Z.csv
# csv exists csv\20240301\014915Z.csv
# csv exists csv\20240301\014920Z.csv
# csv exists csv\20240301\014925Z.csv
# csv exists csv\20240301\014930Z.csv
# csv exists csv\20240301\014935Z.csv
# csv exists csv\20240301\015105Z.csv
# csv exists csv\20240301\014945Z.csv
# csv exists csv\20240301\014950Z.csv
# csv exists csv\20240301\014955Z.csv
# csv exists csv\20240301\015000Z.csv
# csv exists csv\20240301\015005Z.csv
# csv exists csv\20240301\015010Z.csv
# csv exists csv\20240301\014845Z.csv
# csv exists csv\20240301\015145Z.csv
# csv exists csv\20240301\014855Z.csv
# csv exists csv\20240301\014600Z.csv
# csv exists csv\20240301\015035Z.csv
# csv exists csv\20240301\015205Z.csv
# csv exists csv\20240301\015045Z.csv
# csv exists csv\20240301\015050Z.csv
# csv exists csv\20240301\015055Z.csv
# csv exists csv\20240301\015100Z.csv
# ...
# 2024-03-01 23:39:40
# Joined csv\20240301\233940Z.csv
# 2024-03-01 23:39:45
# Joined csv\20240301\233945Z.csv
# 2024-03-01 23:39:50
# Joined csv\20240301\233950Z.csv
# 2024-03-01 23:39:55
# Joined csv\20240301\233955Z.csv
# 2024-03-01 23:40:00
# Joined csv\20240301\234000Z.csv
# 2024-03-01 23:40:05
# Joined csv\20240301\234005Z.csv
# 2024-03-01 23:40:10
# Joined csv\20240301\234010Z.csv
# 2024-03-01 23:40:15
# Joined csv\20240301\234015Z.csv
# 2024-03-01 23:40:20
# Joined csv\20240301\234020Z.csv
# 2024-03-01 23:40:25
# Joined csv\20240301\234025Z.csv
# 2024-03-01 23:40:30
# Joined csv\20240301\234030Z.csv
# 2024-03-01 23:40:35
# Joined csv\20240301\234035Z.csv
# 2024-03-01 23:40:40
# Joined csv\20240301\234040Z.csv
# 2024-03-01 23:40:45
# Joined csv\20240301\234045Z.csv
# 2024-03-01 23:40:50
# Joined csv\20240301\234050Z.csv
# 2024-03-01 23:40:55
# Joined csv\20240301\234055Z.csv
# 2024-03-01 23:41:00
# Joined csv\20240301\234100Z.csv
# 2024-03-01 23:41:05
# Joined csv\20240301\234105Z.csv
# 2024-03-01 23:41:10
# Joined csv\20240301\234110Z.csv
# 2024-03-01 23:41:15
# Joined csv\20240301\234115Z.csv
# 2024-03-01 23:41:20
# Joined csv\20240301\234120Z.csv
# 2024-03-01 23:41:25
# Joined csv\20240301\234125Z.csv
# 2024-03-01 23:41:30
# Joined csv\20240301\234130Z.csv
# 2024-03-01 23:41:35
# Joined csv\20240301\234135Z.csv
# 2024-03-01 23:41:40
# Joined csv\20240301\234140Z.csv
# 2024-03-01 23:41:45
# Joined csv\20240301\234145Z.csv
# 2024-03-01 23:41:50
# Joined csv\20240301\234150Z.csv
# 2024-03-01 23:41:55
# Joined csv\20240301\234155Z.csv
# 2024-03-01 23:42:00
# Joined csv\20240301\234200Z.csv
# 2024-03-01 23:42:05
# Joined csv\20240301\234205Z.csv
# 2024-03-01 23:42:10
# Joined csv\20240301\234210Z.csv
# 2024-03-01 23:42:15
# Joined csv\20240301\234215Z.csv
# 2024-03-01 23:42:20
# Joined csv\20240301\234220Z.csv
# 2024-03-01 23:42:25
# Joined csv\20240301\234225Z.csv
# 2024-03-01 23:42:30
# Joined csv\20240301\234230Z.csv
# 2024-03-01 23:42:35
# Joined csv\20240301\234235Z.csv
# 2024-03-01 23:42:40
# Joined csv\20240301\234240Z.csv
# 2024-03-01 23:42:45
# Joined csv\20240301\234245Z.csv
# 2024-03-01 23:42:50
# Joined csv\20240301\234250Z.csv
# 2024-03-01 23:42:55
# Joined csv\20240301\234255Z.csv
# 2024-03-01 23:43:00
# Joined csv\20240301\234300Z.csv
# 2024-03-01 23:43:05
# Joined csv\20240301\234305Z.csv
# 2024-03-01 23:43:10
# Joined csv\20240301\234310Z.csv
# 2024-03-01 23:43:15
# Joined csv\20240301\234315Z.csv
# 2024-03-01 23:43:20
# Joined csv\20240301\234320Z.csv
# 2024-03-01 23:43:25
# Joined csv\20240301\234325Z.csv
# 2024-03-01 23:43:30
# Joined csv\20240301\234330Z.csv
# 2024-03-01 23:43:35
# Joined csv\20240301\234335Z.csv
# 2024-03-01 23:43:40
# Joined csv\20240301\234340Z.csv
# 2024-03-01 23:43:45
# Joined csv\20240301\234345Z.csv
# 2024-03-01 23:43:50
# Joined csv\20240301\234350Z.csv
# 2024-03-01 23:43:55
# Joined csv\20240301\234355Z.csv
# 2024-03-01 23:44:00
# Joined csv\20240301\234400Z.csv
# 2024-03-01 23:44:05
# Joined csv\20240301\234405Z.csv
# 2024-03-01 23:44:10
# Joined csv\20240301\234410Z.csv
# 2024-03-01 23:44:15
# Joined csv\20240301\234415Z.csv
# 2024-03-01 23:44:20
# Joined csv\20240301\234420Z.csv
# 2024-03-01 23:44:25
# Joined csv\20240301\234425Z.csv
# 2024-03-01 23:44:30
# Joined csv\20240301\234430Z.csv
# 2024-03-01 23:44:35
# Joined csv\20240301\234435Z.csv
# 2024-03-01 23:44:40
# Joined csv\20240301\234440Z.csv
# 2024-03-01 23:44:45
# Joined csv\20240301\234445Z.csv
# 2024-03-01 23:44:50
# Joined csv\20240301\234450Z.csv
# 2024-03-01 23:44:55
# Joined csv\20240301\234455Z.csv
# 2024-03-01 23:45:00
# Joined csv\20240301\234500Z.csv
# 2024-03-01 23:45:05
# Joined csv\20240301\234505Z.csv
# 2024-03-01 23:45:10
# Joined csv\20240301\234510Z.csv
# 2024-03-01 23:45:15
# Joined csv\20240301\234515Z.csv
# 2024-03-01 23:45:20
# Joined csv\20240301\234520Z.csv
# 2024-03-01 23:45:25
# Joined csv\20240301\234525Z.csv
# 2024-03-01 23:45:30
# Joined csv\20240301\234530Z.csv
# 2024-03-01 23:45:35
# Joined csv\20240301\234535Z.csv
# 2024-03-01 23:45:40
# Joined csv\20240301\234540Z.csv
# 2024-03-01 23:45:45
# Joined csv\20240301\234545Z.csv
# 2024-03-01 23:45:50
# Joined csv\20240301\234550Z.csv
# 2024-03-01 23:45:55
# Joined csv\20240301\234555Z.csv
# 2024-03-01 23:46:00
# Joined csv\20240301\234600Z.csv
# 2024-03-01 23:46:05
# Joined csv\20240301\234605Z.csv
# 2024-03-01 23:46:10
# Joined csv\20240301\234610Z.csv
# 2024-03-01 23:46:15
# Joined csv\20240301\234615Z.csv
# 2024-03-01 23:46:20
# Joined csv\20240301\234620Z.csv
# 2024-03-01 23:46:25
# Joined csv\20240301\234625Z.csv
# 2024-03-01 23:46:30
# Joined csv\20240301\234630Z.csv
# 2024-03-01 23:46:35
# Joined csv\20240301\234635Z.csv
# 2024-03-01 23:46:40
# Joined csv\20240301\234640Z.csv
# 2024-03-01 23:46:45
# Joined csv\20240301\234645Z.csv
# 2024-03-01 23:46:50
# Joined csv\20240301\234650Z.csv
# 2024-03-01 23:46:55
# Joined csv\20240301\234655Z.csv
# 2024-03-01 23:47:00
# Joined csv\20240301\234700Z.csv
# 2024-03-01 23:47:05
# Joined csv\20240301\234705Z.csv
# 2024-03-01 23:47:10
# Joined csv\20240301\234710Z.csv
# 2024-03-01 23:47:15
# Joined csv\20240301\234715Z.csv
# 2024-03-01 23:47:20
# Joined csv\20240301\234720Z.csv
# 2024-03-01 23:47:25
# Joined csv\20240301\234725Z.csv
# 2024-03-01 23:47:30
# Joined csv\20240301\234730Z.csv
# 2024-03-01 23:47:35
# Joined csv\20240301\234735Z.csv
# 2024-03-01 23:47:40
# Joined csv\20240301\234740Z.csv
# 2024-03-01 23:47:45
# Joined csv\20240301\234745Z.csv
# 2024-03-01 23:47:50
# Joined csv\20240301\234750Z.csv
# 2024-03-01 23:47:55
# Joined csv\20240301\234755Z.csv
# 2024-03-01 23:48:00
# Joined csv\20240301\234800Z.csv
# 2024-03-01 23:48:05
# Joined csv\20240301\234805Z.csv
# 2024-03-01 23:48:10
# Joined csv\20240301\234810Z.csv
# 2024-03-01 23:48:15
# Joined csv\20240301\234815Z.csv
# 2024-03-01 23:48:20
# Joined csv\20240301\234820Z.csv
# 2024-03-01 23:48:25
# Joined csv\20240301\234825Z.csv
# 2024-03-01 23:48:30
# Joined csv\20240301\234830Z.csv
# 2024-03-01 23:48:35
# Joined csv\20240301\234835Z.csv
# 2024-03-01 23:48:40
# Joined csv\20240301\234840Z.csv
# 2024-03-01 23:48:45
# Joined csv\20240301\234845Z.csv
# 2024-03-01 23:48:50
# Joined csv\20240301\234850Z.csv
# 2024-03-01 23:48:55
# Joined csv\20240301\234855Z.csv
# 2024-03-01 23:49:00
# Joined csv\20240301\234900Z.csv
# 2024-03-01 23:49:05
# Joined csv\20240301\234905Z.csv
# 2024-03-01 23:49:10
# Joined csv\20240301\234910Z.csv
# 2024-03-01 23:49:15
# Joined csv\20240301\234915Z.csv
# 2024-03-01 23:49:20
# Joined csv\20240301\234920Z.csv
# 2024-03-01 23:49:25
# Joined csv\20240301\234925Z.csv
# 2024-03-01 23:49:30
# Joined csv\20240301\234930Z.csv
# 2024-03-01 23:49:35
# Joined csv\20240301\234935Z.csv
# 2024-03-01 23:49:40
# Joined csv\20240301\234940Z.csv
# 2024-03-01 23:49:45
# Joined csv\20240301\234945Z.csv
# 2024-03-01 23:49:50
# Joined csv\20240301\234950Z.csv
# 2024-03-01 23:49:55
# Joined csv\20240301\234955Z.csv
# 2024-03-01 23:50:00
# Joined csv\20240301\235000Z.csv
# 2024-03-01 23:50:05
# Joined csv\20240301\235005Z.csv
# 2024-03-01 23:50:10
# Joined csv\20240301\235010Z.csv
# 2024-03-01 23:50:15
# Joined csv\20240301\235015Z.csv
# 2024-03-01 23:50:20
# Joined csv\20240301\235020Z.csv
# 2024-03-01 23:50:25
# Joined csv\20240301\235025Z.csv
# 2024-03-01 23:50:30
# Joined csv\20240301\235030Z.csv
# 2024-03-01 23:50:35
# Joined csv\20240301\235035Z.csv
# 2024-03-01 23:50:40
# Joined csv\20240301\235040Z.csv
# 2024-03-01 23:50:45
# Joined csv\20240301\235045Z.csv
# 2024-03-01 23:50:50
# Joined csv\20240301\235050Z.csv
# 2024-03-01 23:50:55
# Joined csv\20240301\235055Z.csv
# 2024-03-01 23:51:00
# Joined csv\20240301\235100Z.csv
# 2024-03-01 23:51:05
# Joined csv\20240301\235105Z.csv
# 2024-03-01 23:51:10
# Joined csv\20240301\235110Z.csv
# 2024-03-01 23:51:15
# Joined csv\20240301\235115Z.csv
# 2024-03-01 23:51:20
# Joined csv\20240301\235120Z.csv
# 2024-03-01 23:51:25
# Joined csv\20240301\235125Z.csv
# 2024-03-01 23:51:30
# Joined csv\20240301\235130Z.csv
# 2024-03-01 23:51:35
# Joined csv\20240301\235135Z.csv
# 2024-03-01 23:51:40
# Joined csv\20240301\235140Z.csv
# 2024-03-01 23:51:45
# Joined csv\20240301\235145Z.csv
# 2024-03-01 23:51:50
# Joined csv\20240301\235150Z.csv
# 2024-03-01 23:51:55
# Joined csv\20240301\235155Z.csv
# 2024-03-01 23:52:00
# Joined csv\20240301\235200Z.csv
# 2024-03-01 23:52:05
# Joined csv\20240301\235205Z.csv
# 2024-03-01 23:52:10
# Joined csv\20240301\235210Z.csv
# 2024-03-01 23:52:15
# Joined csv\20240301\235215Z.csv
# 2024-03-01 23:52:20
# Joined csv\20240301\235220Z.csv
# 2024-03-01 23:52:25
# Joined csv\20240301\235225Z.csv
# 2024-03-01 23:52:30
# Joined csv\20240301\235230Z.csv
# 2024-03-01 23:52:35
# Joined csv\20240301\235235Z.csv
# 2024-03-01 23:52:40
# Joined csv\20240301\235240Z.csv
# 2024-03-01 23:52:45
# Joined csv\20240301\235245Z.csv
# 2024-03-01 23:52:50
# Joined csv\20240301\235250Z.csv
# 2024-03-01 23:52:55
# Joined csv\20240301\235255Z.csv
# 2024-03-01 23:53:00
# Joined csv\20240301\235300Z.csv
# 2024-03-01 23:53:05
# Joined csv\20240301\235305Z.csv
# 2024-03-01 23:53:10
# Joined csv\20240301\235310Z.csv
# 2024-03-01 23:53:15
# Joined csv\20240301\235315Z.csv
# 2024-03-01 23:53:20
# Joined csv\20240301\235320Z.csv
# 2024-03-01 23:53:25
# Joined csv\20240301\235325Z.csv
# 2024-03-01 23:53:30
# Joined csv\20240301\235330Z.csv
# 2024-03-01 23:53:35
# Joined csv\20240301\235335Z.csv
# 2024-03-01 23:53:40
# Joined csv\20240301\235340Z.csv
# 2024-03-01 23:53:45
# Joined csv\20240301\235345Z.csv
# 2024-03-01 23:53:50
# Joined csv\20240301\235350Z.csv
# 2024-03-01 23:53:55
# Joined csv\20240301\235355Z.csv
# 2024-03-01 23:54:00
# Joined csv\20240301\235400Z.csv
# 2024-03-01 23:54:05
# Joined csv\20240301\235405Z.csv
# 2024-03-01 23:54:10
# Joined csv\20240301\235410Z.csv
# 2024-03-01 23:54:15
# Joined csv\20240301\235415Z.csv
# 2024-03-01 23:54:20
# Joined csv\20240301\235420Z.csv
# 2024-03-01 23:54:25
# Joined csv\20240301\235425Z.csv
# 2024-03-01 23:54:30
# Joined csv\20240301\235430Z.csv
# 2024-03-01 23:54:35
# Joined csv\20240301\235435Z.csv
# 2024-03-01 23:54:40
# Joined csv\20240301\235440Z.csv
# 2024-03-01 23:54:45
# Joined csv\20240301\235445Z.csv
# 2024-03-01 23:54:50
# Joined csv\20240301\235450Z.csv
# 2024-03-01 23:54:55
# Joined csv\20240301\235455Z.csv
# 2024-03-01 23:55:00
# Joined csv\20240301\235500Z.csv
# 2024-03-01 23:55:05
# Joined csv\20240301\235505Z.csv
# 2024-03-01 23:55:10
# Joined csv\20240301\235510Z.csv
# 2024-03-01 23:55:15
# Joined csv\20240301\235515Z.csv
# 2024-03-01 23:55:20
# Joined csv\20240301\235520Z.csv
# 2024-03-01 23:55:25
# Joined csv\20240301\235525Z.csv
# 2024-03-01 23:55:30
# Joined csv\20240301\235530Z.csv
# 2024-03-01 23:55:35
# Joined csv\20240301\235535Z.csv
# 2024-03-01 23:55:40
# Joined csv\20240301\235540Z.csv
# 2024-03-01 23:55:45
# Joined csv\20240301\235545Z.csv
# 2024-03-01 23:55:50
# Joined csv\20240301\235550Z.csv
# 2024-03-01 23:55:55
# Joined csv\20240301\235555Z.csv
# 2024-03-01 23:56:00
# Joined csv\20240301\235600Z.csv
# 2024-03-01 23:56:05
# Joined csv\20240301\235605Z.csv
# 2024-03-01 23:56:10
# Joined csv\20240301\235610Z.csv
# 2024-03-01 23:56:15
# Joined csv\20240301\235615Z.csv
# 2024-03-01 23:56:20
# Joined csv\20240301\235620Z.csv
# 2024-03-01 23:56:25
# Joined csv\20240301\235625Z.csv
# 2024-03-01 23:56:30
# Joined csv\20240301\235630Z.csv
# 2024-03-01 23:56:35
# Joined csv\20240301\235635Z.csv
# 2024-03-01 23:56:40
# Joined csv\20240301\235640Z.csv
# 2024-03-01 23:56:45
# Joined csv\20240301\235645Z.csv
# 2024-03-01 23:56:50
# Joined csv\20240301\235650Z.csv
# 2024-03-01 23:56:55
# Joined csv\20240301\235655Z.csv
# 2024-03-01 23:57:00
# Joined csv\20240301\235700Z.csv
# 2024-03-01 23:57:05
# Joined csv\20240301\235705Z.csv
# 2024-03-01 23:57:10
# Joined csv\20240301\235710Z.csv
# 2024-03-01 23:57:15
# Joined csv\20240301\235715Z.csv
# 2024-03-01 23:57:20
# Joined csv\20240301\235720Z.csv
# 2024-03-01 23:57:25
# Joined csv\20240301\235725Z.csv
# 2024-03-01 23:57:30
# Joined csv\20240301\235730Z.csv
# 2024-03-01 23:57:35
# Joined csv\20240301\235735Z.csv
# 2024-03-01 23:57:40
# Joined csv\20240301\235740Z.csv
# 2024-03-01 23:57:45
# Joined csv\20240301\235745Z.csv
# 2024-03-01 23:57:50
# Joined csv\20240301\235750Z.csv
# 2024-03-01 23:57:55
# Joined csv\20240301\235755Z.csv
# 2024-03-01 23:58:00
# Joined csv\20240301\235800Z.csv
# 2024-03-01 23:58:05
# Joined csv\20240301\235805Z.csv
# 2024-03-01 23:58:10
# Joined csv\20240301\235810Z.csv
# 2024-03-01 23:58:15
# Joined csv\20240301\235815Z.csv
# 2024-03-01 23:58:20
# Joined csv\20240301\235820Z.csv
# 2024-03-01 23:58:25
# Joined csv\20240301\235825Z.csv
# 2024-03-01 23:58:30
# Joined csv\20240301\235830Z.csv
# 2024-03-01 23:58:35
# Joined csv\20240301\235835Z.csv
# 2024-03-01 23:58:40
# Joined csv\20240301\235840Z.csv
# 2024-03-01 23:58:45
# Joined csv\20240301\235845Z.csv
# 2024-03-01 23:58:50
# Joined csv\20240301\235850Z.csv
# 2024-03-01 23:58:55
# Joined csv\20240301\235855Z.csv
# 2024-03-01 23:59:00
# Joined csv\20240301\235900Z.csv
# 2024-03-01 23:59:05
# Joined csv\20240301\235905Z.csv
# 2024-03-01 23:59:10
# Joined csv\20240301\235910Z.csv
# 2024-03-01 23:59:15
# Joined csv\20240301\235915Z.csv
# 2024-03-01 23:59:20
# Joined csv\20240301\235920Z.csv
# 2024-03-01 23:59:25
# Joined csv\20240301\235925Z.csv
# 2024-03-01 23:59:30
# Joined csv\20240301\235930Z.csv
# 2024-03-01 23:59:35
# Joined csv\20240301\235935Z.csv
# 2024-03-01 23:59:40
# Joined csv\20240301\235940Z.csv
# 2024-03-01 23:59:45
# Joined csv\20240301\235945Z.csv
# 2024-03-01 23:59:50
# Joined csv\20240301\235950Z.csv
# 2024-03-01 23:59:55
# Joined csv\20240301\235955Z.csv
# Saved csv\20240301\235955Z.csv
# Converting csv to parquet
# Conversion progress: 110
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 540
#     533         create_choropleth_map(data="percentage_bad", limits = [0,0.1,0.5,1], lat=hex_list[0][0], lon=hex_list[0][1], hex_list=hex_list)
#     536 # note that for the free sample, only the first day of each month is available on the adsbexchange
#     537 # 4 hours + to download 1 day of files
#     538 # 18 mins to reload
# --> 540 [df1, flights_data, df2] = process_data(dt.datetime(2024,3,1,0,0,0),dt.datetime(2024,3,2,0,0,0), reload=[False, False, False])
#
# Cell In[3], line 220, in process_data(start_date_time, end_date_time, reload)
#     217         print("Thread Pool: An error occurred:", e)
#     219     join_large_file(os.path.join('csv',start_date_time.strftime("%Y%m%d")),start_date_time,end_date_time,file_path)
# --> 220     csv_to_parquet(start_date_time, filetype = FileType.JOINED)
#     222 df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True)
#     224 flights_data = get_flight_data(start_date_time) if not reload[1] else load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)
#
# Cell In[3], line 302, in csv_to_parquet(start_date_time, filetype)
#     300     sys.stdout.write("Conversion progress: %d   \r" % (i) )
#     301     sys.stdout.flush()
# --> 302     parquet_writer = pd.concat([parquet_writer,chunk])
#     303 parquet_writer.to_parquet(parquet_path)
#     304 display(f"{parquet_path}")
#
# File c:\Users\ernes\Raid\flight-data\venv\lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File c:\Users\ernes\Raid\flight-data\venv\lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File c:\Users\ernes\Raid\flight-data\venv\lib\site-packages\pandas\core\internals\concat.py:177, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     167 vals = [ju.block.values for ju in join_units]
#     169 if not blk.is_extension:
#     170     # _is_uniform_join_units ensures a single dtype, so
#     171     #  we can use np.concatenate, which is more performant
#    (...)
#     175     # expected "Union[_SupportsArray[dtype[Any]],
#     176     # _NestedSequence[_SupportsArray[dtype[Any]]]]"
# --> 177     values = np.concatenate(vals, axis=1)  # type: ignore[arg-type]
#     178 elif is_1d_only_ea_dtype(blk.dtype):
#     179     # TODO(EA2D): special-casing not needed with 2D EAs
#     180     values = concat_compat(vals, axis=0, ea_compat_axis=True)
#
# MemoryError: Unable to allocate 7.44 GiB for an array with shape (9, 111000000) and data type float64

# %%
save_df(df2, filetype=FileType.HEXBIN, parquet=True)

# %%
# Generate Plots For Sampled Flights, Alt/NIC vs Time
# start_date_time = dt.datetime(2024,4,1,0,0,0)
# df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True)
# flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)
# display(flights_data['result'].value_counts())

# > 0.9: Equipment Failure
# Between 0.1 and 0.9: Analyse
# < 0.1: Normal
# generate_plots(5, group=ResultGroup.NORMAL)
generate_plots(5, group=ResultGroup.ANALYSE)
# generate_plots(5, group=ResultGroup.EQUIPMENT_FAILURE)

# %%
# Plot correlations
# start_date_time = dt.datetime(2024,4,1,0,0,0)
# df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True)
# flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)

generate_correlations(20, group = ResultGroup.ANALYSE)

# %%
display(df2.head(10))

# %%
start_date_time = dt.datetime(2024,4,1,0,0,0)
df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True) if isinstance(df1, type(None)) else df1
flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True) if isinstance(flights_data, type(None)) else flights_data

sample = flights_data[flights_data["result"]==ResultGroup.ANALYSE].sample(5)
sample_df=None
display(sample.head(5))
for flight in sample["flight"]:
    sample_df = pd.concat([sample_df,df1[df1["flight"]==flight]])
display(sample_df[(sample_df["flight"].isin(sample["flight"])) & sample_df['lat'].isnull()])
sample_df2 = calculate_hexagon_ids(sample_df[sample_df["flight"].isin(sample["flight"])])
sample_df2=sample_df2[~sample_df2['lat'].isnull()]
display(sample_df2[sample_df2['lat'].isnull()])

# %%
# Plot Hex Map

start_date_time = dt.datetime(2024,4,1,0,0,0)
df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True) if isinstance(df1, type(None)) else df1
# display(df1.head(5))
print("Get hexagon df")
df2 = load_df(start_date_time, filetype=FileType.HEXBIN, parquet=True) if isinstance(df2, type(None)) else df2
df2 = df2[df2["Hexagon_ID"]!="NA"]
display(df2.tail(5))
print(f"df2: {df2.shape[0]}")
# save_df(df2, start_date_time, filetype=FileType.HEXBIN, parquet=True)
flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True) if isinstance(flights_data, type(None)) else flights_data
# display(flights_data.head(5))

# %%
# coordinates of all the suspected GPS jammed hexagons
coord_list = [[33.81825, 35.49082],[30.0842, 31.35159]]
#convert to hexagon_ID
hex_list = [h3.geo_to_h3(coord[0], coord[1], resolution=resolution) for coord in coord_list]
print(hex_list)

# extract flights that pass through those hexagons
flights_df = get_flights_with_hex_list(hex_list) if isinstance(flights_df, type(None)) else flights_df

create_choropleth_map(data="percentage_bad", limits = [0,0.1,0.5,1], lat=coord_list[0][0], lon=coord_list[0][1], hex_list=hex_list)

# %%
# given lat/lon -> find hexagon_ID -> filter all flights
# plot flights on hexagon map

# plot Altitude / NIC vs time

# 2024-04-01
# 33.81825, 35.49082
# Label 318/Size 63600
# 30.0842, 31.35159
# Label 281/Size 56200


# 2024-02-01
# 33.81825, 35.49082
# Label 200/Size 40000

# 2024-03-01
# 33.81825, 35.49082
# Label 120/Size 24000

# %% [markdown]
# ### DO
# 1. .info() to get data types  or .dtypes
# 2. .describe() 0> gets mean() count(), 25%, 50%, 75% max min
# 3. .isnull() check for missing values   ->  isnull().sum().sort_values(ascending=False)
# 4. .nunique() -> gets unique values for each field with their counts
# 5. .unique() -> gets a list of unique values in a column
# 6. .value_counts() -> gets unique values for the column with their counts
# 7. for name, group in grouped: -> iterate over groups
# 8. pandas time series functions: Timestamp->DatetimeIndex[] (to_datetime, date_range), Timedelta->TimedeltaIndex[] (to_timedelta, timedelta_range), Period->PeriodIndex[] (Period, period_range), DateOffset (Dateoffset)
# 9. Missing Values: Numeric (pd.nan), String (pd.NA), Time (pd.NaT) -> use .isna(), .notna() to detect missing values
# 10. isinstance(df1, type(None)) to check for empty dataframe
# 11. df1['lat'].astype(float) to convert to type float
# 12. df1[(df1['nic']<7) & (df1['flight']=flight)] for dataframe conditional logic use bitwise and '&' or '|' not '~'
#
# ### DON'T DO
# 1. seems like saving as a pickle may corrupt the data, I see a lot of NA, maybe due to the data conversion between types. avoid any data conversion except at the start
# 2. use display() instead of print()
# 3. .dropna() -> WRONG USE, drops any row or column with a missing value!
# 4. df[df[]] is a filter, not selecting the rows. it is wrong
#
# flights time Hexagon_ID good_bad lat lon
# problem: some lat lon are NaN because of GPS failure. To assign nearest hexagon_ID based on nearest time with lat lon

# %%
# Change in NIC/NAC/SIL indicates an anomaly, which may be due to any reason

# nic: Navigation Integrity Category (2.2.3.2.7.2.6)
# Table 1: NIC value and corresponding size of containment radius
# NIC Containment Radius
# 0 Unknown
# 1 Rc < 37.04km (20nm)
# 2 Rc < 14.816km (8nm)
# 3 Rc < 7.408km (4nm)
# 4 Rc < 3.704km (2nm)
# 5 Rc < 1852m (1nm)
# 6 Rc < 1111.2m (0.6nm)
# Rc < 926m (0.5nm)
# Rc < 555.6m (0.3nm)
# 7 Rc < 370.4m (0.2nm)
# 8 Rc < 185.2m (0.1nm)
# 9 Rc < 75m
# 10 Rc < 25m
# 11 Rc < 7.5m

# Assuming you have already calculated the counts
# counts = df1['nic'].value_counts(dropna=False)
# print(f"List all nic values with counts {counts}")
# # Create bins for the histogram
# bins = np.arange(len(counts) + 1)

# # Plot the histogram with NA on the left
# plt.hist(df1['nic'], bins=bins, align='left',rwidth=0.5)
# plt.yscale('log')
# plt.title('nic')
# plt.show()

print(f"bad {df1[df1['good_bad']=='bad'].shape[0]}")
print(f"total {df1.shape[0]}")
print(f"% bad / total {df1[df1['good_bad']=='bad'].shape[0]/df1.shape[0]*100:.2f}%")
df1[df1['good_bad']=='bad'].head(100)

# %%
# %%
print(f"List all type with counts {df1['type'].value_counts()}")
# List all type with counts type
# adsb_icao         9145 - messages from a Mode S or ADS-B transponder, using a 24-bit ICAO address
# other              725 - IGNORE miscellaneous data received via Basestation / SBS format, quality / source is unknown.
# adsb_icao_nt       524 - IGNORE - messages from an ADS-B equipped “non-transponder” emitter e.g. a ground vehicle, using a 24-bit ICAO address
# mode_s             515 - ModeS data from the planes transponder (no position transmitted)
# adsr_icao          280 - rebroadcast of ADS-B messages originally sent via another data link e.g. UAT, using a 24-bit ICAO address
# tisb_other         256 - traffic information about a non-ADS-B target using a non-ICAO address
# tisb_trackfile     214 - traffic information about a non-ADS-B target using a track/file identifier, typically from primary or Mode A/C radar
# mlat               116 - MLAT, position calculated arrival time differences using multiple receivers, outliers and varying accuracy is expected.
# unknown             49
# tisb_icao           31 - traffic information about a non-ADS-B target identified by a 24-bit ICAO address, e.g. a Mode S target tracked by secondary radar
# adsb_other          17 - messages from an ADS-B transponder using a non-ICAO address, e.g. anonymized address
plt.hist(df1['type'], align='left')
plt.title('type')
plt.xticks(rotation='vertical')
plt.show()

# %%
# %%
# category: emitter category to identify particular aircraft or vehicle classes (values A0 – D7) (2.2.3.2.5.2)
counts = df1['category'].dropna()
# print(f"List all category with counts {counts}")
plt.hist(counts)
plt.title('category')
plt.show()
# A0 : No ADS-B emitter category information. Do not use this emitter category. If no emitter category fits your installation, seek guidance from the FAA as appropriate. A1 : Light (< 15500 lbs) – Any airplane with a maximum takeoff weight less than 15,500 pounds. This includes very light aircraft (light sport aircraft) that do not meet the requirements of 14 CFR § 103.1.
# A2 : Small (15500 to 75000 lbs) – Any airplane with a maximum takeoff weight greater than or equal to15,500 pounds but less than 75,000 pounds.
# A3 : Large (75000 to 300000 lbs) – Any airplane with a maximum takeoff weight greater than or equal to 75,000 pounds but less than 300,000 pounds that does not qualify for the high vortex category.
# A4 :  High vortex large (aircraft such as B-757) – Any airplane with a maximum takeoff weight greater than or equal to 75,000 pounds but less than 300,000 pounds that has been determined to generate a high wake vortex. Currently, the Boeing 757 is the only example.
# A5 : Heavy (> 300000 lbs) – Any airplane with a maximum takeoff weight equal to or above 300,000 pounds.
# A6 : High performance (> 5g acceleration and 400 kts) – Any airplane, regardless of weight, which can maneuver in excess of 5 G’s and maintain true airspeed above 400 knots.
# A7 : Rotorcraft – Any rotorcraft regardless of weight.
# B0 : No ADS-B emitter category information
# B1 : Glider / sailplane – Any glider or sailplane regardless of weight.
# B2 : Lighter-than-air – Any lighter than air (airship or balloon) regardless of weight.
# B3 : Parachutist / skydiver
# B4 : Ultralight / hang-glider / paraglider – A vehicle that meets the requirements of 14 CFR § 103.1. Light sport aircraft should not use the ultralight emitter category unless they meet 14 CFR § 103.1.
# B5 : Reserved
# B6 : Unmanned aerial vehicle – Any unmanned aerial vehicle or unmanned aircraft system regardless of weight.
# B7 : Space / trans-atmospheric vehicle
# C0 : No ADS-B emitter category information
# C1 : Surface vehicle – emergency vehicle
# C2 : Surface vehicle – service vehicle
# C3 : Point obstacle (includes tethered balloons)
# C4 : Cluster obstacle
# C5 : Line obstacle
# C6 : Reserved
# C7 : Reserved
