# %%
# !python -m venv venv
# # !venv/scripts/activate
# %pip install pandas numpy matplotlib seaborn plotly geopandas scipy scikit-learn statsmodels requests aiohttp shapely ipython h3 ipywidgets dtale tqdm pickle

# %pip install --upgrade nbformat

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt

import requests
import os

import datetime as dt

from pandas import read_csv
import concurrent.futures
import psutil

from datetime import datetime

import h3
import geopandas as gpd
import shapely
import plotly.express as px

from tqdm import tqdm
tqdm.pandas()

from pandas import read_pickle
import matplotlib.dates as mdates

import seaborn as sn
import sys

# %%
# Latitude and longitude coordinates
home_lat = 1.3472764
home_lng = 103.9104234

# Generate H3 hexagons at a specified resolution (e.g., 9)
resolution = 5

# Indicate the number of rings around the central hexagon
ring_size = 463

# global dataframes to avoid keep loading files
df1=None
df2=None
flights_data=None
hexagon_df=None
flights_df=None
hex_list_df = None

# %%
# Verify that the hexagon grid is suitable
# create_choropleth_map_only_hexagon_df(geojson_df=hexagon_df)

# def create_choropleth_map_only_hexagon_df(geojson_df, alpha=0.1, map_style="carto-positron", color_scale="Viridis"):
#     """
#     Create an interactive choropleth map using Plotly Express.
#     Parameters:
#     - geojson_df (GeoDataFrame): GeoJSON data containing polygon geometries.
#     - alpha (float): Opacity level for the map polygons (0.0 to 1.0).
#     - map_style (str): Map style for the Plotly map (e.g., "carto-positron").
#     - color_scale (str): Color scale for the choropleth map.
#     Returns:
#     None
#     """
#     # Create a choropleth map using px.choropleth_mapbox
#     fig = px.choropleth_mapbox(
#         geojson_df,
#         geojson=geojson_df.geometry,
#         locations=geojson_df.index,  # Use index as locations to avoid duplicate rows
#         # color="Count",
#         color_continuous_scale=color_scale,
#         title="GPS Jam Map",
#         mapbox_style=map_style,
#         center={"lat": home_lat, "lon": home_lng},  # Adjust the center as needed
#         zoom=2,
#     )

#     # Customize the opacity of the hexagons
#     fig.update_traces(marker=dict(opacity=alpha))

#     # Set margins to 25 on all sides
#     fig.update_layout(margin=dict(l=35, r=35, t=45, b=35))
    
#     # Adjust the width of the visualization
#     fig.update_layout(width=1000) 

#     fig.show()

# %% [markdown]
# ### Brief
# The dashboard or app has to be useful for a flight planner to decide how to plan a mission or for a pilot to decide how he might want to fly a flight profile. Given this, how should we investigate the data to determine a representation that yould help him/her. With this in mind, what does the data tell us? GPS Jamming is like encountering turbulence on route. It's undesirable for flight, but it's usually not a safety hazard unless it's large and unexpected.
# It is terrible for munitions that rely on this for guidance. But these profiles can be adjusted. You have access to pilots and planners who would fly these things. So we'll help to provide some context to how the data may be investigated. But do look at the raw data and see what it can tell you.
# Maybe you want to try unsupervised learning to see if there are distinct categories. And then investigate what are the common factors in these clusters? Do the EDA and see what hidden insights there are. Then you can decide on the best representation of the data.
#
# ### Exploratory Questions
#  1. How is GPS signal affected by altitude? Speed? Is there any strong correlation?

# %%
def calculate_hexagon_ids(df):
    """
    Calculate Hexagon IDs for each row(ping) in a DataFrame based on their geographic coordinates.
    Args:
        df (pd.DataFrame): DataFrame containing ADSB data with "lat" and "lon" columns.
        hexagon_df (gpd.GeoDataFrame): GeoDataFrame with hexagon geometries and associated Hexagon IDs.
    Returns:
        pd.DataFrame: The input DataFrame with an additional "Hexagon_ID" column indicating the Hexagon ID for each ping.
    """

    # Create a column Hexagon_ID with the ID of the hexagon
    df['Hexagon_ID'] = None

    df = df.sort_values(['flight','time'])

    # Iterate through the rows in the df DataFrame and calculate counts within each hexagon
    for i, ping in df.iterrows():
        if not isinstance(ping['lat'], float):
            # use location of last ping
            found = False
            j=1
            while not found:
                if isinstance(df.loc[i-j,'lat'],float):
                    df.loc[i,'lat']=df.loc[i-j,'lat']
                    df.loc[i,'lon']=df.loc[i-j,'lon']
                    found=True
                elif isinstance(df.loc[i+j,'lat'],float):
                    df.loc[i,'lat']=df.loc[i+j,'lat']
                    df.loc[i,'lon']=df.loc[i+j,'lon']
                    found=True
                else:
                    j+=1
            continue
        resolution=5   
        result = h3.geo_to_h3(ping["lat"], ping["lon"], resolution)
        # print(f'{ping["lat"]},{ping["lon"]}=>{result}')
        if result != 0:
             df.loc[i, 'Hexagon_ID'] = result
    
    return df

def get_adsb_data(data):
    """
    Fetches data from ADSB web api. Filter adsb_icao. Clean up non-numeric values. 
    Assign Hexagon_IDs to each ping. Convert types per the mapping. Filter where flight is null. 
    Assign "good_bad" is True when NIC >= 7, False when NIC <= 6
    Saves data to csv.
    Args:
        data: Dictionary of url and csv paths
    Returns:
        None

    """

    if (os.path.isfile(data["csv"])):
        print(f"csv exists {data['csv']}")
        return
    else:
        try:
            response = requests.get(data["url"])
            print(f"downloaded {data['url']}")
            json_data = response.json()
            
            df = pd.json_normalize(json_data['aircraft'])

            df = df[df["type"] == 'adsb_icao']
            df['time'] = pd.to_datetime(datetime.fromtimestamp(json_data['now']).strftime("%Y%m%d%H%M%S"))
            df['Hexagon_ID'] = pd.NA
            df['good_bad'] = np.NaN
            df = df[['flight','r','time', 'hex', 'Hexagon_ID', 'alt_baro', 'nic', 'good_bad','lat','lon','type','t','category','version','nac_p','nac_v','track','baro_rate','seen_pos','seen','gs','alt_geom']]	
            df = df[df["type"] == 'adsb_icao']
            df['alt_baro'] = df['alt_baro'].apply(lambda x: 0 if (x == "ground" or x == np.nan ) else float(x))
            df["nic"] = df["nic"].replace(np.NaN,0)

            mapping = {
                "flight": str,
                "r": str,
                "time": "datetime64[ns]",
                "hex": str,
                "Hexagon_ID": str,
                "alt_baro": float,
                "nic": float,
                "good_bad": bool,
                "lat": float,
                "lon": float,
                "type": str,
                "t": str,
                "category": str,
                "version": float,
                "nac_p": float,
                "nac_v": float,
                "track": float,
                "baro_rate": float,
                "seen_pos": float,
                "seen": float,
                "gs": float,
                "alt_geom": float
            }
            df=df.astype(mapping, copy=True)
            df['good_bad'] = df['nic'].apply(lambda x: False if x==np.NaN or x<7 else True)
            df = df[~df["flight"].isnull()]

            df = calculate_hexagon_ids(df)

            if not os.path.exists(os.path.dirname(data["csv"])):
                os.makedirs(os.path.dirname(data["csv"]))
            df.to_csv(data["csv"])

        except Exception as e:
            # Handle other exceptions
            print("Get ADSB Data: An error occurred:", e)


def join_large_file(folder_path,start,end,file_path):
    if os.path.exists(file_path):
        os.remove(file_path)
    isHeader = True
    with open(file_path, 'w') as outfile:
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            file_datetime = datetime.strptime(file_path, 'csv\\%Y%m%d\\%H%M%SZ.csv')
            print(file_datetime)
            if filename.endswith('.csv') and start <= file_datetime and file_datetime <= end:
                with open(file_path, 'r') as infile:
                    # skip row header
                    if isHeader:
                        outfile.write(infile.read())
                        isHeader = False
                    else:
                        outfile.write(''.join(infile.readlines()[1:]))
                print(f'Joined {file_path}')
        print(f"Saved {file_path}")

def get_flight_data(start_date_time):
    """
    Creates a table of flights and calculates stats for each flight based on aggregates over the rows
    Args:
        start_date_time: start time e.g. dt.datetime(YYYY,MM,DD,HH,MM,SS)
    Global:
        df1: dataframe of raw flight pings from ADSB
        global flights_data
    Returns:
        flights_data: one row for each flight with aggregated fields 'flight', 'bad_count', 'total_count', 'percentage_bad','result'
    """
    global df1
    global flights_data
    flights = df1["flight"].unique()
    flights = flights[1:]
    display(f"Found {flights.shape[0]} flights. Preparing data by flights")
    flights_data = pd.DataFrame(flights, columns=['flight']).progress_apply(lambda x: process_flights_data(x['flight']), axis=1)
    display(flights_data.head(10))
    save_df(flights_data, start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)
    return flights_data

def process_flights_data(flight):
    """
    Extract "rows" for this flight from the large df1 table. Calculate counts so that the flight cas be classified as "normal", "equipment failure", "analyse" or "unknown"
    This function is called inside a pandas.apply on flights_data.
    Args:
        flight: string of Flight Identifier
    Globals:
        df1: dataframe of raw flight pings from ADSB
    Returns:
        pd.Series: one row of flights_data dataframe with aggregated fields 'flight', 'bad_count', 'total_count', 'percentage_bad','result'
    """
    global df1
    rows = df1[df1['flight']==flight]
    # print(f"{flight} - {len(rows)} pings")
    bad_count = rows[rows['good_bad'] == False].shape[0]
    total_count = rows.shape[0]
    percentage_bad = bad_count/total_count if total_count!=0 else 0
    result = analyse_data(percentage_bad)
    return pd.Series({'flight': flight, 'bad_count': bad_count, 'total_count': total_count, 'percentage_bad': percentage_bad, 'result': result})

    
def process_data(start_date_time,end_date_time, reload=[False,False,False]):
    """
    Args:
        start_date_time: start time e.g. dt.datetime(YYYY,MM,DD,HH,MM,SS)
        end_date_time: end time e.g. dt.datetime(YYYY,MM,DD,HH,MM,SS)
        reload=[False,False,False]:
            Reload flags are for skipping steps and saving processing time
            reload[0]=True loads data from [date]joined.csv (df1)
            reload[1]=True loads data from [date]flights_data.csv (>45 min) (flights_data)
            reload[2]=True loads data from [date]hexbin.csv (df2)
    Returns:
        [df1, df2, flights_data]
        df1: dataframe of 'flight','r','time', 'hex', 'Hexagon_ID', 'alt_baro', 'nic', 'good_bad',
            'lat','lon','type','t','category','version','nac_p','nac_v','track','baro_rate','seen_pos',
            'seen','gs','alt_geom'
        flights_data: dataframe of  'flight','bad_count', 'total_count', 'percentage_bad', 'result'
        df2: dataframe of 'Hexagon_ID', 'total_count, 'bad_count', 'alt_baro_range', 'time_range', 
            'percentage_bad'

    """
    delta = dt.timedelta(seconds=5)
    start = start_date_time
    global df1
    global df2
    global flights_data
    file_path = os.path.join('csv', 'joined', f'{start_date_time.strftime("%Y%m%d")}joined.csv')

    if not reload[0]:

        data_array = []
        while start < end_date_time:
            data_array.append({
                "url": f'https://samples.adsbexchange.com/readsb-hist/{start.strftime("%Y/%m/%d")}/{start.strftime("%H%M%S")}Z.json.gz',
                "csv": os.path.join('csv',start.strftime("%Y%m%d"), f'{start.strftime("%H%M%S")}Z.csv')
                })
            start += delta

        try:
            with concurrent.futures.ThreadPoolExecutor() as executor:
                list(executor.map(lambda i: get_adsb_data(data_array[i]), range(len(data_array))))
        except Exception as e:
            print("Thread Pool: An error occurred:", e)
            
        join_large_file(os.path.join('csv',start_date_time.strftime("%Y%m%d")),start_date_time,end_date_time,file_path)
        csv_to_parquet(start_date_time, filetype = FileType.JOINED)

    df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True)
    
    flights_data = get_flight_data(start_date_time) if not reload[1] else load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)

    df2 = get_hexagon_df(start_date_time) if not reload[2] else load_df(start_date_time, filetype=FileType.HEXBIN, parquet=True)

    return [df1, flights_data, df2]


def get_hexagon_df(start_date_time):
    global df1
    global df2
    df2 = df1.groupby(['Hexagon_ID', 'flight'], as_index=False)[['good_bad','alt_baro','time']].agg(
                            total_count=('good_bad', lambda x: (x == x).sum()),
                            bad_count=('good_bad', lambda x: (x == False).sum()),
                            percentage_bad=('good_bad', lambda x: (x == False).sum()/(x==x).sum()),
                            alt_baro_min=('alt_baro', lambda x: x.min()),
                            alt_baro_max=('alt_baro', lambda x: x.max()),
                            time_min=('time', lambda x: x.min()),
                            time_max=('time', lambda x: x.max())
                            )
    df2 = pd.DataFrame(df2)
    df2["Hexagon_ID"]=df2["Hexagon_ID"].replace("0","NA")
    display(df2.head(10))

    # Apply the function to create new 'lat' and 'lng' columns
    coord = df2['Hexagon_ID'].apply(lambda x: h3.h3_to_geo(x) if x!="NA" else (np.nan, np.nan))
    df2[['lat', 'lon']] = pd.DataFrame(coord.tolist(), index=df2.index)

    # coord = df2['Hexagon_ID'].apply(lambda x: h3.h3_to_geo(x) if x!="NA" else pd.Series([np.nan, np.nan]))
    # df2['lat']=coord[0]
    # df2['lon']=coord[1]
    
    save_df(df2, start_date_time, filetype=FileType.HEXBIN, parquet=True)
    return df2


class FileType:
    JOINED = "joined"
    SAMPLED = "sampled"
    HEXBIN = "hexbin"
    FLIGHTS_DATA = "flights_data"

def save_df(df, start_date_time, filetype=FileType.JOINED, parquet=False):
    directory = 'joined'
    if parquet:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.parquet')
        display(f'Saving parquet {file_path}')
        df.to_parquet(file_path) 
    else:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.csv')
        display(f'Saving csv {file_path}')
        if isinstance(df, np.ndarray):
            df = pd.DataFrame(df)
            df.to_csv(file_path) 
        else:
            df.to_csv(file_path) 

def load_df(start_date_time, filetype=FileType.JOINED, parquet=False):
    directory = 'joined'
    if parquet:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.parquet')
        display(f'Reading parquet {file_path}')
        return pd.read_parquet(file_path)
    else:
        file_path = os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.csv')
        return pd.concat([chunk for chunk in tqdm(pd.read_csv(file_path, chunksize=1000000), desc=f'Loading csv {file_path}')])

def csv_to_parquet(start_date_time, filetype=FileType.JOINED):
    chunk_size = 1000000
    parquet_writer = pd.DataFrame()
    directory = 'joined'
    if filetype == FileType.HEXBIN:
        directory = 'hexbin'
    csv_path=os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.csv')
    parquet_path=os.path.join('csv', directory , f'{start_date_time.strftime("%Y%m%d")}{filetype}.parquet')
    print("Converting csv to parquet")
    for i,chunk in enumerate(pd.read_csv(csv_path, chunksize=chunk_size)):
        sys.stdout.write("Conversion progress: %d   \r" % (i) )
        sys.stdout.flush()
        parquet_writer = pd.concat([parquet_writer,chunk])
    parquet_writer.to_parquet(parquet_path)
    display(f"{parquet_path}")

def parquet_to_csv(start_date_time, filetype=FileType.JOINED):
    print("Converting parquet to csv")
    df1=load_df(start_date_time, filetype=filetype, parquet=True)
    save_df(df1, start_date_time, filetype=filetype, parquet=False)


class ResultGroup:
    EQUIPMENT_FAILURE = "equipment_failure"
    NORMAL = "normal"
    ANALYSE = "analyse"
    UNKNOWN = "unknown"

# plot Alt/NIC vs Time
def generate_plots(sample_size, group = ResultGroup.ANALYSE):
    global df1
    global flights_data

    if isinstance(df1, type(None)) or isinstance(flights_data, type(None)):
        print("Generate plots: error no data")
        return

    flights = [str(flight) for flight in flights_data[flights_data['result']==group].sample(sample_size)['flight']]
    for flight in flights:
        flight_df = df1[df1['flight']==flight]
        flight_df.set_index("time")

        fig, ax1 = plt.subplots(figsize=(8, 4))
        ax1.plot(flight_df['time'].astype("datetime64[ns]"), flight_df['alt_baro'], 'bx-', label='alt_baro')
        ax1.tick_params('y', colors='b')
        ax1.set_yticks(np.arange(0, 50000, 5000))
        ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y %H:%M:%S'))

        ax1.set_xlabel('Date-Time', fontsize=10)
        ax1.set_ylabel('Altitude (ft)', color='b', fontsize=10)

        plt.gcf().autofmt_xdate()

        ax2 = ax1.twinx()
        ax2.plot(flight_df['time'].astype("datetime64[ns]"), flight_df['nic'], 'rx-', label='nic')
        ax2.set_ylabel('NIC', color='g', fontsize=10)
        ax2.tick_params('y', colors='g')
        ax2.set_yticks(np.arange(0, 14, 1))

        plt.title(f'Flight:{flight} Altitude and NIC vs Time  (categorised as {group})', fontsize=10)
        fig.legend(loc="lower right")
        plt.show()
        url = f"https://doc8643.com/aircraft/{flight_df.iloc[0]['t']}"
        print(url)
# categorise flights based on NIC
def analyse_data(percentage_bad):
    upper_limit=0.9
    lower_limit=0.1
    if percentage_bad>upper_limit:
        return "equipment_failure"
    elif percentage_bad<lower_limit:
        return "normal"
    elif percentage_bad>=lower_limit and percentage_bad<=upper_limit:
        return "analyse"
    else: 
        return "unknown"

# correlations plot
def generate_correlations(sample_size, group = ResultGroup.ANALYSE):
    global df1
    global flights_data

    if isinstance(df1, type(None)) or isinstance(flights_data, type(None)):
        print("Generate plots: error no data")
        return

    flights = [str(flight) for flight in flights_data[flights_data['result']==group].sample(sample_size)['flight']]
    flights_df=None
    for flight in flights:
        flight_df = df1[df1['flight']==flight]
        flights_df = pd.concat([flights_df,flight_df])    
    
    flights_df.set_index("time")
    selected_columns = ["alt_baro", "nic", "nac_p","nac_v","track","baro_rate","seen_pos","seen","gs","alt_geom"]
    print(flights_df.shape[0])
    display(flights_df.head(10))

    corr_matrix = flights_df[selected_columns].corr(method='pearson')
    ax = plt.axes()
    ax.set_title(f'Pearson cofficient for sample size {sample_size}, \ngroup: {group} \nflights: {flights} ',fontsize=10)
    sn.heatmap(corr_matrix, annot=True)
    plt.show()

# generate hexagons
def get_hexagon_grid(latitude, longitude, resolution, ring_size):
    """
    Generate a hexagonal grid GeoDataFrame centered around a specified location.
    Parameters:
    - latitude (float): Latitude of the center point.
    - longitude (float): Longitude of the center point.
    - resolution (int): H3 resolution for hexagons.
    - ring_size (int): Number of rings to create around the center hexagon.
    Returns:
    - hexagon_df (geopandas.GeoDataFrame): GeoDataFrame containing hexagons and their geometries.
    """

    global hexagon_df

    # Get the H3 hexagons covering the specified location
    center_h3 = h3.geo_to_h3(latitude, longitude, resolution)
    hexagons = list(h3.k_ring(center_h3, ring_size))  # Convert the set to a list

    # Create a GeoDataFrame with hexagons and their corresponding geometries
    hexagon_geometries = [shapely.geometry.Polygon(h3.h3_to_geo_boundary(hexagon, geo_json=True)) for hexagon in hexagons]
    hexagon_df = gpd.GeoDataFrame({'Hexagon_ID': hexagons, 'geometry': hexagon_geometries})
    return hexagon_df

# plot hexagon map    
def create_choropleth_map(alpha=0.5, map_style="carto-positron", data="percentage_bad", limits=[0,0.1,0.5,1], lat=home_lat, lon=home_lng, hex_list=[]):
    """
    Create an interactive choropleth map using Plotly Express.
    Parameters:
    - geojson_df (GeoDataFrame): GeoJSON data containing polygon geometries.
    - data_df (DataFrame): DataFrame containing data to be visualized on the map.
    - alpha (float): Opacity level for the map polygons (0.0 to 1.0).
    - map_style (str): Map style for the Plotly map (e.g., "carto-positron").
    - color_scale (str): Color scale for the choropleth map.
    Returns:
    None
    """
    global df2
    global hexagon_df
    global flights_df
    global hex_list_df
    

    # Hexagon grid around HOME
    if isinstance(hexagon_df, type(None)):
        hexagon_df = get_hexagon_grid(home_lat, home_lng, resolution, ring_size)
    print("hexagons calculated")

    if isinstance(hex_list_df, type(None)):
        hex_list_df = df2[(df2["Hexagon_ID"].isin(hex_list))]
    print("hex_list_df calculated")
    display(hex_list_df.head(10))

    # Merge the GeoJSON data with your DataFrame
    merged_df = hexagon_df.merge(df2 if (len(hex_list)==0) else hex_list_df, on="Hexagon_ID", how="left")
    print(f'merged hexagon_df with {"df2" if (len(hex_list)==0) else "hex_list_df"}')

    merged_df['lat'].astype(float)
    merged_df['lon'].astype(float)
    # merged_df = merged_df.dropna(subset=['lat', 'lon']) if merged_df["lat"].isnull().values.any() else merged_df
    
    display(merged_df.head(10))
    print(f"merged_df: {merged_df.shape[0]}")

    # Create a choropleth map using px.choropleth_mapbox
    fig = px.choropleth_mapbox(
        merged_df,
        geojson=merged_df.geometry,
        locations=merged_df.index,  # Use index as locations to avoid duplicate rows
        color=data,
        color_continuous_scale=[[limits[0], f'rgba(0,255,0,{alpha})'],
                                [limits[1], f'rgba(255,255,0,{alpha})'],
                                [limits[2], f'rgba(255,0,0,{alpha})'],
                                [limits[3], f'rgba(255,0,0,{alpha})']],        
        title="GPS Jam Map",
        mapbox_style=map_style,
        center={"lat": lat, "lon": lon},  # Adjust the center as needed
        zoom=2,
    )

    # Customize the opacity of the hexagons
    fig.update_traces(marker=dict(opacity=alpha))

    # Add hover data for hotel names
    fig.update_traces(customdata=merged_df[["Hexagon_ID","bad_count", "total_count", "percentage_bad", "lat", "lon"]])

    # Define the hover template 
    hover_template = "<b>Hexagon ID:</b> %{customdata[0]}<br><b>Location:</b> %{customdata[4]:.4f},%{customdata[5]:.4f}<br><b>Percentage bad:</b> %{customdata[3]:.3f}<br><b>Total Count:</b> %{customdata[2]}<extra></extra>"
    fig.update_traces(hovertemplate=hover_template)

    # Set margins to 25 on all sides
    fig.update_layout(margin=dict(l=35, r=35, t=45, b=35))
    
    # Adjust the width of the visualization
    fig.update_layout(width=1000) 


    # Create a scatter mapbox plot for the flight data
    flight_fig = px.scatter_mapbox(
        flights_df,
        lat="lat",
        lon="lon",
        hover_name="flight", 
        hover_data=["flight","time","alt_baro", "nic", "nac_p","nac_v","track","baro_rate","seen_pos","seen","gs","alt_geom"], 
        color_discrete_sequence=["blue"],  # Set the color of the flight points
        zoom=2,
    )

    # Overlay the flight data onto the choropleth map
    fig.add_trace(flight_fig.data[0])

    fig.show()

# plot flights on hexagon map, only those flights passing through hexagons in the hex_list
def get_flights_with_hex_list(hex_list):
        
        global flights_df
        global df1

        flights_df=None


        for hexagon_ID in hex_list:
                
                # get the flights in that hexagon
                flights_in_hex = df1[df1['Hexagon_ID']==hexagon_ID]['flight'].unique()

                # extract all the rows for those flights
                for flight in flights_in_hex:
                        flight_df = df1[(df1['flight']==flight) & (df1['Hexagon_ID']==hexagon_ID)]
                        time_start = flight_df["time"].min()
                        time_end = flight_df["time"].max()
                        # flight_df2 contains all pings of the flight between the start and end time that the flight is inside the hex. i.e. it includes pings that have null lat/lon values
                        flight_df2 = df1[(df1['flight']==flight) & (df1['time'].between(time_start, time_end))]
                        flights_df = pd.concat([flights_df,flight_df2])

        display(flights_df.head(5))

        return flights_df
        # plot choropleth map with flights overlaid on top of the hexagons
        create_choropleth_map(data="percentage_bad", limits = [0,0.1,0.5,1], lat=hex_list[0][0], lon=hex_list[0][1], hex_list=hex_list)


# note that for the free sample, only the first day of each month is available on the adsbexchange
# 4 hours + to download 1 day of files
# 18 mins to reload

[df1, flights_data, df2] = process_data(dt.datetime(2024,3,1,0,0,0),dt.datetime(2024,3,2,0,0,0), reload=[False, False, False])
# Out:
# csv exists csv\20240301\000000Z.csv
# csv exists csv\20240301\000005Z.csv
# csv exists csv\20240301\000010Z.csv
# csv exists csv\20240301\000015Z.csv
# csv exists csv\20240301\000020Z.csv
# csv exists csv\20240301\000025Z.csv
# csv exists csv\20240301\000030Z.csv
# csv exists csv\20240301\000035Z.csv
# csv exists csv\20240301\000040Z.csv
# csv exists csv\20240301\000050Z.csv
# csv exists csv\20240301\000100Z.csv
# csv exists csv\20240301\000105Z.csv
# csv exists csv\20240301\000055Z.csv
# csv exists csv\20240301\000045Z.csv
# csv exists csv\20240301\000110Z.csv
# csv exists csv\20240301\000115Z.csv
# csv exists csv\20240301\000125Z.csv
# csv exists csv\20240301\000120Z.csv
# csv exists csv\20240301\000130Z.csv
# csv exists csv\20240301\000135Z.csv
# csv exists csv\20240301\000235Z.csv
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000320Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000305Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000450Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000405Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000435Z.json.gz
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000505Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000420Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000645Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000640Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000620Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000625Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000720Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000730Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000650Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000700Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000755Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000805Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000810Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000800Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000815Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000820Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000825Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000845Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000855Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000910Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000915Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000920Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000925Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000930Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000940Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000935Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000945Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000955Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/000950Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001000Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001010Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001035Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001025Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001045Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001050Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001115Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001305Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001320Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001405Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001420Z.json.gz
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001435Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001450Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001505Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001620Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001625Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001640Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001645Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001650Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001700Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001720Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001730Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001755Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001800Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001805Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001810Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001815Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001820Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001825Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001845Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001855Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001910Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001915Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001920Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001925Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001930Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001935Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001940Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001945Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001950Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/001955Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002000Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002010Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002025Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002035Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002045Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002050Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002115Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002305Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002320Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002405Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002420Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002435Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002450Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002505Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002620Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002625Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002640Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002645Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002650Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002700Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002720Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002730Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002755Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002800Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002810Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002805Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002815Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002820Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002825Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002845Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002855Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002910Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002915Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002920Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002925Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002930Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002935Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002940Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002945Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002950Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/002955Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003000Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003010Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003025Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003035Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003050Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003045Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003115Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003305Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003320Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003405Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003420Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003435Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003450Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003505Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003620Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003625Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003640Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003645Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003650Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003700Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003720Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003730Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003755Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003800Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003805Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003810Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003815Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003820Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003825Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003845Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003855Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003910Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003915Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003925Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003920Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003930Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003935Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003940Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003945Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003950Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/003955Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004000Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004010Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004025Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004035Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004045Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004050Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004115Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004305Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004320Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004405Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004420Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004435Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004450Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004505Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004620Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004625Z.json.gz
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004640Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004645Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004650Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004700Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004720Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004730Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004755Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004800Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004805Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004810Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004820Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004825Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004815Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004845Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004855Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/004905Z.json.gz
# ...
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121045Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121050Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121115Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121305Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121320Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121405Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121420Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121435Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121450Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121505Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121500Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121510Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121620Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121625Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121635Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121640Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121645Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121650Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121655Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121710Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121705Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121700Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121715Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121720Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121725Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121730Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121735Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121740Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121750Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121745Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121755Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121800Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121805Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121810Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121815Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121820Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121830Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121825Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121835Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121840Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121850Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121845Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121855Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121900Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121905Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121910Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121915Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121920Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121925Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121930Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121935Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121940Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121945Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121950Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/121955Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122025Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122015Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122020Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122005Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122000Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122010Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122030Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122035Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122040Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122045Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122050Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122105Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122100Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122055Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122115Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122120Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122130Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122125Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122110Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122135Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122145Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122140Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122150Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122155Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122200Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122205Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122210Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122215Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122220Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122235Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122230Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122225Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122240Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122245Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122250Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122255Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122300Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122305Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122310Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122315Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122325Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122320Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122330Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122335Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122340Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122345Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122350Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122355Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122400Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122405Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122410Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122415Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122420Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122425Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122430Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122435Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122440Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122445Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122450Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122455Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122510Z.json.gzdownloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122500Z.json.gz
#
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122505Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122515Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122520Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122525Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122530Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122535Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122540Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122545Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122550Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122555Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122600Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122605Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122610Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122615Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122620Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122625Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122630Z.json.gz
# downloaded https://samples.adsbexchange.com/readsb-hist/2024/03/01/122635Z.json.gz

# %%
save_df(df2, filetype=FileType.HEXBIN, parquet=True)

# %%
# Generate Plots For Sampled Flights, Alt/NIC vs Time
# start_date_time = dt.datetime(2024,4,1,0,0,0)
# df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True)
# flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)
# display(flights_data['result'].value_counts())

# > 0.9: Equipment Failure
# Between 0.1 and 0.9: Analyse
# < 0.1: Normal
# generate_plots(5, group=ResultGroup.NORMAL)
generate_plots(5, group=ResultGroup.ANALYSE)
# generate_plots(5, group=ResultGroup.EQUIPMENT_FAILURE)

# %%
# Plot correlations
# start_date_time = dt.datetime(2024,4,1,0,0,0)
# df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True)
# flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True)

generate_correlations(20, group = ResultGroup.ANALYSE)

# %%
display(df2.head(10))

# %%
start_date_time = dt.datetime(2024,4,1,0,0,0)
df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True) if isinstance(df1, type(None)) else df1
flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True) if isinstance(flights_data, type(None)) else flights_data

sample = flights_data[flights_data["result"]==ResultGroup.ANALYSE].sample(5)
sample_df=None
display(sample.head(5))
for flight in sample["flight"]:
    sample_df = pd.concat([sample_df,df1[df1["flight"]==flight]])
display(sample_df[(sample_df["flight"].isin(sample["flight"])) & sample_df['lat'].isnull()])
sample_df2 = calculate_hexagon_ids(sample_df[sample_df["flight"].isin(sample["flight"])])
sample_df2=sample_df2[~sample_df2['lat'].isnull()]
display(sample_df2[sample_df2['lat'].isnull()])

# %%
# Plot Hex Map

start_date_time = dt.datetime(2024,4,1,0,0,0)
df1 = load_df(start_date_time, filetype=FileType.JOINED, parquet=True) if isinstance(df1, type(None)) else df1
# display(df1.head(5))
print("Get hexagon df")
df2 = load_df(start_date_time, filetype=FileType.HEXBIN, parquet=True) if isinstance(df2, type(None)) else df2
df2 = df2[df2["Hexagon_ID"]!="NA"]
display(df2.tail(5))
print(f"df2: {df2.shape[0]}")
# save_df(df2, start_date_time, filetype=FileType.HEXBIN, parquet=True)
flights_data = load_df(start_date_time, filetype=FileType.FLIGHTS_DATA, parquet=True) if isinstance(flights_data, type(None)) else flights_data
# display(flights_data.head(5))

# %%
# coordinates of all the suspected GPS jammed hexagons
coord_list = [[33.81825, 35.49082],[30.0842, 31.35159]]
#convert to hexagon_ID
hex_list = [h3.geo_to_h3(coord[0], coord[1], resolution=resolution) for coord in coord_list]
print(hex_list)

# extract flights that pass through those hexagons
flights_df = get_flights_with_hex_list(hex_list) if isinstance(flights_df, type(None)) else flights_df

create_choropleth_map(data="percentage_bad", limits = [0,0.1,0.5,1], lat=coord_list[0][0], lon=coord_list[0][1], hex_list=hex_list)

# %%
# given lat/lon -> find hexagon_ID -> filter all flights
# plot flights on hexagon map

# plot Altitude / NIC vs time

# 2024-04-01
# 33.81825, 35.49082
# Label 318/Size 63600
# 30.0842, 31.35159
# Label 281/Size 56200


# 2024-02-01
# 33.81825, 35.49082
# Label 200/Size 40000

# 2024-03-01
# 33.81825, 35.49082
# Label 120/Size 24000

# %% [markdown]
# ### DO
# 1. .info() to get data types  or .dtypes
# 2. .describe() 0> gets mean() count(), 25%, 50%, 75% max min
# 3. .isnull() check for missing values   ->  isnull().sum().sort_values(ascending=False)
# 4. .nunique() -> gets unique values for each field with their counts
# 5. .unique() -> gets a list of unique values in a column
# 6. .value_counts() -> gets unique values for the column with their counts
# 7. for name, group in grouped: -> iterate over groups
# 8. pandas time series functions: Timestamp->DatetimeIndex[] (to_datetime, date_range), Timedelta->TimedeltaIndex[] (to_timedelta, timedelta_range), Period->PeriodIndex[] (Period, period_range), DateOffset (Dateoffset)
# 9. Missing Values: Numeric (pd.nan), String (pd.NA), Time (pd.NaT) -> use .isna(), .notna() to detect missing values
# 10. isinstance(df1, type(None)) to check for empty dataframe
# 11. df1['lat'].astype(float) to convert to type float
# 12. df1[(df1['nic']<7) & (df1['flight']=flight)] for dataframe conditional logic use bitwise and '&' or '|' not '~'
#
# ### DON'T DO
# 1. seems like saving as a pickle may corrupt the data, I see a lot of NA, maybe due to the data conversion between types. avoid any data conversion except at the start
# 2. use display() instead of print()
# 3. .dropna() -> WRONG USE, drops any row or column with a missing value!
# 4. df[df[]] is a filter, not selecting the rows. it is wrong
#
# flights time Hexagon_ID good_bad lat lon
# problem: some lat lon are NaN because of GPS failure. To assign nearest hexagon_ID based on nearest time with lat lon

# %%
# Change in NIC/NAC/SIL indicates an anomaly, which may be due to any reason

# nic: Navigation Integrity Category (2.2.3.2.7.2.6)
# Table 1: NIC value and corresponding size of containment radius
# NIC Containment Radius
# 0 Unknown
# 1 Rc < 37.04km (20nm)
# 2 Rc < 14.816km (8nm)
# 3 Rc < 7.408km (4nm)
# 4 Rc < 3.704km (2nm)
# 5 Rc < 1852m (1nm)
# 6 Rc < 1111.2m (0.6nm)
# Rc < 926m (0.5nm)
# Rc < 555.6m (0.3nm)
# 7 Rc < 370.4m (0.2nm)
# 8 Rc < 185.2m (0.1nm)
# 9 Rc < 75m
# 10 Rc < 25m
# 11 Rc < 7.5m

# Assuming you have already calculated the counts
# counts = df1['nic'].value_counts(dropna=False)
# print(f"List all nic values with counts {counts}")
# # Create bins for the histogram
# bins = np.arange(len(counts) + 1)

# # Plot the histogram with NA on the left
# plt.hist(df1['nic'], bins=bins, align='left',rwidth=0.5)
# plt.yscale('log')
# plt.title('nic')
# plt.show()

print(f"bad {df1[df1['good_bad']=='bad'].shape[0]}")
print(f"total {df1.shape[0]}")
print(f"% bad / total {df1[df1['good_bad']=='bad'].shape[0]/df1.shape[0]*100:.2f}%")
df1[df1['good_bad']=='bad'].head(100)

# %%
# %%
print(f"List all type with counts {df1['type'].value_counts()}")
# List all type with counts type
# adsb_icao         9145 - messages from a Mode S or ADS-B transponder, using a 24-bit ICAO address
# other              725 - IGNORE miscellaneous data received via Basestation / SBS format, quality / source is unknown.
# adsb_icao_nt       524 - IGNORE - messages from an ADS-B equipped “non-transponder” emitter e.g. a ground vehicle, using a 24-bit ICAO address
# mode_s             515 - ModeS data from the planes transponder (no position transmitted)
# adsr_icao          280 - rebroadcast of ADS-B messages originally sent via another data link e.g. UAT, using a 24-bit ICAO address
# tisb_other         256 - traffic information about a non-ADS-B target using a non-ICAO address
# tisb_trackfile     214 - traffic information about a non-ADS-B target using a track/file identifier, typically from primary or Mode A/C radar
# mlat               116 - MLAT, position calculated arrival time differences using multiple receivers, outliers and varying accuracy is expected.
# unknown             49
# tisb_icao           31 - traffic information about a non-ADS-B target identified by a 24-bit ICAO address, e.g. a Mode S target tracked by secondary radar
# adsb_other          17 - messages from an ADS-B transponder using a non-ICAO address, e.g. anonymized address
plt.hist(df1['type'], align='left')
plt.title('type')
plt.xticks(rotation='vertical')
plt.show()

# %%
# %%
# category: emitter category to identify particular aircraft or vehicle classes (values A0 – D7) (2.2.3.2.5.2)
counts = df1['category'].dropna()
# print(f"List all category with counts {counts}")
plt.hist(counts)
plt.title('category')
plt.show()
# A0 : No ADS-B emitter category information. Do not use this emitter category. If no emitter category fits your installation, seek guidance from the FAA as appropriate. A1 : Light (< 15500 lbs) – Any airplane with a maximum takeoff weight less than 15,500 pounds. This includes very light aircraft (light sport aircraft) that do not meet the requirements of 14 CFR § 103.1.
# A2 : Small (15500 to 75000 lbs) – Any airplane with a maximum takeoff weight greater than or equal to15,500 pounds but less than 75,000 pounds.
# A3 : Large (75000 to 300000 lbs) – Any airplane with a maximum takeoff weight greater than or equal to 75,000 pounds but less than 300,000 pounds that does not qualify for the high vortex category.
# A4 :  High vortex large (aircraft such as B-757) – Any airplane with a maximum takeoff weight greater than or equal to 75,000 pounds but less than 300,000 pounds that has been determined to generate a high wake vortex. Currently, the Boeing 757 is the only example.
# A5 : Heavy (> 300000 lbs) – Any airplane with a maximum takeoff weight equal to or above 300,000 pounds.
# A6 : High performance (> 5g acceleration and 400 kts) – Any airplane, regardless of weight, which can maneuver in excess of 5 G’s and maintain true airspeed above 400 knots.
# A7 : Rotorcraft – Any rotorcraft regardless of weight.
# B0 : No ADS-B emitter category information
# B1 : Glider / sailplane – Any glider or sailplane regardless of weight.
# B2 : Lighter-than-air – Any lighter than air (airship or balloon) regardless of weight.
# B3 : Parachutist / skydiver
# B4 : Ultralight / hang-glider / paraglider – A vehicle that meets the requirements of 14 CFR § 103.1. Light sport aircraft should not use the ultralight emitter category unless they meet 14 CFR § 103.1.
# B5 : Reserved
# B6 : Unmanned aerial vehicle – Any unmanned aerial vehicle or unmanned aircraft system regardless of weight.
# B7 : Space / trans-atmospheric vehicle
# C0 : No ADS-B emitter category information
# C1 : Surface vehicle – emergency vehicle
# C2 : Surface vehicle – service vehicle
# C3 : Point obstacle (includes tethered balloons)
# C4 : Cluster obstacle
# C5 : Line obstacle
# C6 : Reserved
# C7 : Reserved
